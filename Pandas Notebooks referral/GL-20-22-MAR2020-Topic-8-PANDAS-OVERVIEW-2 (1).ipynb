# %% [markdown]
# ### Pandas
# -  Pandas is open source library built on top of Numpy
# -  Fast analysis and data cleaning and preparation
# -  Excels in performance and productivity of analytical operations
# -  Works well with visualization tools
# -  Can work with data from wide variety of sources
#
# ###  Data Structures In Pandas
#  1) Series
#      - One Dimensional labelled Arrays
#      - Supports multiple data types
#      - Series is similar to numpy array, difference is it can be indexed by label
#      - Series can be defined out of ndarray,dict,scalar ,list
#      - Series are one dimensional in nature
#      - Series are not widely used in the industry as Dataframes are more applicable(easy to use) to real life usecases
#
#   2) Data Frame
#      - Two Dimensional Labelled Arrays
#      - Supports Multiple Data Types
#      - Input can be a Series or another Data Frame

# %% [markdown]
# ### Pandas Topics
#
# ## Data Analysis Process
# ##  Data Ingestion
#     ### Pandas Read
#     ### Reading XL Files
#
# ##  Data Preparation
#     ### Data Summarization
#         - Use of Describe
#         - Info()
#
#
# ##  Data Manipulation
#     - Data Grouping
#     - Data Sorting
#     - Renaming columns
#     - Treating Missing Values
#
#
# ## Data Exploration
#     - Univariate  & Bi Variate Analysis
#     - Feature Engineering
#     - Conditional Selection
#     - Row and Column level data retrieval
#
# ### Optional Topics
#     ### Pandas Series Overview
#     ### data manipulation - merge,join,concat

# %% [markdown]
# ---

# %% [markdown]
# # MODULE -1  -- Intro to pandas data types Series and Dataframes

# %% [markdown]
# ## Import Pandas Modules
# #### pandas and numpy are installed as part of anaconda installation
#       -  import pandas as pd
#
#   - incase the imports below fail, then we use the following approach
#   - go to anaconda prompt - windows start --> apps --> anaconda --> anaconda prompt
#   - this will open an anaconda prompt console
#   - anaconda prompt is like a command prompt where we can execute commands
#   - in anaconda prompt console type the following to install numpy
#
#                  conda install numpy
#
#  - in the anaconda prompt type the following to install pandas
#       conda install pandas

# %%
#### import packages
import pandas as pd
import numpy as np

# %% [markdown]
# ### Samples on Dataframes

# %% [markdown]
# ---

# %% [markdown]
#  Pandas Data Frames
#
# ### Data Frames
# - Data frames are 2d data structures
# - Data is aligned in a tabular format consists of rows and columns
# - DataFrames can hold multiple data types
# - DataFrames Constructor in pandas is
#     - pd.DataFrames(data=,index=,dtype=,copy)
#     - data holds the data source
#     - index holds the index to access the data source
#     - dtype is type of the data
#     - copy is self to false default. take a copy

# %%
### importing Numpy
import numpy as np

### importing Pandas
import pandas as pd

# %%
### used to create random numbers
from numpy.random import randn

# %% [markdown]
# ### Data Frame Basics
#   - use of index and column parameters
#   - creating data frames via other python data objects

# %% [markdown]
#  #### Creating some sample data frames using randomly generated numbers
#  - randn library helps to generate numbers that can fit a normal distribution
#  - in the example below, we are generating random numbers using randn to create a dataframe of 5 rows and 4 columns

# %%
### https://yourbasic.org/algorithms/random-number-generator-seed/

# %%
#### creating a data frame using random number generator randn,use shift + tab to understand more about data frame parameters

df0 = pd.DataFrame(data=randn(5,4),index=['A','B','C','D','E'],columns= ['W','X','Y','Z'])

# %%
df0

#### each of the column W,X,Y,Z is each a pandas series sharing a common index
# Out:
#           W         X         Y         Z
# A -0.268540 -0.569411  1.092268  1.165874
# B  1.478290 -0.590652  0.513888  1.349180
# C -0.418708 -1.304127 -0.803231  0.921256
# D -1.844925 -0.330221  1.109703  0.317364
# E  0.192466 -0.107064 -0.151337 -0.272687

# %%
### to understand the data type of df0
type(df0)
# Out:
# pandas.core.frame.DataFrame

# %%
### if index parameter is removed, row names are replaced by defauly indexes
df00 = pd.DataFrame(data=randn(5,4),columns= ['W','X','Y','Z'])
df00
# Out:
#           W         X         Y         Z
# 0 -0.518204  0.291248 -0.016741  0.196887
# 1  1.267260  1.308870  0.718716 -1.826749
# 2 -0.187964 -0.051042  0.784414 -1.364607
# 3  1.797825 -1.531462 -0.074510 -1.381146
# 4 -1.209872 -0.525341 -0.579285 -0.032910

# %%
### if column parameter is removed, column names are replaced by defauly indexes

df01 = pd.DataFrame(data=randn(5,4),index=['A','B','C','D','E'])
df01
# Out:
#           0         1         2         3
# A  1.432008 -0.035302 -1.516400 -0.212005
# B  0.204163  1.075614 -0.822085 -1.525643
# C -0.273589  1.468303  0.051317  1.306265
# D  0.083379  0.018203  0.130211  1.346945
# E  1.329506  0.317123  0.453513 -0.324383

# %%
### if both index and column parameter is removed, row and column names are replaced by defauly indexes

df02 = pd.DataFrame(data=randn(5,4))
df02
# Out:
#           0         1         2         3
# 0 -0.724603  1.523029  0.729957 -0.175371
# 1  1.009755  1.560977 -0.815943  0.504981
# 2  0.612877  2.106022 -0.042765  1.223614
# 3  0.506072 -0.788211  0.374765 -1.013594
# 4 -2.473304  0.858378 -0.813954  0.840191

# %%
#### creating a data frame from a list
df_list = [['a1','b1','c1'],['a2','b2','c2'],['a3','b3','c3']]
df_list

#### to create user defined index, let us create a list of index
df_index = ['indx1','indx2','indx3']

# %%
### create dataframe from list
#data_Frame_list = pd.DataFrame(data=df_list)

data_Frame_list = pd.DataFrame(data=df_list,index=df_index,columns=('ColA','ColB','Colc'))
data_Frame_list
# Out:
#       ColA ColB Colc
# indx1   a1   b1   c1
# indx2   a2   b2   c2
# indx3   a3   b3   c3

# %%
#### creating a dataframe from dictionary
#### let us create a new diction
df_dict = {'k1':(1,2,3),'k2':(20,30,40),'k3':(30,40,50),'k4':[100,200,300]}


df_dict

### to make INDEXES FOR DATAFRAME
#data_F
rame_dict = pd.
DataFrame(data=df_dict,index=('k1','k2','k3','k4'),columns=('ColA','ColB','ColC','ColD'))
#data_Frame_dict
# Out:
#   File "C:\Users\anand\AppData\Local\Temp/ipykernel_15796/3561871149.py", line 10
#     rame_dict = pd.
#                    ^
# SyntaxError: invalid syntax

# %%
### dictionary keys cannot be replaced by dataframe indexes
### to make INDEXES FOR DATAFRAME using dict data
data_Frame_dict = pd.DataFrame(data=df_dict,index=('I1','I2','I3','I4'),columns=('ColA','ColB','ColC','ColD'))
data_Frame_dict

### we get missing values (NaN)
### dictionay keys cannot be replaced by user defined indexes given in the create dataframe command
### dictionary keys can only be defined during the definition of dictionary
### since the dataframe data_Frame_dict got created with an columns=ColA,ColB,Colc,ColD , but the data= has the data from dictionary
### so dataframe is not able to align the column parameter to the keys of the dictionary
### so we get missing values
# Out:
#    ColA ColB ColC ColD
# I1  NaN  NaN  NaN  NaN
# I2  NaN  NaN  NaN  NaN
# I3  NaN  NaN  NaN  NaN
# I4  NaN  NaN  NaN  NaN

# %%
### default creation of dataframe using a dictionary
### keys of the dictionary will be sitting as columns
data_Frame_dict = pd.DataFrame(data=df_dict,index=('I1','I2','I3'))
data_Frame_dict
# Out:
#     k1  k2  k3   k4
# I1   1  20  30  100
# I2   2  30  40  200
# I3   3  40  50  300

# %%
df_dict
# Out:
# {'k1': (1, 2, 3),
#  'k2': (20, 30, 40),
#  'k3': (30, 40, 50),
#  'k4': [100, 200, 300]}

# %%
data_Frame_dict = pd.DataFrame(data=df_dict,index=('I1','I2','I3'),columns=('k1','k2','k3','k4'))
data_Frame_dict
# Out:
#     k1  k2  k3   k4
# I1   1  20  30  100
# I2   2  30  40  200
# I3   3  40  50  300

# %%
### default creation of dataframe using a dictionary
### keys of the dictionary will be sitting as columns
data_Frame_dict = pd.DataFrame(data=df_dict)
print(data_Frame_dict)
# Out:
#    k1  k2  k3   k4   k5
# 0   1  20  30  100  100
# 1   2  30  40  200  200
# 2   3  40  50  300  300

# %%
df00= pd.DataFrame({'col1':[1,2,3,4,5],'col2':[444,555,333,120,111],'col3':['abc','cde','def','efg','ghi']})

# %% [markdown]
# #### Data Analysis Process
#  - Data Ingestion
#  - Data Preparation
#    - Data Summarization

# %% [markdown]
# ### DATA INGESTION VIA PANDAS

# %% [markdown]
# ### Creating Data Frames by reading files

# %%
## WE WILL USE THE FILE Uber Drives

# %%
## Pandas Libraries to be installed 
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Ingestion with Pandas

# %%
# read the data in pandas FROM A CSV

df = pd.read_csv("Uber Drives 2016-new.csv")

#### default read - when the file is in the same folder as that of our jupyter .ipynb notebook

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1156 rows x 7 columns]

# %% [markdown]
# ### other ways of reading csv files
#
# ### 1
# import pandas as pd
# df = pd.read_csv('C:\\E:\\DATASCIENCE\\GL\\GLCA\\Week-3 (Numpy and Pandas)Uber Drives 2016.csv')
#
# you can also do an import as below
#
# ### 2
# from pandas import read_csv
# read_csv('C:\\Users\\anand\\Python-DataScience-Anand\\GL\\march-2930-2019\\Uber Drives 2016.csv')
#
# ### 3 - read as raw string
# import pandas as pd
# pd.read_csv(r'C:\Users\anand\Python-DataScience-Anand\GL\march-2930-2019\Uber Drives 2016.csv')
#
# ### 4
# import pandas as pd
# pd.read_csv('C:/Users/anand/Python-DataScience-Anand/GL/march-2930-2019/Uber Drives 2016.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1156 rows x 7 columns]

# %%
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.head(2)
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*        STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce  Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce  Fort Pierce
#
#    MILES*        PURPOSE*
# 0     5.1  Meal/Entertain
# 1     5.0             NaN

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.tail(2)
# Out:
#            START_DATE*         END_DATE* CATEGORY*   START*      STOP*  \
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business  Gampaha  Ilukwatta
# 1155            Totals               NaN       NaN      NaN        NaN
#
#        MILES*        PURPOSE*
# 1154     48.2  Temporary Site
# 1155  12204.7             NaN

# %%
df.loc[100:110]
# Out:
#           START_DATE*         END_DATE* CATEGORY*            START*  \
# 100  02-12-2016 15:33  02-12-2016 16:06  Business       Morrisville
# 101   2/13/2016 14:21   2/13/2016 14:41  Business              Cary
# 102   2/13/2016 23:45    2/14/2016 0:01  Personal     East Elmhurst
# 103    2/14/2016 0:50    2/14/2016 1:00  Personal   Jackson Heights
# 104   2/14/2016 14:07   2/14/2016 14:40  Business     East Elmhurst
# 105   2/14/2016 14:46   2/14/2016 15:03  Business           Midtown
# 106   2/14/2016 16:35   2/14/2016 17:02  Business          New York
# 107   2/14/2016 17:06   2/14/2016 17:29  Business  Long Island City
# 108    2/16/2016 3:21    2/16/2016 4:13  Business        Katunayaka
# 109    2/16/2016 8:29    2/16/2016 9:34  Business  Unknown Location
# 110   2/16/2016 10:31   2/16/2016 10:41  Business           Colombo
#
#                 STOP*  MILES*        PURPOSE*
# 100              Cary    11.5  Customer Visit
# 101       Morrisville     8.9         Meeting
# 102   Jackson Heights     2.7             NaN
# 103     East Elmhurst     1.8             NaN
# 104          New York     8.1         Meeting
# 105      Midtown West     2.0         Meeting
# 106  Long Island City    13.0         Meeting
# 107           Jamaica    13.9         Meeting
# 108  Unknown Location    43.7  Customer Visit
# 109           Colombo    14.1             NaN
# 110           Colombo     2.6             NaN

# %%
df.loc[[100,120]]
# Out:
#           START_DATE*         END_DATE* CATEGORY*       START*       STOP*  \
# 100  02-12-2016 15:33  02-12-2016 16:06  Business  Morrisville        Cary
# 120   2/17/2016 16:38   2/17/2016 16:43  Business   Katunayaka  Katunayaka
#
#      MILES*         PURPOSE*
# 100    11.5   Customer Visit
# 120     0.5  Errand/Supplies

# %% [markdown]
# ### Data Profiling
#  - understand the data at a high level
#  - top few rows, bottom few rows
#  - get information about columns
#  - get information about data types of columns
#  - get information about number of rows

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1156 rows x 7 columns]

# %%
###### to display the data in a dataframe - will now show every row
#### jupyter manages the memory by displaying top 30 and bottom 30 rows
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.iloc[4][3]
# Out:
# 'Fort Pierce'

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1156 rows x 7 columns]

# %%
### by default display is adjusted by jupyter to 60 rows.
### to change it we can use pd.options.display.max_rows and set it to max rows in the dataframe
### not recommended approach

pd.options.display.max_rows = 1156

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business
# 1        1/2/2016 1:25     1/2/2016 1:37  Business
# 2       1/2/2016 20:25    1/2/2016 20:38  Business
# 3       1/5/2016 17:31    1/5/2016 17:45  Business
# 4       1/6/2016 14:42    1/6/2016 15:49  Business
# 5       1/6/2016 17:15    1/6/2016 17:19  Business
# 6       1/6/2016 17:30    1/6/2016 17:35  Business
# 7       1/7/2016 13:27    1/7/2016 13:33  Business
# 8       1/10/2016 8:05    1/10/2016 8:25  Business
# 9      1/10/2016 12:17   1/10/2016 12:44  Business
# 10     1/10/2016 15:08   1/10/2016 15:51  Business
# 11     1/10/2016 18:18   1/10/2016 18:53  Business
# 12     1/10/2016 19:12   1/10/2016 19:32  Business
# 13      1/11/2016 8:55    1/11/2016 9:21  Business
# 14     1/11/2016 11:56   1/11/2016 12:03  Business
# 15     1/11/2016 13:32   1/11/2016 13:46  Business
# 16     1/11/2016 14:30   1/11/2016 14:43  Business
# 17     1/12/2016 12:33   1/12/2016 12:49  Business
# 18     1/12/2016 12:53   1/12/2016 13:09  Business
# 19     1/12/2016 14:42   1/12/2016 14:56  Business
# 20     1/12/2016 15:13   1/12/2016 15:28  Business
# 21     1/12/2016 15:42   1/12/2016 15:54  Business
# 22     1/12/2016 16:02   1/12/2016 17:00  Business
# 23     1/13/2016 13:54   1/13/2016 14:07  Business
# 24     1/13/2016 15:00   1/13/2016 15:28  Business
# 25     1/14/2016 16:29   1/14/2016 17:05  Business
# 26     1/14/2016 21:39   1/14/2016 21:45  Business
# 27      1/15/2016 0:41    1/15/2016 1:01  Business
# 28     1/15/2016 11:43   1/15/2016 12:03  Business
# 29     1/15/2016 13:26   1/15/2016 13:44  Business
# 30     1/18/2016 14:55   1/18/2016 15:06  Business
# 31     1/18/2016 16:13   1/18/2016 16:24  Business
# 32      1/19/2016 9:09    1/19/2016 9:23  Business
# 33     1/19/2016 10:55   1/19/2016 11:09  Business
# 34     1/20/2016 10:36   1/20/2016 11:11  Business
# 35     1/20/2016 11:48   1/20/2016 12:19  Business
# 36     1/20/2016 13:25   1/20/2016 14:19  Business
# 37     1/21/2016 14:25   1/21/2016 14:29  Business
# 38     1/21/2016 14:43   1/21/2016 14:51  Business
# 39     1/21/2016 16:01   1/21/2016 16:06  Business
# 40     1/26/2016 10:41   1/26/2016 10:50  Business
# 41     1/26/2016 12:33   1/26/2016 12:41  Business
# 42     1/26/2016 16:24   1/26/2016 16:32  Business
# 43     1/26/2016 17:17   1/26/2016 17:22  Business
# 44     1/26/2016 17:27   1/26/2016 17:29  Business
# 45      1/27/2016 9:24    1/27/2016 9:31  Business
# 46     1/27/2016 10:19   1/27/2016 10:48  Business
# 47     1/27/2016 12:34   1/27/2016 12:44  Business
# 48     1/27/2016 14:05   1/27/2016 14:13  Business
# 49     1/27/2016 14:46   1/27/2016 15:08  Business
# 50     1/28/2016 12:28   1/28/2016 13:00  Business
# 51     1/28/2016 15:11   1/28/2016 15:31  Business
# 52     1/28/2016 16:21   1/28/2016 16:51  Business
# 53      1/29/2016 9:31    1/29/2016 9:45  Business
# 54     1/29/2016 10:56   1/29/2016 11:07  Business
# 55     1/29/2016 11:43   1/29/2016 12:03  Business
# 56     1/29/2016 13:24   1/29/2016 13:47  Business
# 57     1/29/2016 18:31   1/29/2016 18:52  Business
# 58     1/29/2016 21:21   1/29/2016 21:40  Business
# 59     1/30/2016 16:21   1/30/2016 16:33  Business
# 60     1/30/2016 18:09   1/30/2016 18:24  Business
# 61      2/1/2016 10:35    2/1/2016 11:15  Business
# 62      2/1/2016 12:10    2/1/2016 12:43  Business
# 63      2/1/2016 12:56    2/1/2016 13:07  Business
# 64      2/2/2016 13:04    2/2/2016 13:23  Business
# 65      2/2/2016 13:51    2/2/2016 14:06  Business
# 66      2/2/2016 14:38    2/2/2016 14:42  Business
# 67       2/4/2016 8:40     2/4/2016 9:01  Business
# 68       2/4/2016 9:37    2/4/2016 10:09  Business
# 69      2/4/2016 10:26    2/4/2016 10:32  Business
# 70      2/4/2016 15:59    2/4/2016 16:03  Business
# 71      2/4/2016 16:35    2/4/2016 16:39  Business
# 72      2/4/2016 18:04    2/4/2016 18:31  Business
# 73      2/4/2016 20:36    2/4/2016 20:55  Business
# 74      2/5/2016 11:47    2/5/2016 12:07  Business
# 75      2/5/2016 13:22    2/5/2016 13:41  Business
# 76      2/6/2016 16:20    2/6/2016 16:53  Business
# 77      2/6/2016 18:57    2/6/2016 19:21  Business
# 78      2/6/2016 19:28    2/6/2016 19:37  Business
# 79      2/7/2016 16:49    2/7/2016 17:01  Business
# 80      2/7/2016 18:03    2/7/2016 18:17  Business
# 81      2/7/2016 18:39    2/7/2016 18:53  Business
# 82      2/7/2016 20:22    2/7/2016 20:40  Business
# 83      2/8/2016 12:57    2/8/2016 13:08  Business
# 84      2/8/2016 14:00    2/8/2016 14:10  Business
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal
# 88      2/9/2016 13:58    2/9/2016 14:02  Personal
# 89      2/9/2016 18:55    2/9/2016 19:11  Business
# 90      2/9/2016 20:24    2/9/2016 20:40  Business
# 91     2/11/2016 16:28   2/11/2016 17:10  Business
# 92     2/11/2016 17:49   2/11/2016 18:10  Business
# 93     2/11/2016 18:24   2/11/2016 18:46  Business
# 94     2/11/2016 20:36   2/11/2016 20:51  Business
# 95      2/12/2016 8:21    2/12/2016 8:42  Business
# 96     2/12/2016 10:45   2/12/2016 10:52  Business
# 97     2/12/2016 11:14   2/12/2016 11:35  Business
# 98     2/12/2016 13:02   2/12/2016 13:36  Business
# 99     2/12/2016 14:49   2/12/2016 15:06  Business
# 100    2/12/2016 15:33   2/12/2016 16:06  Business
# 101    2/13/2016 14:21   2/13/2016 14:41  Business
# 102    2/13/2016 23:45    2/14/2016 0:01  Personal
# 103     2/14/2016 0:50    2/14/2016 1:00  Personal
# 104    2/14/2016 14:07   2/14/2016 14:40  Business
# 105    2/14/2016 14:46   2/14/2016 15:03  Business
# 106    2/14/2016 16:35   2/14/2016 17:02  Business
# 107    2/14/2016 17:06   2/14/2016 17:29  Business
# 108     2/16/2016 3:21    2/16/2016 4:13  Business
# 109     2/16/2016 8:29    2/16/2016 9:34  Business
# 110    2/16/2016 10:31   2/16/2016 10:41  Business
# 111    2/16/2016 11:32   2/16/2016 12:02  Business
# 112    2/16/2016 12:39   2/16/2016 12:42  Business
# 113    2/16/2016 13:43   2/16/2016 13:55  Business
# 114    2/16/2016 16:34   2/16/2016 17:10  Business
# 115    2/16/2016 17:17   2/16/2016 17:26  Business
# 116    2/16/2016 17:40   2/16/2016 17:44  Business
# 117    2/17/2016 13:18   2/17/2016 14:04  Business
# 118    2/17/2016 15:17   2/17/2016 15:22  Business
# 119    2/17/2016 15:33   2/17/2016 16:17  Business
# 120    2/17/2016 16:38   2/17/2016 16:43  Business
# 121     2/18/2016 8:19    2/18/2016 8:27  Business
# 122    2/18/2016 14:03   2/18/2016 14:45  Business
# 123    2/18/2016 15:16   2/18/2016 15:31  Business
# 124    2/18/2016 18:44   2/18/2016 18:58  Business
# 125    2/18/2016 19:27   2/18/2016 20:08  Business
# 126     2/19/2016 9:02    2/19/2016 9:14  Business
# 127     2/19/2016 9:21    2/19/2016 9:51  Business
# 128    2/19/2016 10:21   2/19/2016 10:48  Business
# 129    2/19/2016 11:20   2/19/2016 11:26  Personal
# 130    2/19/2016 11:45   2/19/2016 11:50  Personal
# 131    2/19/2016 12:09   2/19/2016 12:27  Business
# 132    2/19/2016 16:26   2/19/2016 16:45  Business
# 133    2/19/2016 17:09   2/19/2016 17:20  Business
# 134    2/19/2016 20:08   2/19/2016 20:30  Personal
# 135    2/19/2016 20:34   2/19/2016 20:51  Personal
# 136     2/20/2016 7:59    2/20/2016 8:32  Personal
# 137    2/20/2016 10:48   2/20/2016 10:56  Personal
# 138    2/20/2016 11:45   2/20/2016 11:53  Personal
# 139    2/20/2016 12:41   2/20/2016 13:17  Business
# 140    2/20/2016 14:50   2/20/2016 15:54  Business
# 141    2/20/2016 16:59   2/20/2016 17:54  Personal
# 142    2/20/2016 18:00   2/20/2016 18:03  Business
# 143    2/20/2016 19:28   2/20/2016 19:49  Business
# 144     2/21/2016 9:07    2/21/2016 9:46  Business
# 145    2/21/2016 11:39   2/21/2016 11:43  Business
# 146    2/21/2016 11:47   2/21/2016 12:01  Business
# 147    2/21/2016 12:13   2/21/2016 12:35  Business
# 148    2/21/2016 12:51   2/21/2016 13:12  Business
# 149    2/21/2016 13:33   2/21/2016 14:30  Business
# 150    2/21/2016 14:36   2/21/2016 15:03  Business
# 151    2/21/2016 15:14   2/21/2016 15:31  Business
# 152    2/21/2016 15:36   2/21/2016 15:41  Business
# 153    2/21/2016 16:04   2/21/2016 16:32  Business
# 154    2/21/2016 23:15   2/21/2016 23:52  Business
# 155    2/22/2016 21:54   2/22/2016 22:09  Business
# 156    2/24/2016 14:30   2/24/2016 14:35  Business
# 157    2/24/2016 15:19   2/24/2016 15:25  Business
# 158    2/25/2016 16:27   2/25/2016 16:35  Business
# 159    2/25/2016 16:47   2/25/2016 17:02  Business
# 160    2/25/2016 17:16   2/25/2016 17:36  Business
# 161    2/25/2016 18:22   2/25/2016 18:39  Business
# 162     2/26/2016 9:06    2/26/2016 9:29  Business
# 163    2/26/2016 11:05   2/26/2016 11:11  Personal
# 164    2/26/2016 11:35   2/26/2016 11:59  Business
# 165    2/26/2016 13:01   2/26/2016 13:24  Business
# 166    2/26/2016 14:38   2/26/2016 14:46  Personal
# 167    2/26/2016 15:00   2/26/2016 15:18  Personal
# 168    2/26/2016 17:01   2/26/2016 17:12  Personal
# 169     2/28/2016 5:22    2/28/2016 5:38  Business
# 170     2/28/2016 9:26    2/28/2016 9:42  Business
# 171    2/29/2016 11:07   2/29/2016 11:14  Personal
# 172    2/29/2016 11:30   2/29/2016 11:40  Business
# 173    2/29/2016 12:36   2/29/2016 12:48  Business
# 174    2/29/2016 14:55   2/29/2016 15:03  Business
# 175    2/29/2016 16:40   2/29/2016 17:00  Business
# 176     3/1/2016 18:47    3/1/2016 19:10  Business
# 177     3/1/2016 21:27    3/1/2016 21:45  Business
# 178      3/3/2016 9:45     3/3/2016 9:52  Personal
# 179     3/3/2016 11:04    3/3/2016 11:10  Business
# 180     3/3/2016 14:44    3/3/2016 14:58  Business
# 181     3/3/2016 15:27    3/3/2016 15:48  Business
# 182     3/3/2016 16:02    3/3/2016 16:42  Business
# 183      3/4/2016 7:47     3/4/2016 8:06  Business
# 184      3/4/2016 9:46    3/4/2016 10:03  Business
# 185     3/4/2016 11:46    3/4/2016 12:06  Business
# 186     3/4/2016 13:03    3/4/2016 13:25  Business
# 187     3/4/2016 13:40    3/4/2016 14:09  Business
# 188     3/4/2016 15:56    3/4/2016 16:08  Business
# 189     3/4/2016 16:16    3/4/2016 16:22  Business
# 190     3/4/2016 16:43    3/4/2016 17:12  Business
# 191     3/4/2016 19:02    3/4/2016 19:08  Business
# 192     3/4/2016 19:16    3/4/2016 19:25  Business
# 193     3/5/2016 11:44    3/5/2016 11:59  Business
# 194     3/5/2016 12:57    3/5/2016 13:12  Personal
# 195     3/5/2016 14:08    3/5/2016 14:18  Personal
# 196     3/5/2016 14:39    3/5/2016 15:01  Business
# 197     3/5/2016 16:52    3/5/2016 17:13  Business
# 198     3/5/2016 17:23    3/5/2016 17:34  Business
# 199      3/7/2016 9:10     3/7/2016 9:20  Business
# 200      3/7/2016 9:23     3/7/2016 9:47  Business
# 201     3/7/2016 12:10    3/7/2016 12:26  Business
# 202     3/7/2016 13:57    3/7/2016 14:18  Business
# 203     3/7/2016 15:19    3/7/2016 15:45  Business
# 204     3/8/2016 14:38    3/8/2016 14:55  Business
# 205     3/8/2016 15:35    3/8/2016 16:00  Business
# 206     3/8/2016 16:13    3/8/2016 16:25  Personal
# 207     3/10/2016 3:36    3/10/2016 3:53  Business
# 208    3/10/2016 10:08   3/10/2016 10:37  Business
# 209    3/10/2016 14:39   3/10/2016 14:55  Business
# 210    3/10/2016 16:18   3/10/2016 16:28  Business
# 211     3/11/2016 9:47    3/11/2016 9:59  Business
# 212    3/11/2016 10:29   3/11/2016 10:36  Business
# 213    3/11/2016 11:57   3/11/2016 12:04  Business
# 214    3/11/2016 13:43   3/11/2016 13:51  Business
# 215    3/11/2016 19:21   3/11/2016 19:35  Business
# 216     3/12/2016 9:13    3/12/2016 9:22  Business
# 217    3/12/2016 18:27   3/12/2016 18:37  Personal
# 218     3/13/2016 9:07    3/13/2016 9:37  Business
# 219    3/13/2016 18:23   3/13/2016 18:43  Business
# 220    3/13/2016 20:07   3/13/2016 20:28  Business
# 221    3/13/2016 20:39   3/13/2016 20:58  Business
# 222    3/13/2016 21:11   3/13/2016 21:23  Business
# 223    3/13/2016 22:19   3/13/2016 22:39  Business
# 224     3/14/2016 8:34    3/14/2016 8:49  Business
# 225    3/14/2016 18:39   3/14/2016 18:55  Business
# 226     3/15/2016 8:45    3/15/2016 8:57  Business
# 227    3/15/2016 20:48   3/15/2016 21:01  Business
# 228    3/16/2016 11:34   3/16/2016 11:45  Business
# 229    3/16/2016 14:44   3/16/2016 14:55  Business
# 230    3/16/2016 18:43   3/16/2016 18:56  Business
# 231     3/17/2016 0:33    3/17/2016 0:44  Personal
# 232    3/17/2016 12:52   3/17/2016 15:11  Business
# 233    3/17/2016 15:16   3/17/2016 15:58  Business
# 234    3/17/2016 17:20   3/17/2016 18:02  Business
# 235    3/17/2016 18:47   3/17/2016 19:09  Personal
# 236    3/17/2016 20:57   3/17/2016 21:28  Personal
# 237    3/17/2016 21:48   3/17/2016 22:04  Personal
# 238     3/18/2016 7:15    3/18/2016 7:21  Business
# 239     3/18/2016 8:35    3/18/2016 8:43  Business
# 240    3/18/2016 18:24   3/18/2016 19:08  Business
# 241    3/18/2016 19:23   3/18/2016 19:29  Business
# 242    3/18/2016 21:01   3/18/2016 21:15  Business
# 243     3/19/2016 9:10    3/19/2016 9:25  Business
# 244    3/19/2016 12:50   3/19/2016 13:13  Business
# 245    3/19/2016 14:01   3/19/2016 14:57  Business
# 246    3/19/2016 15:34   3/19/2016 16:38  Business
# 247    3/19/2016 17:17   3/19/2016 17:32  Business
# 248    3/19/2016 17:37   3/19/2016 17:47  Business
# 249    3/19/2016 17:52   3/19/2016 18:00  Business
# 250    3/19/2016 18:53   3/19/2016 19:29  Business
# 251    3/19/2016 19:33   3/19/2016 20:39  Business
# 252     3/20/2016 7:37    3/20/2016 7:48  Business
# 253    3/20/2016 11:42   3/20/2016 11:56  Business
# 254    3/20/2016 17:08   3/20/2016 17:34  Business
# 255    3/20/2016 18:34   3/20/2016 18:40  Personal
# 256    3/20/2016 18:45   3/20/2016 19:06  Business
# 257    3/21/2016 10:21   3/21/2016 10:26  Personal
# 258    3/21/2016 16:05   3/21/2016 16:13  Business
# 259    3/21/2016 18:59   3/21/2016 19:15  Business
# 260    3/21/2016 20:18   3/21/2016 20:55  Business
# 261     3/22/2016 6:17    3/22/2016 6:43  Business
# 262    3/22/2016 12:06   3/22/2016 12:24  Personal
# 263    3/22/2016 19:12   3/22/2016 19:25  Personal
# 264    3/23/2016 14:37   3/23/2016 14:42  Personal
# 265    3/23/2016 14:53   3/23/2016 14:59  Personal
# 266    3/24/2016 19:47   3/24/2016 19:54  Personal
# 267    3/24/2016 20:34   3/24/2016 20:40  Business
# 268    3/25/2016 13:24   3/25/2016 16:22  Business
# 269    3/25/2016 16:52   3/25/2016 22:22  Business
# 270    3/25/2016 22:54    3/26/2016 1:39  Business
# 271    3/26/2016 14:05   3/26/2016 14:29  Personal
# 272    3/26/2016 15:19   3/26/2016 15:49  Personal
# 273    3/26/2016 16:26   3/26/2016 16:30  Personal
# 274     3/27/2016 0:31    3/27/2016 0:40  Business
# 275     3/27/2016 1:11    3/27/2016 1:23  Business
# 276    3/27/2016 15:31   3/27/2016 15:56  Business
# 277    3/27/2016 21:26   3/27/2016 21:41  Personal
# 278    3/27/2016 23:04   3/27/2016 23:18  Personal
# 279    3/28/2016 12:29   3/28/2016 12:42  Personal
# 280    3/28/2016 19:30   3/28/2016 20:23  Personal
# 281    3/28/2016 22:55   3/28/2016 23:26  Personal
# 282    3/29/2016 15:27   3/29/2016 16:11  Personal
# 283    3/29/2016 18:20   3/29/2016 18:39  Personal
# 284    3/29/2016 20:29   3/29/2016 20:44  Personal
# 285    3/29/2016 23:04   3/29/2016 23:21  Personal
# 286    3/30/2016 22:05   3/30/2016 22:55  Business
# 287    3/31/2016 12:47   3/31/2016 13:22  Business
# 288    3/31/2016 14:37   3/31/2016 15:09  Business
# 289     4/1/2016 13:43    4/1/2016 14:01  Business
# 290     4/1/2016 14:36    4/1/2016 15:24  Business
# 291     4/1/2016 16:01    4/1/2016 16:49  Business
# 292     4/1/2016 16:52    4/1/2016 16:57  Personal
# 293      4/2/2016 8:48     4/2/2016 9:04  Personal
# 294     4/2/2016 11:01    4/2/2016 11:16  Personal
# 295     4/2/2016 12:21    4/2/2016 14:47  Business
# 296     4/2/2016 16:57    4/2/2016 18:09  Business
# 297     4/2/2016 19:38    4/2/2016 22:36  Business
# 298     4/2/2016 23:11     4/3/2016 1:34  Business
# 299      4/3/2016 2:00     4/3/2016 4:16  Business
# 300     4/5/2016 21:39    4/5/2016 21:55  Business
# 301      4/6/2016 0:19     4/6/2016 0:39  Business
# 302     4/7/2016 18:20    4/7/2016 18:39  Business
# 303     4/7/2016 19:45    4/7/2016 20:00  Business
# 304     4/8/2016 12:30    4/8/2016 12:48  Business
# 305     4/8/2016 13:34    4/8/2016 13:51  Business
# 306     4/8/2016 13:55    4/8/2016 14:03  Business
# 307     4/8/2016 14:43    4/8/2016 15:20  Business
# 308     4/8/2016 16:05    4/8/2016 16:47  Business
# 309     4/12/2016 9:15    4/12/2016 9:26  Business
# 310     4/12/2016 9:34    4/12/2016 9:53  Business
# 311    4/12/2016 10:58   4/12/2016 11:18  Business
# 312    4/12/2016 12:22   4/12/2016 12:44  Business
# 313    4/12/2016 13:42   4/12/2016 14:01  Business
# 314     4/14/2016 7:29    4/14/2016 8:09  Business
# 315    4/14/2016 16:00   4/14/2016 16:43  Business
# 316    4/15/2016 11:36   4/15/2016 12:07  Business
# 317    4/15/2016 12:29   4/15/2016 12:32  Business
# 318    4/15/2016 14:31   4/15/2016 15:01  Business
# 319    4/16/2016 12:59   4/16/2016 13:17  Business
# 320    4/16/2016 15:10   4/16/2016 15:26  Business
# 321    4/19/2016 17:44   4/19/2016 18:08  Business
# 322    4/19/2016 19:57   4/19/2016 20:19  Business
# 323     4/22/2016 8:25    4/22/2016 9:04  Business
# 324    4/22/2016 10:10   4/22/2016 10:40  Business
# 325    4/22/2016 12:08   4/22/2016 12:28  Business
# 326    4/22/2016 13:02   4/22/2016 13:26  Business
# 327    4/23/2016 17:03   4/23/2016 17:16  Business
# 328    4/23/2016 18:49   4/23/2016 19:05  Business
# 329    4/24/2016 19:07   4/24/2016 19:16  Business
# 330    4/24/2016 19:46   4/24/2016 19:52  Business
# 331    4/24/2016 21:41   4/24/2016 21:50  Business
# 332    4/27/2016 13:30   4/27/2016 13:40  Business
# 333    4/27/2016 14:13   4/27/2016 14:25  Business
# 334    4/28/2016 12:09   4/28/2016 12:34  Business
# 335    4/28/2016 13:30   4/28/2016 13:49  Business
# 336    4/28/2016 22:10   4/28/2016 22:28  Business
# 337    4/29/2016 11:44   4/29/2016 12:01  Business
# 338    4/29/2016 13:13   4/29/2016 13:34  Business
# 339    4/29/2016 18:46   4/29/2016 19:18  Business
# 340    4/29/2016 22:44   4/29/2016 23:19  Business
# 341    4/30/2016 18:42   4/30/2016 18:57  Business
# 342    4/30/2016 22:16   4/30/2016 22:34  Business
# 343     5/1/2016 13:45    5/1/2016 13:53  Business
# 344     5/1/2016 14:26    5/1/2016 14:31  Business
# 345     5/1/2016 17:33    5/1/2016 17:45  Business
# 346     5/1/2016 17:54    5/1/2016 18:10  Business
# 347     5/1/2016 22:38    5/1/2016 22:49  Business
# 348     5/2/2016 14:14    5/2/2016 14:21  Business
# 349     5/2/2016 15:37    5/2/2016 15:48  Business
# 350     5/3/2016 22:20    5/3/2016 22:28  Business
# 351     5/4/2016 15:16    5/4/2016 15:37  Business
# 352     5/4/2016 20:55    5/4/2016 21:14  Business
# 353     5/4/2016 21:30    5/4/2016 21:36  Business
# 354     5/4/2016 22:19    5/4/2016 22:27  Business
# 355     5/5/2016 21:24    5/5/2016 21:36  Business
# 356     5/5/2016 22:34    5/5/2016 22:40  Business
# 357     5/5/2016 23:55     5/6/2016 0:08  Business
# 358      5/6/2016 5:47     5/6/2016 6:02  Business
# 359     5/6/2016 16:45    5/6/2016 16:59  Business
# 360     5/6/2016 17:18    5/6/2016 17:44  Business
# 361      5/9/2016 6:08     5/9/2016 6:25  Business
# 362     5/9/2016 14:39    5/9/2016 15:06  Business
# 363     5/9/2016 17:58    5/9/2016 18:26  Business
# 364     5/9/2016 19:35    5/9/2016 19:59  Business
# 365     5/10/2016 9:03    5/10/2016 9:20  Business
# 366    5/10/2016 17:19   5/10/2016 17:31  Business
# 367     5/11/2016 8:35    5/11/2016 9:12  Business
# 368    5/11/2016 21:47   5/11/2016 22:04  Business
# 369    5/14/2016 18:35   5/14/2016 18:39  Business
# 370    5/14/2016 23:01   5/14/2016 23:05  Business
# 371    5/17/2016 13:15   5/17/2016 13:23  Business
# 372    5/17/2016 13:56   5/17/2016 14:08  Business
# 373    5/17/2016 14:34   5/17/2016 14:40  Business
# 374     5/18/2016 9:11    5/18/2016 9:41  Business
# 375    5/18/2016 13:00   5/18/2016 13:02  Business
# 376    5/19/2016 14:37   5/19/2016 15:01  Business
# 377    5/20/2016 10:56   5/20/2016 11:07  Business
# 378    5/20/2016 15:43   5/20/2016 16:12  Business
# 379    5/22/2016 15:39   5/22/2016 15:46  Business
# 380    5/22/2016 18:46   5/22/2016 18:53  Business
# 381    5/23/2016 20:19   5/23/2016 20:27  Business
# 382    5/23/2016 21:09   5/23/2016 21:21  Business
# 383    5/27/2016 20:26   5/27/2016 20:30  Business
# 384    5/27/2016 20:47   5/27/2016 20:53  Business
# 385    5/27/2016 22:11   5/27/2016 22:14  Business
# 386     5/28/2016 0:15    5/28/2016 0:21  Business
# 387    5/28/2016 12:52   5/28/2016 13:06  Business
# 388    5/28/2016 14:35   5/28/2016 15:04  Business
# 389    5/31/2016 13:54   5/31/2016 14:41  Business
# 390    5/31/2016 16:02   5/31/2016 16:39  Business
# 391    5/31/2016 17:50   5/31/2016 17:59  Business
# 392     6/1/2016 10:19    6/1/2016 10:47  Business
# 393     6/1/2016 13:10    6/1/2016 13:39  Business
# 394     6/3/2016 11:29    6/3/2016 11:49  Business
# 395     6/3/2016 13:08    6/3/2016 13:38  Business
# 396     6/3/2016 15:31    6/3/2016 15:54  Business
# 397     6/3/2016 18:14    6/3/2016 18:29  Business
# 398     6/3/2016 18:41    6/3/2016 18:53  Business
# 399     6/3/2016 19:36    6/3/2016 19:42  Business
# 400     6/3/2016 22:47    6/3/2016 23:06  Business
# 401     6/5/2016 14:03    6/5/2016 14:33  Business
# 402     6/5/2016 15:06    6/5/2016 15:22  Business
# 403     6/5/2016 15:57    6/5/2016 16:08  Business
# 404     6/5/2016 18:05    6/5/2016 18:14  Business
# 405     6/5/2016 21:53    6/5/2016 22:05  Business
# 406     6/5/2016 23:52     6/6/2016 0:08  Business
# 407     6/6/2016 15:36    6/6/2016 15:45  Business
# 408     6/6/2016 16:16    6/6/2016 16:24  Business
# 409     6/6/2016 20:06    6/6/2016 20:20  Business
# 410     6/6/2016 21:08    6/6/2016 21:37  Business
# 411     6/6/2016 21:41    6/6/2016 22:00  Business
# 412     6/6/2016 23:34    6/6/2016 23:48  Business
# 413     6/7/2016 21:42    6/7/2016 22:00  Business
# 414     6/7/2016 23:41     6/8/2016 0:04  Business
# 415      6/8/2016 8:23     6/8/2016 8:53  Business
# 416     6/8/2016 12:04    6/8/2016 13:01  Business
# 417     6/8/2016 13:12    6/8/2016 13:29  Business
# 418     6/8/2016 14:31    6/8/2016 14:37  Business
# 419     6/8/2016 16:55    6/8/2016 17:11  Business
# 420     6/8/2016 17:16    6/8/2016 17:18  Business
# 421     6/8/2016 17:59    6/8/2016 18:05  Business
# 422     6/8/2016 20:11    6/8/2016 20:25  Business
# 423    6/10/2016 15:19   6/10/2016 16:28  Business
# 424    6/10/2016 21:47   6/10/2016 22:04  Business
# 425    6/10/2016 23:53    6/11/2016 0:01  Business
# 426    6/11/2016 17:08   6/11/2016 17:16  Business
# 427    6/11/2016 17:34   6/11/2016 17:39  Business
# 428    6/11/2016 17:50   6/11/2016 17:56  Business
# 429    6/11/2016 21:45   6/11/2016 22:04  Business
# 430    6/11/2016 23:39    6/12/2016 0:05  Business
# 431    6/12/2016 19:53   6/12/2016 19:56  Business
# 432    6/12/2016 20:05   6/12/2016 20:16  Business
# 433    6/12/2016 21:58   6/12/2016 22:19  Business
# 434     6/13/2016 5:23    6/13/2016 5:42  Business
# 435    6/13/2016 14:17   6/13/2016 14:46  Business
# 436    6/13/2016 18:08   6/13/2016 18:47  Business
# 437    6/13/2016 18:54   6/13/2016 19:23  Business
# 438    6/13/2016 20:00   6/13/2016 20:05  Business
# 439    6/14/2016 12:03   6/14/2016 12:21  Business
# 440    6/14/2016 16:09   6/14/2016 16:39  Business
# 441    6/14/2016 17:15   6/14/2016 17:24  Business
# 442    6/14/2016 17:27   6/14/2016 17:57  Business
# 443     6/15/2016 1:46    6/15/2016 2:06  Business
# 444    6/15/2016 15:26   6/15/2016 15:34  Business
# 445    6/15/2016 16:37   6/15/2016 17:02  Business
# 446    6/15/2016 17:29   6/15/2016 17:49  Personal
# 447    6/15/2016 19:52   6/15/2016 19:58  Business
# 448    6/16/2016 13:36   6/16/2016 14:30  Business
# 449    6/16/2016 14:42   6/16/2016 14:46  Business
# 450    6/16/2016 15:17   6/16/2016 15:41  Business
# 451    6/16/2016 19:39   6/16/2016 19:56  Business
# 452    6/16/2016 21:43   6/16/2016 21:56  Business
# 453    6/17/2016 16:11   6/17/2016 16:44  Business
# 454     6/18/2016 0:29    6/18/2016 0:51  Business
# 455     6/19/2016 2:39    6/19/2016 2:50  Business
# 456     6/19/2016 5:51    6/19/2016 6:00  Business
# 457    6/21/2016 15:39   6/21/2016 16:08  Business
# 458    6/21/2016 17:11   6/21/2016 18:02  Business
# 459    6/24/2016 10:41   6/24/2016 10:57  Business
# 460    6/24/2016 11:54   6/24/2016 12:01  Business
# 461    6/24/2016 12:19   6/24/2016 12:37  Business
# 462    6/24/2016 12:50   6/24/2016 13:12  Business
# 463    6/24/2016 13:18   6/24/2016 13:27  Business
# 464    6/24/2016 14:01   6/24/2016 14:20  Business
# 465    6/24/2016 20:44   6/24/2016 21:02  Business
# 466     6/25/2016 9:03    6/25/2016 9:12  Business
# 467     6/25/2016 9:15   6/25/2016 10:08  Business
# 468    6/25/2016 10:18   6/25/2016 10:25  Business
# 469    6/25/2016 10:50   6/25/2016 11:18  Business
# 470    6/25/2016 11:25   6/25/2016 11:34  Business
# 471    6/25/2016 11:53   6/25/2016 13:21  Business
# 472    6/25/2016 19:47   6/25/2016 19:58  Business
# 473    6/25/2016 23:19   6/25/2016 23:26  Business
# 474    6/26/2016 17:43   6/26/2016 18:18  Business
# 475    6/26/2016 18:45   6/26/2016 19:12  Business
# 476    6/26/2016 19:41   6/26/2016 19:50  Business
# 477    6/26/2016 21:14   6/26/2016 21:42  Business
# 478     6/27/2016 7:37    6/27/2016 8:48  Business
# 479     6/27/2016 8:51    6/27/2016 9:00  Business
# 480     6/27/2016 9:05    6/27/2016 9:33  Business
# 481     6/27/2016 9:43   6/27/2016 10:08  Business
# 482    6/27/2016 10:22   6/27/2016 10:39  Business
# 483    6/27/2016 10:51   6/27/2016 10:58  Business
# 484    6/27/2016 11:06   6/27/2016 11:24  Business
# 485    6/27/2016 11:30   6/27/2016 11:42  Business
# 486    6/27/2016 12:22   6/27/2016 13:02  Business
# 487    6/27/2016 13:56   6/27/2016 14:05  Business
# 488    6/27/2016 21:09   6/27/2016 21:19  Business
# 489     6/28/2016 0:48    6/28/2016 1:05  Business
# 490    6/28/2016 20:13   6/28/2016 20:33  Business
# 491    6/28/2016 23:34   6/28/2016 23:59  Business
# 492    6/28/2016 23:34   6/28/2016 23:59  Business
# 493     6/29/2016 8:56    6/29/2016 9:24  Business
# 494    6/29/2016 10:22   6/29/2016 10:38  Business
# 495    6/29/2016 11:49   6/29/2016 11:51  Business
# 496    6/29/2016 12:11   6/29/2016 12:16  Business
# 497    6/29/2016 20:11   6/29/2016 20:29  Business
# 498    6/29/2016 23:38    6/30/2016 0:00  Business
# 499    6/30/2016 20:09   6/30/2016 20:26  Business
# 500      7/1/2016 0:00     7/1/2016 0:25  Business
# 501      7/1/2016 9:34     7/1/2016 9:57  Business
# 502     7/1/2016 12:36    7/1/2016 13:00  Business
# 503     7/1/2016 20:06    7/1/2016 20:24  Business
# 504     7/1/2016 23:48     7/2/2016 0:09  Business
# 505     7/2/2016 20:18    7/2/2016 20:36  Business
# 506     7/2/2016 23:48     7/3/2016 0:12  Business
# 507      7/3/2016 0:28     7/3/2016 0:38  Business
# 508      7/3/2016 3:02     7/3/2016 3:08  Business
# 509     7/3/2016 20:00    7/3/2016 20:18  Business
# 510      7/4/2016 0:32     7/4/2016 0:47  Business
# 511     7/4/2016 17:31    7/4/2016 17:49  Business
# 512     7/4/2016 18:23    7/4/2016 18:49  Business
# 513     7/4/2016 20:00    7/4/2016 20:17  Business
# 514      7/5/2016 0:00     7/5/2016 0:05  Business
# 515      7/5/2016 0:08     7/5/2016 0:28  Business
# 516     7/5/2016 16:48    7/5/2016 16:52  Business
# 517     7/5/2016 20:06    7/5/2016 20:26  Business
# 518     7/5/2016 22:41    7/5/2016 23:02  Business
# 519      7/6/2016 0:33     7/6/2016 0:53  Business
# 520      7/6/2016 9:06     7/6/2016 9:25  Business
# 521     7/6/2016 12:48    7/6/2016 13:08  Business
# 522     7/6/2016 20:04    7/6/2016 20:14  Business
# 523     7/6/2016 23:46    7/6/2016 23:59  Business
# 524      7/7/2016 8:22     7/7/2016 8:50  Business
# 525     7/7/2016 10:27    7/7/2016 10:33  Business
# 526     7/7/2016 12:59    7/7/2016 13:35  Business
# 527      7/8/2016 9:50    7/8/2016 10:13  Business
# 528     7/8/2016 10:51    7/8/2016 11:12  Business
# 529     7/8/2016 13:48    7/8/2016 14:11  Business
# 530     7/8/2016 17:11    7/8/2016 17:30  Business
# 531      7/9/2016 9:03     7/9/2016 9:46  Business
# 532      7/9/2016 9:52    7/9/2016 10:06  Business
# 533     7/9/2016 10:15    7/9/2016 10:33  Business
# 534    7/10/2016 14:10   7/10/2016 14:17  Business
# 535    7/10/2016 16:04   7/10/2016 16:15  Business
# 536    7/10/2016 18:05   7/10/2016 18:21  Business
# 537    7/10/2016 19:51   7/10/2016 20:08  Business
# 538    7/12/2016 16:10   7/12/2016 16:45  Business
# 539    7/12/2016 19:21   7/12/2016 19:26  Personal
# 540    7/12/2016 23:47    7/13/2016 0:11  Personal
# 541    7/13/2016 12:39   7/13/2016 13:20  Personal
# 542    7/13/2016 13:25   7/13/2016 13:39  Personal
# 543    7/13/2016 13:42   7/13/2016 13:54  Personal
# 544    7/14/2016 15:51   7/14/2016 15:59  Personal
# 545    7/14/2016 16:03   7/14/2016 16:34  Business
# 546    7/14/2016 16:39   7/14/2016 20:05  Business
# 547    7/15/2016 11:32   7/15/2016 11:53  Personal
# 548    7/15/2016 12:09   7/15/2016 12:19  Personal
# 549    7/15/2016 12:35   7/15/2016 13:15  Personal
# 550    7/15/2016 15:03   7/15/2016 15:33  Personal
# 551    7/15/2016 15:40   7/15/2016 15:52  Personal
# 552    7/16/2016 13:14   7/16/2016 14:10  Personal
# 553    7/16/2016 14:14   7/16/2016 14:30  Personal
# 554    7/16/2016 15:29   7/16/2016 16:57  Personal
# 555    7/16/2016 19:42   7/16/2016 20:35  Personal
# 556    7/16/2016 21:45   7/16/2016 22:18  Personal
# 557    7/16/2016 22:50   7/16/2016 23:03  Business
# 558    7/17/2016 11:23   7/17/2016 11:50  Personal
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal
# 560    7/18/2016 10:37   7/18/2016 10:49  Personal
# 561    7/18/2016 10:54   7/18/2016 11:15  Personal
# 562    7/18/2016 11:25   7/18/2016 11:36  Personal
# 563    7/18/2016 11:40   7/18/2016 11:56  Personal
# 564    7/18/2016 17:12   7/18/2016 17:33  Business
# 565    7/18/2016 18:32   7/18/2016 18:47  Business
# 566    7/18/2016 19:07   7/18/2016 19:14  Business
# 567    7/18/2016 20:28   7/18/2016 20:32  Business
# 568    7/18/2016 21:11   7/18/2016 21:19  Business
# 569    7/19/2016 10:35   7/19/2016 10:51  Business
# 570    7/19/2016 10:56   7/19/2016 11:11  Business
# 571    7/19/2016 11:30   7/19/2016 12:00  Business
# 572    7/19/2016 17:14   7/19/2016 17:24  Business
# 573    7/19/2016 17:50   7/19/2016 18:08  Personal
# 574    7/20/2016 17:12   7/20/2016 17:24  Personal
# 575    7/20/2016 17:50   7/20/2016 17:57  Personal
# 576    7/20/2016 18:16   7/20/2016 18:20  Personal
# 577    7/21/2016 17:17   7/21/2016 17:23  Business
# 578    7/21/2016 17:42   7/21/2016 17:51  Business
# 579    7/21/2016 18:27   7/21/2016 18:42  Business
# 580    7/21/2016 19:30   7/21/2016 19:39  Business
# 581    7/22/2016 10:42   7/22/2016 10:53  Business
# 582    7/22/2016 11:11   7/22/2016 11:25  Business
# 583    7/22/2016 11:37   7/22/2016 12:00  Business
# 584    7/22/2016 12:14   7/22/2016 12:31  Business
# 585    7/22/2016 13:21   7/22/2016 13:42  Business
# 586    7/22/2016 14:27   7/22/2016 14:43  Business
# 587    7/22/2016 15:49   7/22/2016 16:22  Business
# 588    7/22/2016 18:33   7/22/2016 18:51  Business
# 589    7/23/2016 14:27   7/23/2016 14:44  Business
# 590    7/23/2016 14:48   7/23/2016 15:12  Business
# 591    7/23/2016 15:15   7/23/2016 15:27  Business
# 592    7/23/2016 15:50   7/23/2016 16:10  Business
# 593    7/23/2016 20:17   7/23/2016 20:33  Business
# 594    7/23/2016 23:18   7/23/2016 23:43  Business
# 595    7/25/2016 10:35   7/25/2016 10:41  Business
# 596    7/25/2016 10:47   7/25/2016 10:58  Business
# 597    7/25/2016 11:04   7/25/2016 11:33  Business
# 598    7/25/2016 11:37   7/25/2016 11:44  Business
# 599    7/26/2016 15:43   7/26/2016 15:49  Business
# 600    7/26/2016 17:14   7/26/2016 17:24  Business
# 601    7/26/2016 20:52   7/26/2016 21:00  Business
# 602    7/26/2016 22:31   7/26/2016 22:39  Business
# 603    7/27/2016 19:08   7/27/2016 19:20  Business
# 604    7/27/2016 21:34   7/27/2016 21:57  Business
# 605    7/27/2016 22:00   7/27/2016 22:26  Business
# 606     7/28/2016 0:04    7/28/2016 0:09  Business
# 607    7/29/2016 15:45   7/29/2016 15:47  Business
# 608    7/29/2016 17:27   7/29/2016 17:45  Business
# 609    7/30/2016 17:02   7/30/2016 17:27  Business
# 610    7/30/2016 21:16   7/30/2016 21:41  Business
# 611    7/31/2016 17:30   7/31/2016 17:37  Business
# 612     8/1/2016 12:47    8/1/2016 13:04  Business
# 613     8/1/2016 13:08    8/1/2016 13:19  Business
# 614     8/1/2016 13:28    8/1/2016 13:46  Business
# 615     8/1/2016 13:52    8/1/2016 14:14  Business
# 616     8/1/2016 15:40    8/1/2016 15:47  Business
# 617     8/1/2016 16:18    8/1/2016 16:25  Business
# 618     8/1/2016 16:29    8/1/2016 16:59  Business
# 619     8/1/2016 17:23    8/1/2016 17:55  Business
# 620      8/2/2016 8:11     8/2/2016 8:32  Business
# 621     8/2/2016 11:51    8/2/2016 12:15  Business
# 622     8/2/2016 19:15    8/2/2016 19:23  Business
# 623     8/2/2016 21:23    8/2/2016 21:29  Business
# 624     8/3/2016 12:46    8/3/2016 13:00  Business
# 625     8/3/2016 14:59    8/3/2016 15:03  Business
# 626     8/3/2016 16:00    8/3/2016 16:04  Business
# 627     8/5/2016 17:23    8/5/2016 17:30  Business
# 628     8/5/2016 18:17    8/5/2016 18:21  Business
# 629     8/5/2016 19:17    8/5/2016 19:27  Business
# 630      8/6/2016 6:40     8/6/2016 6:58  Business
# 631      8/6/2016 9:31     8/6/2016 9:53  Business
# 632     8/7/2016 17:14    8/7/2016 17:23  Business
# 633     8/7/2016 17:28    8/7/2016 17:43  Business
# 634     8/7/2016 18:17    8/7/2016 18:23  Business
# 635     8/7/2016 20:15    8/7/2016 20:23  Business
# 636     8/8/2016 16:17    8/8/2016 16:31  Business
# 637     8/8/2016 16:37    8/8/2016 16:50  Business
# 638     8/8/2016 17:02    8/8/2016 17:13  Business
# 639     8/8/2016 21:50    8/8/2016 22:15  Business
# 640     8/8/2016 23:28    8/8/2016 23:37  Business
# 641     8/9/2016 14:20    8/9/2016 14:38  Business
# 642     8/9/2016 15:15    8/9/2016 15:36  Business
# 643     8/9/2016 16:04    8/9/2016 16:37  Business
# 644    8/10/2016 16:56   8/10/2016 17:24  Business
# 645    8/10/2016 17:53   8/10/2016 18:28  Business
# 646    8/10/2016 18:49   8/10/2016 18:50  Business
# 647    8/10/2016 19:47   8/10/2016 20:02  Business
# 648    8/11/2016 12:53   8/11/2016 13:00  Business
# 649    8/11/2016 13:14   8/11/2016 13:28  Business
# 650    8/11/2016 13:32   8/11/2016 13:42  Business
# 651    8/11/2016 18:37   8/11/2016 19:29  Business
# 652    8/11/2016 20:59   8/11/2016 21:44  Business
# 653    8/12/2016 18:49   8/12/2016 18:52  Business
# 654    8/12/2016 18:56   8/12/2016 19:05  Business
# 655    8/13/2016 15:35   8/13/2016 15:58  Business
# 656     8/15/2016 9:05    8/15/2016 9:52  Business
# 657    8/15/2016 15:20   8/15/2016 15:47  Business
# 658    8/15/2016 16:52   8/15/2016 17:30  Business
# 659    8/15/2016 19:08   8/15/2016 20:30  Business
# 660     8/16/2016 7:58    8/16/2016 8:11  Business
# 661     8/16/2016 8:16    8/16/2016 8:23  Business
# 662     8/16/2016 8:46    8/16/2016 8:53  Business
# 663    8/16/2016 10:06   8/16/2016 10:27  Business
# 664    8/16/2016 10:31   8/16/2016 10:38  Business
# 665    8/16/2016 11:47   8/16/2016 12:03  Business
# 666    8/16/2016 15:13   8/16/2016 15:36  Business
# 667    8/17/2016 10:17   8/17/2016 10:41  Business
# 668    8/17/2016 10:57   8/17/2016 11:20  Business
# 669    8/17/2016 14:45   8/17/2016 14:50  Business
# 670    8/17/2016 15:32   8/17/2016 15:47  Business
# 671    8/17/2016 16:29   8/17/2016 16:50  Business
# 672    8/17/2016 16:54   8/17/2016 17:00  Business
# 673    8/17/2016 17:05   8/17/2016 17:34  Business
# 674    8/17/2016 18:38   8/17/2016 18:57  Business
# 675    8/18/2016 18:40   8/18/2016 19:07  Business
# 676     8/19/2016 8:24    8/19/2016 8:45  Business
# 677     8/19/2016 8:54    8/19/2016 9:07  Business
# 678     8/19/2016 9:27    8/19/2016 9:47  Business
# 679    8/19/2016 10:57   8/19/2016 11:06  Business
# 680    8/19/2016 12:07   8/19/2016 12:24  Business
# 681    8/19/2016 15:51   8/19/2016 16:06  Business
# 682    8/19/2016 17:12   8/19/2016 17:52  Business
# 683    8/21/2016 10:00   8/21/2016 10:29  Business
# 684    8/21/2016 14:05   8/21/2016 14:34  Business
# 685    8/21/2016 16:30   8/21/2016 17:02  Business
# 686    8/21/2016 18:10   8/21/2016 18:17  Business
# 687    8/21/2016 18:48   8/21/2016 19:24  Business
# 688    8/22/2016 10:00   8/22/2016 10:44  Business
# 689    8/22/2016 11:07   8/22/2016 11:23  Business
# 690    8/22/2016 12:36   8/22/2016 12:49  Business
# 691    8/22/2016 13:02   8/22/2016 13:11  Business
# 692    8/22/2016 14:07   8/22/2016 14:31  Business
# 693    8/22/2016 15:14   8/22/2016 15:49  Business
# 694    8/22/2016 15:59   8/22/2016 17:16  Business
# 695    8/22/2016 19:58   8/22/2016 20:50  Business
# 696    8/22/2016 20:53   8/22/2016 21:31  Business
# 697    8/22/2016 22:31   8/22/2016 23:00  Business
# 698     8/23/2016 8:10    8/23/2016 8:25  Business
# 699     8/23/2016 9:35   8/23/2016 10:09  Business
# 700    8/23/2016 12:59   8/23/2016 13:15  Business
# 701    8/23/2016 13:19   8/23/2016 13:30  Business
# 702    8/23/2016 13:49   8/23/2016 14:04  Business
# 703    8/23/2016 15:07   8/23/2016 15:12  Business
# 704    8/23/2016 15:15   8/23/2016 17:16  Business
# 705    8/23/2016 17:42   8/23/2016 18:31  Business
# 706    8/24/2016 12:05   8/24/2016 12:56  Business
# 707    8/24/2016 13:01   8/24/2016 15:25  Business
# 708    8/25/2016 15:17   8/25/2016 16:22  Business
# 709    8/25/2016 16:36   8/25/2016 16:56  Business
# 710    8/25/2016 17:19   8/25/2016 19:20  Business
# 711    8/25/2016 19:25   8/25/2016 19:57  Business
# 712    8/25/2016 22:58   8/25/2016 23:16  Business
# 713     8/26/2016 9:06    8/26/2016 9:20  Business
# 714    8/26/2016 11:14   8/26/2016 11:26  Business
# 715    8/26/2016 12:10   8/26/2016 12:20  Business
# 716    8/26/2016 14:10   8/26/2016 14:33  Business
# 717    8/26/2016 15:23   8/26/2016 15:35  Business
# 718    8/26/2016 15:59   8/26/2016 16:24  Business
# 719    8/26/2016 16:55   8/26/2016 17:12  Business
# 720    8/26/2016 18:42   8/26/2016 18:56  Business
# 721    8/26/2016 19:31   8/26/2016 19:54  Business
# 722    8/26/2016 20:06   8/26/2016 20:16  Business
# 723     8/27/2016 9:34   8/27/2016 10:11  Business
# 724    8/27/2016 11:47   8/27/2016 12:06  Business
# 725    8/27/2016 12:12   8/27/2016 12:17  Business
# 726    8/27/2016 14:01   8/27/2016 15:44  Business
# 727    8/27/2016 16:15   8/27/2016 19:13  Business
# 728     8/28/2016 9:57   8/28/2016 10:18  Business
# 729    8/28/2016 16:39   8/28/2016 16:55  Business
# 730    8/28/2016 17:37   8/28/2016 17:55  Business
# 731    8/28/2016 21:15   8/28/2016 21:59  Business
# 732    8/29/2016 12:02   8/29/2016 12:31  Business
# 733    8/29/2016 13:38   8/29/2016 13:48  Business
# 734    8/29/2016 14:31   8/29/2016 14:41  Business
# 735    8/29/2016 14:49   8/29/2016 15:04  Business
# 736    8/29/2016 15:49   8/29/2016 15:59  Business
# 737    8/29/2016 16:06   8/29/2016 16:21  Business
# 738    8/29/2016 17:24   8/29/2016 17:41  Business
# 739    8/29/2016 18:27   8/29/2016 18:36  Business
# 740    8/30/2016 11:53   8/30/2016 12:05  Business
# 741    8/30/2016 12:46   8/30/2016 13:09  Business
# 742    8/30/2016 13:25   8/30/2016 13:46  Business
# 743    8/30/2016 14:00   8/30/2016 14:20  Business
# 744    8/30/2016 17:27   8/30/2016 18:09  Business
# 745     9/1/2016 11:51    9/1/2016 12:24  Business
# 746     9/1/2016 17:21    9/1/2016 17:36  Business
# 747     9/1/2016 18:49    9/1/2016 19:08  Business
# 748     9/2/2016 11:37    9/2/2016 12:24  Business
# 749     9/2/2016 18:56    9/2/2016 19:37  Business
# 750     9/5/2016 10:25    9/5/2016 10:44  Business
# 751     9/6/2016 17:49    9/6/2016 17:49  Business
# 752    9/10/2016 10:28   9/10/2016 10:45  Business
# 753     9/11/2016 9:51    9/11/2016 9:55  Business
# 754    9/11/2016 21:40   9/11/2016 21:42  Business
# 755     9/12/2016 8:07    9/12/2016 8:12  Business
# 756    9/12/2016 11:15   9/12/2016 11:24  Business
# 757    9/12/2016 13:04   9/12/2016 13:44  Business
# 758    9/13/2016 16:56   9/13/2016 17:02  Business
# 759    9/14/2016 11:55   9/14/2016 11:59  Business
# 760    9/15/2016 20:33   9/15/2016 20:38  Business
# 761     9/16/2016 7:08    9/16/2016 7:08  Business
# 762    9/18/2016 18:07   9/18/2016 18:11  Business
# 763     9/19/2016 6:18    9/19/2016 6:49  Business
# 764    9/19/2016 14:40   9/19/2016 14:56  Business
# 765    9/19/2016 16:23   9/19/2016 16:31  Business
# 766    9/19/2016 17:36   9/19/2016 18:20  Business
# 767    9/19/2016 19:10   9/19/2016 19:49  Business
# 768    9/20/2016 11:29   9/20/2016 11:48  Business
# 769    9/20/2016 20:47   9/20/2016 22:47  Business
# 770    9/23/2016 13:15   9/23/2016 13:40  Business
# 771    9/24/2016 14:34   9/24/2016 15:15  Business
# 772    9/24/2016 20:29   9/24/2016 20:33  Business
# 773     9/27/2016 8:33    9/27/2016 8:35  Business
# 774    9/27/2016 13:21   9/27/2016 14:43  Business
# 775    9/27/2016 19:14   9/27/2016 20:34  Business
# 776    9/27/2016 21:01    9/28/2016 2:37  Business
# 777    9/28/2016 17:21   9/28/2016 19:36  Business
# 778    9/29/2016 16:13   9/29/2016 18:47  Business
# 779    9/30/2016 17:39   9/30/2016 20:20  Business
# 780    9/30/2016 20:59   9/30/2016 22:34  Business
# 781    10/3/2016 17:09   10/3/2016 17:12  Business
# 782    10/3/2016 18:17   10/3/2016 18:34  Business
# 783    10/3/2016 18:51   10/3/2016 19:01  Business
# 784    10/3/2016 22:04   10/3/2016 22:33  Business
# 785     10/4/2016 9:50   10/4/2016 10:52  Business
# 786    10/4/2016 12:17   10/4/2016 12:18  Business
# 787     10/6/2016 8:49   10/6/2016 11:36  Business
# 788    10/6/2016 17:23   10/6/2016 17:40  Business
# 789    10/6/2016 18:37   10/6/2016 18:39  Business
# 790    10/6/2016 19:46   10/6/2016 20:26  Business
# 791    10/7/2016 10:56   10/7/2016 10:59  Business
# 792    10/7/2016 11:27   10/7/2016 11:50  Business
# 793    10/7/2016 13:52   10/7/2016 14:08  Business
# 794    10/7/2016 14:29   10/7/2016 15:11  Business
# 795    10/7/2016 15:47   10/7/2016 16:02  Business
# 796    10/7/2016 18:08   10/7/2016 18:27  Business
# 797    10/7/2016 18:33   10/7/2016 19:01  Business
# 798    10/8/2016 15:03   10/8/2016 15:03  Business
# 799    10/8/2016 18:15   10/8/2016 18:18  Business
# 800    10/9/2016 14:04   10/9/2016 14:23  Business
# 801   10/10/2016 17:22  10/10/2016 17:28  Business
# 802   10/10/2016 17:33  10/10/2016 18:13  Business
# 803    10/11/2016 1:27   10/11/2016 2:08  Business
# 804   10/12/2016 19:18  10/12/2016 19:21  Business
# 805   10/13/2016 11:20  10/13/2016 11:58  Business
# 806   10/13/2016 12:08  10/13/2016 12:14  Business
# 807   10/13/2016 13:02  10/13/2016 13:02  Business
# 808   10/13/2016 13:37  10/13/2016 13:46  Business
# 809   10/13/2016 16:08  10/13/2016 16:53  Business
# 810    10/14/2016 8:50   10/14/2016 9:44  Business
# 811   10/14/2016 10:16  10/14/2016 10:52  Business
# 812   10/14/2016 15:56  10/14/2016 16:20  Business
# 813   10/14/2016 23:54   10/15/2016 2:06  Business
# 814   10/15/2016 22:28  10/15/2016 22:48  Business
# 815    10/16/2016 0:01   10/16/2016 0:14  Business
# 816   10/16/2016 12:52  10/16/2016 13:11  Business
# 817   10/16/2016 14:40  10/16/2016 15:01  Business
# 818   10/16/2016 15:10  10/16/2016 15:19  Business
# 819   10/16/2016 19:27  10/16/2016 19:33  Business
# 820   10/16/2016 20:30  10/16/2016 20:39  Business
# 821   10/16/2016 21:34  10/16/2016 21:41  Business
# 822   10/17/2016 15:19  10/17/2016 15:57  Business
# 823   10/17/2016 16:29  10/17/2016 17:11  Business
# 824   10/17/2016 18:02  10/17/2016 18:16  Business
# 825   10/17/2016 18:31  10/17/2016 18:45  Business
# 826   10/17/2016 19:08  10/17/2016 19:25  Business
# 827    10/18/2016 8:12   10/18/2016 8:22  Business
# 828    10/18/2016 8:53   10/18/2016 9:02  Business
# 829   10/18/2016 10:41  10/18/2016 11:09  Business
# 830   10/18/2016 18:12  10/18/2016 18:33  Business
# 831   10/18/2016 19:03  10/18/2016 19:13  Business
# 832   10/18/2016 20:31  10/18/2016 20:37  Business
# 833    10/19/2016 9:33   10/19/2016 9:47  Business
# 834    10/19/2016 9:54  10/19/2016 10:21  Business
# 835   10/19/2016 13:45  10/19/2016 13:56  Business
# 836   10/19/2016 14:02  10/19/2016 14:31  Business
# 837   10/19/2016 15:44  10/19/2016 16:02  Business
# 838   10/19/2016 16:06  10/19/2016 16:19  Business
# 839   10/19/2016 16:33  10/19/2016 17:01  Business
# 840   10/20/2016 11:26  10/20/2016 11:34  Business
# 841   10/20/2016 12:19  10/20/2016 13:17  Business
# 842   10/20/2016 20:44  10/20/2016 21:37  Business
# 843   10/21/2016 10:06  10/21/2016 10:21  Business
# 844    10/22/2016 0:54   10/22/2016 1:09  Business
# 845   10/22/2016 13:26  10/22/2016 14:03  Business
# 846   10/22/2016 17:08  10/22/2016 17:55  Business
# 847    10/23/2016 9:24  10/23/2016 10:05  Business
# 848   10/23/2016 12:17  10/23/2016 12:59  Business
# 849   10/23/2016 19:04  10/23/2016 19:14  Business
# 850   10/23/2016 21:10  10/23/2016 21:25  Business
# 851   10/24/2016 14:57  10/24/2016 15:26  Business
# 852   10/24/2016 15:33  10/24/2016 16:13  Business
# 853   10/24/2016 16:34  10/24/2016 16:41  Business
# 854   10/25/2016 13:27  10/25/2016 14:08  Business
# 855   10/25/2016 15:04  10/25/2016 15:11  Business
# 856   10/25/2016 15:16  10/25/2016 15:33  Business
# 857   10/25/2016 20:00  10/25/2016 20:11  Business
# 858   10/25/2016 20:54  10/25/2016 21:03  Business
# 859   10/25/2016 22:24  10/25/2016 22:45  Business
# 860   10/26/2016 19:25  10/26/2016 19:31  Business
# 861   10/26/2016 20:53  10/26/2016 21:03  Business
# 862   10/27/2016 18:51  10/27/2016 19:16  Business
# 863   10/27/2016 19:20  10/27/2016 19:35  Business
# 864   10/27/2016 19:52  10/27/2016 20:21  Business
# 865   10/27/2016 20:47  10/27/2016 20:54  Business
# 866   10/27/2016 21:26  10/27/2016 21:48  Business
# 867   10/28/2016 11:34  10/28/2016 11:52  Business
# 868   10/28/2016 13:06  10/28/2016 13:36  Business
# 869   10/28/2016 15:53  10/28/2016 17:59  Business
# 870   10/28/2016 18:13  10/28/2016 20:07  Business
# 871   10/28/2016 20:13  10/28/2016 22:00  Business
# 872   10/29/2016 15:22  10/29/2016 17:05  Business
# 873   10/29/2016 17:13  10/29/2016 19:19  Business
# 874    10/30/2016 7:49   10/30/2016 8:30  Business
# 875    10/30/2016 9:07  10/30/2016 10:09  Business
# 876   10/30/2016 10:11  10/30/2016 10:38  Business
# 877   10/30/2016 10:51  10/30/2016 11:21  Business
# 878   10/30/2016 12:24  10/30/2016 12:35  Business
# 879   10/30/2016 12:58  10/30/2016 13:18  Business
# 880   10/30/2016 13:24  10/30/2016 14:37  Business
# 881   10/30/2016 15:22  10/30/2016 18:23  Business
# 882   10/30/2016 18:26  10/30/2016 19:39  Business
# 883   10/31/2016 18:11  10/31/2016 18:20  Business
# 884   10/31/2016 18:47  10/31/2016 19:16  Business
# 885   10/31/2016 20:18  10/31/2016 20:44  Business
# 886   10/31/2016 21:45  10/31/2016 22:10  Business
# ...
# 490           Meeting
# 491           Meeting
# 492           Meeting
# 493               NaN
# 494               NaN
# 495               NaN
# 496               NaN
# 497           Meeting
# 498           Meeting
# 499           Meeting
# 500           Meeting
# 501           Meeting
# 502           Meeting
# 503           Meeting
# 504           Meeting
# 505           Meeting
# 506           Meeting
# 507   Errand/Supplies
# 508   Errand/Supplies
# 509           Meeting
# 510           Meeting
# 511           Meeting
# 512    Temporary Site
# 513           Meeting
# 514   Errand/Supplies
# 515           Meeting
# 516   Errand/Supplies
# 517               NaN
# 518               NaN
# 519    Meal/Entertain
# 520           Meeting
# 521               NaN
# 522    Meal/Entertain
# 523    Customer Visit
# 524    Temporary Site
# 525               NaN
# 526               NaN
# 527               NaN
# 528               NaN
# 529               NaN
# 530               NaN
# 531               NaN
# 532               NaN
# 533               NaN
# 534               NaN
# 535               NaN
# 536               NaN
# 537               NaN
# 538               NaN
# 539               NaN
# 540               NaN
# 541               NaN
# 542               NaN
# 543               NaN
# 544               NaN
# 545   Errand/Supplies
# 546               NaN
# 547               NaN
# 548               NaN
# 549               NaN
# 550               NaN
# 551               NaN
# 552               NaN
# 553               NaN
# 554               NaN
# 555               NaN
# 556               NaN
# 557   Errand/Supplies
# 558       Charity ($)
# 559           Commute
# 560            Moving
# 561            Moving
# 562            Moving
# 563            Moving
# 564           Meeting
# 565    Meal/Entertain
# 566    Meal/Entertain
# 567   Errand/Supplies
# 568    Meal/Entertain
# 569    Customer Visit
# 570           Meeting
# 571    Meal/Entertain
# 572   Errand/Supplies
# 573               NaN
# 574               NaN
# 575               NaN
# 576               NaN
# 577               NaN
# 578               NaN
# 579               NaN
# 580               NaN
# 581               NaN
# 582               NaN
# 583               NaN
# 584               NaN
# 585           Meeting
# 586    Meal/Entertain
# 587               NaN
# 588               NaN
# 589               NaN
# 590               NaN
# 591               NaN
# 592               NaN
# 593           Meeting
# 594           Meeting
# 595               NaN
# 596               NaN
# 597               NaN
# 598               NaN
# 599               NaN
# 600               NaN
# 601    Meal/Entertain
# 602    Meal/Entertain
# 603               NaN
# 604               NaN
# 605               NaN
# 606               NaN
# 607               NaN
# 608    Meal/Entertain
# 609               NaN
# 610               NaN
# 611               NaN
# 612               NaN
# 613               NaN
# 614               NaN
# 615               NaN
# 616               NaN
# 617               NaN
# 618               NaN
# 619               NaN
# 620           Meeting
# 621               NaN
# 622               NaN
# 623               NaN
# 624               NaN
# 625               NaN
# 626               NaN
# 627               NaN
# 628               NaN
# 629               NaN
# 630               NaN
# 631               NaN
# 632               NaN
# 633    Customer Visit
# 634               NaN
# 635    Meal/Entertain
# 636               NaN
# 637               NaN
# 638    Customer Visit
# 639               NaN
# 640    Customer Visit
# 641               NaN
# 642               NaN
# 643               NaN
# 644               NaN
# 645               NaN
# 646               NaN
# 647               NaN
# 648               NaN
# 649               NaN
# 650               NaN
# 651               NaN
# 652               NaN
# 653               NaN
# 654               NaN
# 655           Meeting
# 656               NaN
# 657               NaN
# 658               NaN
# 659    Temporary Site
# 660               NaN
# 661               NaN
# 662               NaN
# 663               NaN
# 664               NaN
# 665    Temporary Site
# 666               NaN
# 667               NaN
# 668               NaN
# 669               NaN
# 670               NaN
# 671               NaN
# 672               NaN
# 673               NaN
# 674    Temporary Site
# 675    Temporary Site
# 676               NaN
# 677               NaN
# 678               NaN
# 679               NaN
# 680               NaN
# 681               NaN
# 682               NaN
# 683    Airport/Travel
# 684               NaN
# 685               NaN
# 686               NaN
# 687               NaN
# 688               NaN
# 689               NaN
# 690               NaN
# 691               NaN
# 692               NaN
# 693               NaN
# 694               NaN
# 695               NaN
# 696               NaN
# 697               NaN
# 698               NaN
# 699               NaN
# 700               NaN
# 701               NaN
# 702               NaN
# 703               NaN
# 704               NaN
# 705               NaN
# 706               NaN
# 707               NaN
# 708               NaN
# 709               NaN
# 710               NaN
# 711               NaN
# 712               NaN
# 713               NaN
# 714               NaN
# 715               NaN
# 716               NaN
# 717               NaN
# 718               NaN
# 719               NaN
# 720               NaN
# 721               NaN
# 722               NaN
# 723               NaN
# 724               NaN
# 725               NaN
# 726               NaN
# 727               NaN
# 728               NaN
# 729               NaN
# 730               NaN
# 731               NaN
# 732               NaN
# 733               NaN
# 734               NaN
# 735    Temporary Site
# 736               NaN
# 737               NaN
# 738               NaN
# 739               NaN
# 740               NaN
# 741               NaN
# 742               NaN
# 743               NaN
# 744               NaN
# 745               NaN
# 746               NaN
# 747               NaN
# 748               NaN
# 749               NaN
# 750               NaN
# 751               NaN
# 752               NaN
# 753               NaN
# 754               NaN
# 755               NaN
# 756               NaN
# 757               NaN
# 758               NaN
# 759               NaN
# 760               NaN
# 761               NaN
# 762               NaN
# 763               NaN
# 764               NaN
# 765               NaN
# 766               NaN
# 767               NaN
# 768               NaN
# 769               NaN
# 770               NaN
# 771               NaN
# 772               NaN
# 773               NaN
# 774               NaN
# 775               NaN
# 776               NaN
# 777               NaN
# 778               NaN
# 779               NaN
# 780               NaN
# 781               NaN
# 782               NaN
# 783               NaN
# 784               NaN
# 785               NaN
# 786               NaN
# 787               NaN
# 788               NaN
# 789               NaN
# 790               NaN
# 791               NaN
# 792               NaN
# 793               NaN
# 794               NaN
# 795               NaN
# 796               NaN
# 797               NaN
# 798               NaN
# 799               NaN
# 800    Temporary Site
# 801               NaN
# 802               NaN
# 803           Meeting
# 804               NaN
# 805               NaN
# 806               NaN
# 807               NaN
# 808               NaN
# 809               NaN
# 810               NaN
# 811               NaN
# 812               NaN
# 813           Meeting
# 814               NaN
# 815               NaN
# 816           Meeting
# 817               NaN
# 818               NaN
# 819           Meeting
# 820               NaN
# 821    Meal/Entertain
# 822               NaN
# 823               NaN
# 824               NaN
# 825               NaN
# 826               NaN
# 827               NaN
# 828               NaN
# 829    Temporary Site
# 830               NaN
# 831               NaN
# 832               NaN
# 833               NaN
# 834               NaN
# 835               NaN
# 836               NaN
# 837               NaN
# 838               NaN
# 839               NaN
# 840               NaN
# 841               NaN
# 842               NaN
# 843               NaN
# 844               NaN
# 845               NaN
# 846               NaN
# 847               NaN
# 848               NaN
# 849    Meal/Entertain
# 850    Customer Visit
# 851               NaN
# 852               NaN
# 853               NaN
# 854               NaN
# 855               NaN
# 856               NaN
# 857    Meal/Entertain
# 858               NaN
# 859   Errand/Supplies
# 860           Meeting
# 861               NaN
# 862           Meeting
# 863               NaN
# 864               NaN
# 865               NaN
# 866               NaN
# 867           Meeting
# 868           Meeting
# 869           Meeting
# 870           Meeting
# 871           Meeting
# 872           Meeting
# 873               NaN
# 874               NaN
# 875               NaN
# 876               NaN
# 877               NaN
# 878               NaN
# 879               NaN
# 880               NaN
# 881               NaN
# 882               NaN
# 883               NaN
# 884               NaN
# 885               NaN
# 886   Errand/Supplies
# 887               NaN
# 888               NaN
# 889               NaN
# 890               NaN
# 891               NaN
# 892    Meal/Entertain
# 893               NaN
# 894               NaN
# 895           Meeting
# 896               NaN
# 897               NaN
# 898               NaN
# 899               NaN
# 900               NaN
# 901               NaN
# 902    Meal/Entertain
# 903    Customer Visit
# 904    Temporary Site
# 905               NaN
# 906               NaN
# 907               NaN
# 908               NaN
# 909               NaN
# 910               NaN
# 911               NaN
# 912           Meeting
# 913    Customer Visit
# 914               NaN
# 915               NaN
# 916   Between Offices
# 917   Between Offices
# 918   Between Offices
# 919           Meeting
# 920               NaN
# 921               NaN
# 922               NaN
# 923               NaN
# 924               NaN
# 925               NaN
# 926           Meeting
# 927    Customer Visit
# 928               NaN
# 929               NaN
# 930    Temporary Site
# 931               NaN
# 932               NaN
# 933    Temporary Site
# 934           Meeting
# 935               NaN
# 936    Customer Visit
# 937               NaN
# 938               NaN
# 939    Customer Visit
# 940               NaN
# 941               NaN
# 942               NaN
# 943               NaN
# 944               NaN
# 945               NaN
# 946           Meeting
# 947               NaN
# 948               NaN
# 949   Errand/Supplies
# 950               NaN
# 951               NaN
# 952               NaN
# 953               NaN
# 954           Meeting
# 955               NaN
# 956               NaN
# 957               NaN
# 958               NaN
# 959               NaN
# 960    Customer Visit
# 961    Customer Visit
# 962               NaN
# 963   Errand/Supplies
# 964               NaN
# 965    Temporary Site
# 966    Temporary Site
# 967    Temporary Site
# 968    Meal/Entertain
# 969    Customer Visit
# 970    Meal/Entertain
# 971    Meal/Entertain
# 972           Meeting
# 973           Meeting
# 974           Meeting
# 975               NaN
# 976               NaN
# 977   Errand/Supplies
# 978    Customer Visit
# 979   Between Offices
# 980    Customer Visit
# 981           Meeting
# 982   Errand/Supplies
# 983    Meal/Entertain
# 984    Meal/Entertain
# 985   Errand/Supplies
# 986    Meal/Entertain
# 987   Errand/Supplies
# 988           Meeting
# 989           Meeting
# 990    Customer Visit
# 991    Meal/Entertain
# 992    Customer Visit
# 993    Meal/Entertain
# 994               NaN
# 995               NaN
# 996               NaN
# 997           Meeting
# 998           Meeting
# 999               NaN
# 1000          Meeting
# 1001          Meeting
# 1002  Between Offices
# 1003  Errand/Supplies
# 1004   Meal/Entertain
# 1005              NaN
# 1006   Customer Visit
# 1007   Temporary Site
# 1008              NaN
# 1009          Meeting
# 1010  Errand/Supplies
# 1011   Meal/Entertain
# 1012   Customer Visit
# 1013   Meal/Entertain
# 1014   Customer Visit
# 1015   Meal/Entertain
# 1016   Customer Visit
# 1017  Errand/Supplies
# 1018              NaN
# 1019   Customer Visit
# 1020   Meal/Entertain
# 1021   Customer Visit
# 1022              NaN
# 1023   Meal/Entertain
# 1024          Meeting
# 1025          Meeting
# 1026   Customer Visit
# 1027   Meal/Entertain
# 1028  Errand/Supplies
# 1029  Errand/Supplies
# 1030          Meeting
# 1031  Errand/Supplies
# 1032  Errand/Supplies
# 1033   Temporary Site
# 1034          Meeting
# 1035   Customer Visit
# 1036          Meeting
# 1037  Errand/Supplies
# 1038   Meal/Entertain
# 1039   Customer Visit
# 1040   Meal/Entertain
# 1041  Errand/Supplies
# 1042  Errand/Supplies
# 1043  Errand/Supplies
# 1044   Meal/Entertain
# 1045   Customer Visit
# 1046   Meal/Entertain
# 1047   Customer Visit
# 1048  Errand/Supplies
# 1049   Meal/Entertain
# 1050              NaN
# 1051              NaN
# 1052   Meal/Entertain
# 1053   Customer Visit
# 1054          Meeting
# 1055   Airport/Travel
# 1056   Temporary Site
# 1057  Errand/Supplies
# 1058  Errand/Supplies
# 1059              NaN
# 1060  Errand/Supplies
# 1061   Temporary Site
# 1062  Errand/Supplies
# 1063              NaN
# 1064              NaN
# 1065              NaN
# 1066              NaN
# 1067   Customer Visit
# 1068   Customer Visit
# 1069              NaN
# 1070          Meeting
# 1071              NaN
# 1072  Errand/Supplies
# 1073          Meeting
# 1074  Errand/Supplies
# 1075   Temporary Site
# 1076  Errand/Supplies
# 1077  Errand/Supplies
# 1078   Customer Visit
# 1079          Meeting
# 1080  Errand/Supplies
# 1081   Meal/Entertain
# 1082          Meeting
# 1083  Errand/Supplies
# 1084  Errand/Supplies
# 1085          Meeting
# 1086   Customer Visit
# 1087          Meeting
# 1088          Meeting
# 1089          Meeting
# 1090   Customer Visit
# 1091          Meeting
# 1092          Meeting
# 1093  Errand/Supplies
# 1094   Temporary Site
# 1095          Meeting
# 1096   Meal/Entertain
# 1097   Customer Visit
# 1098          Meeting
# 1099          Meeting
# 1100          Meeting
# 1101  Errand/Supplies
# 1102   Meal/Entertain
# 1103   Meal/Entertain
# 1104   Meal/Entertain
# 1105   Meal/Entertain
# 1106  Errand/Supplies
# 1107  Errand/Supplies
# 1108  Errand/Supplies
# 1109   Meal/Entertain
# 1110  Errand/Supplies
# 1111  Errand/Supplies
# 1112   Meal/Entertain
# 1113   Meal/Entertain
# 1114   Meal/Entertain
# 1115   Customer Visit
# 1116   Customer Visit
# 1117   Customer Visit
# 1118          Meeting
# 1119   Temporary Site
# 1120   Meal/Entertain
# 1121   Meal/Entertain
# 1122   Customer Visit
# 1123          Meeting
# 1124   Customer Visit
# 1125   Meal/Entertain
# 1126  Errand/Supplies
# 1127  Errand/Supplies
# 1128   Meal/Entertain
# 1129  Errand/Supplies
# 1130  Errand/Supplies
# 1131  Errand/Supplies
# 1132  Errand/Supplies
# 1133   Meal/Entertain
# 1134   Meal/Entertain
# 1135  Errand/Supplies
# 1136  Errand/Supplies
# 1137   Airport/Travel
# 1138  Between Offices
# 1139  Errand/Supplies
# 1140   Meal/Entertain
# 1141   Customer Visit
# 1142          Meeting
# 1143              NaN
# 1144          Meeting
# 1145  Errand/Supplies
# 1146  Errand/Supplies
# 1147  Errand/Supplies
# 1148          Meeting
# 1149   Customer Visit
# 1150          Meeting
# 1151   Temporary Site
# 1152          Meeting
# 1153   Temporary Site
# 1154   Temporary Site
# 1155              NaN

# %% [markdown]
# ---

# %% [markdown]
# #####  Data Summarization
#   - Useful for getting a profile of our data
#   - Its a good practice to understand our data before diving deep into analysis
#   - saves time in terms of identifying the data gaps
#   - allows us to look at the measures of central tendency as as well as distribution of data (functions like describe)
#   - helps in doing higher level of univariate analysis using functions like value_counts(), unique(),nunique() etc

# %%
### display the top 5 records of a dataframe
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
### to customize your top records - top 10 rows
df.head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain
# 6       Palm Beach     7.1          Meeting
# 7             Cary     0.8          Meeting
# 8      Morrisville     8.3          Meeting
# 9         New York    16.5   Customer Visit

# %%
### to get bottom 10 records
df.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Kar?chi      2.9  Errand/Supplies
# 1147           Kar?chi      4.6  Errand/Supplies
# 1148           Kar?chi      4.6          Meeting
# 1149           Kar?chi      0.8   Customer Visit
# 1150           Kar?chi      0.7          Meeting
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN

# %%
### display the bottom 5 records of a dataframe
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
### to return a random sample of records from a dataframe
### df2= df.sample(n=100000,replace=True)

# %%
### to get information about the dataframe
### no of rows or observation 
### no of columns or features
### type of each column or feature - whether its a python object or a int or float
### how many missing or null values are there in each column ==> total no of rows-no of non null values in each column or missing valeus
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
### to know the column names of dataframe
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
### Shape of data frame
df.shape
# Out:
# (1156, 7)

# %%
### size of dataframe # a multiple of rows and columns
df.size
# Out:
# 8092

# %%
### length of dataframe will give the number of rows
len(df)
# Out:
# 1156

# %%
### datatypes of columns in a dataframe
### quantitative data - int or float  - numerical or continuous numerical
### qualitative data - every other data  - categorical (gender, string)
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# ###### convert data to datetime format #### check this out
# #pd.to_datetime(df["START_DATE*"],format='%m/%d/%Y %H:%M')
#
# ###### Available time formats: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %% [markdown]
# ### Dataset summarization methods

# %%
### by default will give summary statistics for numeric /quantitative variables only 
### uni variate analysis
### methods of central tendency
### methods of dispersion (distribution)
df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df.describe(include="all")  ### will give summary statistics for all variables - 5 Point Summary

### NaN is missing values
### for quantitative all summary stats are shown
### for categorical only top,freq unique values are shown
### missing values are reported too
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# count       653
# unique       10
# top     Meeting
# freq        187
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ## interpretation of describe
#
# ###### For Categorical Columns
#     -top - gives the top occuring value in a given categorical column
#     -freq  gives the frequency of times that a particular value occurs (example here "cary" occurs 201 times as start point
#      -unique = gives the unique occurrence the column
#
# - mean - mean value of the column
# - min - min value of column
# - std - standard deviation of column
# - 25% - 25th percentile - Lower Quartile - 25% of the data falls below this level
# - 50% - middile quartile - middle 50% of the data points
# - 75% - Upper quartlie - 75% of data points falls below this level
#
#
# - Inter-quartile range
#  The range of scores from lower to upper quartile is -referred to as the inter-quartile range. The middle 50% of scores fall within the inter-quartile range.

# %% [markdown]
# ### Box Plot Interpretation
#
# <a href='https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots'> <img src='../W@S_boxplot-labels.png' /></a>

# %% [markdown]
# ##### Data Summarization -   -- Univariate analysis in Pandas (Some Examples)
#         -- Helps in understanding the profile of every column(feature/dimension) in a dataset
#         -- helps to get the measures of central tendency(mean/median etc)
#         -- helps to get the measures of dispersion (1st quartile, mid quartile, 3rd quartile)
#           - dispersion will tell how spread out the data is

# %%
### describe for individual columns 
### helps to understand the attributes of individual columns 
### one aspect of "Univariate Analysis"


df["START_DATE*"].describe()
# Out:
# count                1156
# unique               1155
# top       6/28/2016 23:34
# freq                    2
# Name: START_DATE*, dtype: object

# %%
### describe for select group of columns
###  helps to understand the attributes of columns together
### one aspect of "Univariate Analysis"


df[["START_DATE*","END_DATE*"]].describe()
# Out:
#             START_DATE*        END_DATE*
# count              1156             1155
# unique             1155             1154
# top     6/28/2016 23:34  6/28/2016 23:59
# freq                  2                2

# %%
df.info
# Out:
# <bound method DataFrame.info of            START_DATE*         END_DATE* CATEGORY*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business
# 1        1/2/2016 1:25     1/2/2016 1:37  Business
# 2       1/2/2016 20:25    1/2/2016 20:38  Business
# 3       1/5/2016 17:31    1/5/2016 17:45  Business
# 4       1/6/2016 14:42    1/6/2016 15:49  Business
# 5       1/6/2016 17:15    1/6/2016 17:19  Business
# 6       1/6/2016 17:30    1/6/2016 17:35  Business
# 7       1/7/2016 13:27    1/7/2016 13:33  Business
# 8       1/10/2016 8:05    1/10/2016 8:25  Business
# 9      1/10/2016 12:17   1/10/2016 12:44  Business
# 10     1/10/2016 15:08   1/10/2016 15:51  Business
# 11     1/10/2016 18:18   1/10/2016 18:53  Business
# 12     1/10/2016 19:12   1/10/2016 19:32  Business
# 13      1/11/2016 8:55    1/11/2016 9:21  Business
# 14     1/11/2016 11:56   1/11/2016 12:03  Business
# 15     1/11/2016 13:32   1/11/2016 13:46  Business
# 16     1/11/2016 14:30   1/11/2016 14:43  Business
# 17     1/12/2016 12:33   1/12/2016 12:49  Business
# 18     1/12/2016 12:53   1/12/2016 13:09  Business
# 19     1/12/2016 14:42   1/12/2016 14:56  Business
# 20     1/12/2016 15:13   1/12/2016 15:28  Business
# 21     1/12/2016 15:42   1/12/2016 15:54  Business
# 22     1/12/2016 16:02   1/12/2016 17:00  Business
# 23     1/13/2016 13:54   1/13/2016 14:07  Business
# 24     1/13/2016 15:00   1/13/2016 15:28  Business
# 25     1/14/2016 16:29   1/14/2016 17:05  Business
# 26     1/14/2016 21:39   1/14/2016 21:45  Business
# 27      1/15/2016 0:41    1/15/2016 1:01  Business
# 28     1/15/2016 11:43   1/15/2016 12:03  Business
# 29     1/15/2016 13:26   1/15/2016 13:44  Business
# 30     1/18/2016 14:55   1/18/2016 15:06  Business
# 31     1/18/2016 16:13   1/18/2016 16:24  Business
# 32      1/19/2016 9:09    1/19/2016 9:23  Business
# 33     1/19/2016 10:55   1/19/2016 11:09  Business
# 34     1/20/2016 10:36   1/20/2016 11:11  Business
# 35     1/20/2016 11:48   1/20/2016 12:19  Business
# 36     1/20/2016 13:25   1/20/2016 14:19  Business
# 37     1/21/2016 14:25   1/21/2016 14:29  Business
# 38     1/21/2016 14:43   1/21/2016 14:51  Business
# 39     1/21/2016 16:01   1/21/2016 16:06  Business
# 40     1/26/2016 10:41   1/26/2016 10:50  Business
# 41     1/26/2016 12:33   1/26/2016 12:41  Business
# 42     1/26/2016 16:24   1/26/2016 16:32  Business
# 43     1/26/2016 17:17   1/26/2016 17:22  Business
# 44     1/26/2016 17:27   1/26/2016 17:29  Business
# 45      1/27/2016 9:24    1/27/2016 9:31  Business
# 46     1/27/2016 10:19   1/27/2016 10:48  Business
# 47     1/27/2016 12:34   1/27/2016 12:44  Business
# 48     1/27/2016 14:05   1/27/2016 14:13  Business
# 49     1/27/2016 14:46   1/27/2016 15:08  Business
# 50     1/28/2016 12:28   1/28/2016 13:00  Business
# 51     1/28/2016 15:11   1/28/2016 15:31  Business
# 52     1/28/2016 16:21   1/28/2016 16:51  Business
# 53      1/29/2016 9:31    1/29/2016 9:45  Business
# 54     1/29/2016 10:56   1/29/2016 11:07  Business
# 55     1/29/2016 11:43   1/29/2016 12:03  Business
# 56     1/29/2016 13:24   1/29/2016 13:47  Business
# 57     1/29/2016 18:31   1/29/2016 18:52  Business
# 58     1/29/2016 21:21   1/29/2016 21:40  Business
# 59     1/30/2016 16:21   1/30/2016 16:33  Business
# 60     1/30/2016 18:09   1/30/2016 18:24  Business
# 61      2/1/2016 10:35    2/1/2016 11:15  Business
# 62      2/1/2016 12:10    2/1/2016 12:43  Business
# 63      2/1/2016 12:56    2/1/2016 13:07  Business
# 64      2/2/2016 13:04    2/2/2016 13:23  Business
# 65      2/2/2016 13:51    2/2/2016 14:06  Business
# 66      2/2/2016 14:38    2/2/2016 14:42  Business
# 67       2/4/2016 8:40     2/4/2016 9:01  Business
# 68       2/4/2016 9:37    2/4/2016 10:09  Business
# 69      2/4/2016 10:26    2/4/2016 10:32  Business
# 70      2/4/2016 15:59    2/4/2016 16:03  Business
# 71      2/4/2016 16:35    2/4/2016 16:39  Business
# 72      2/4/2016 18:04    2/4/2016 18:31  Business
# 73      2/4/2016 20:36    2/4/2016 20:55  Business
# 74      2/5/2016 11:47    2/5/2016 12:07  Business
# 75      2/5/2016 13:22    2/5/2016 13:41  Business
# 76      2/6/2016 16:20    2/6/2016 16:53  Business
# 77      2/6/2016 18:57    2/6/2016 19:21  Business
# 78      2/6/2016 19:28    2/6/2016 19:37  Business
# 79      2/7/2016 16:49    2/7/2016 17:01  Business
# 80      2/7/2016 18:03    2/7/2016 18:17  Business
# 81      2/7/2016 18:39    2/7/2016 18:53  Business
# 82      2/7/2016 20:22    2/7/2016 20:40  Business
# 83      2/8/2016 12:57    2/8/2016 13:08  Business
# 84      2/8/2016 14:00    2/8/2016 14:10  Business
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal
# 88      2/9/2016 13:58    2/9/2016 14:02  Personal
# 89      2/9/2016 18:55    2/9/2016 19:11  Business
# 90      2/9/2016 20:24    2/9/2016 20:40  Business
# 91     2/11/2016 16:28   2/11/2016 17:10  Business
# 92     2/11/2016 17:49   2/11/2016 18:10  Business
# 93     2/11/2016 18:24   2/11/2016 18:46  Business
# 94     2/11/2016 20:36   2/11/2016 20:51  Business
# 95      2/12/2016 8:21    2/12/2016 8:42  Business
# 96     2/12/2016 10:45   2/12/2016 10:52  Business
# 97     2/12/2016 11:14   2/12/2016 11:35  Business
# 98     2/12/2016 13:02   2/12/2016 13:36  Business
# 99     2/12/2016 14:49   2/12/2016 15:06  Business
# 100    2/12/2016 15:33   2/12/2016 16:06  Business
# 101    2/13/2016 14:21   2/13/2016 14:41  Business
# 102    2/13/2016 23:45    2/14/2016 0:01  Personal
# 103     2/14/2016 0:50    2/14/2016 1:00  Personal
# 104    2/14/2016 14:07   2/14/2016 14:40  Business
# 105    2/14/2016 14:46   2/14/2016 15:03  Business
# 106    2/14/2016 16:35   2/14/2016 17:02  Business
# 107    2/14/2016 17:06   2/14/2016 17:29  Business
# 108     2/16/2016 3:21    2/16/2016 4:13  Business
# 109     2/16/2016 8:29    2/16/2016 9:34  Business
# 110    2/16/2016 10:31   2/16/2016 10:41  Business
# 111    2/16/2016 11:32   2/16/2016 12:02  Business
# 112    2/16/2016 12:39   2/16/2016 12:42  Business
# 113    2/16/2016 13:43   2/16/2016 13:55  Business
# 114    2/16/2016 16:34   2/16/2016 17:10  Business
# 115    2/16/2016 17:17   2/16/2016 17:26  Business
# 116    2/16/2016 17:40   2/16/2016 17:44  Business
# 117    2/17/2016 13:18   2/17/2016 14:04  Business
# 118    2/17/2016 15:17   2/17/2016 15:22  Business
# 119    2/17/2016 15:33   2/17/2016 16:17  Business
# 120    2/17/2016 16:38   2/17/2016 16:43  Business
# 121     2/18/2016 8:19    2/18/2016 8:27  Business
# 122    2/18/2016 14:03   2/18/2016 14:45  Business
# 123    2/18/2016 15:16   2/18/2016 15:31  Business
# 124    2/18/2016 18:44   2/18/2016 18:58  Business
# 125    2/18/2016 19:27   2/18/2016 20:08  Business
# 126     2/19/2016 9:02    2/19/2016 9:14  Business
# 127     2/19/2016 9:21    2/19/2016 9:51  Business
# 128    2/19/2016 10:21   2/19/2016 10:48  Business
# 129    2/19/2016 11:20   2/19/2016 11:26  Personal
# 130    2/19/2016 11:45   2/19/2016 11:50  Personal
# 131    2/19/2016 12:09   2/19/2016 12:27  Business
# 132    2/19/2016 16:26   2/19/2016 16:45  Business
# 133    2/19/2016 17:09   2/19/2016 17:20  Business
# 134    2/19/2016 20:08   2/19/2016 20:30  Personal
# 135    2/19/2016 20:34   2/19/2016 20:51  Personal
# 136     2/20/2016 7:59    2/20/2016 8:32  Personal
# 137    2/20/2016 10:48   2/20/2016 10:56  Personal
# 138    2/20/2016 11:45   2/20/2016 11:53  Personal
# 139    2/20/2016 12:41   2/20/2016 13:17  Business
# 140    2/20/2016 14:50   2/20/2016 15:54  Business
# 141    2/20/2016 16:59   2/20/2016 17:54  Personal
# 142    2/20/2016 18:00   2/20/2016 18:03  Business
# 143    2/20/2016 19:28   2/20/2016 19:49  Business
# 144     2/21/2016 9:07    2/21/2016 9:46  Business
# 145    2/21/2016 11:39   2/21/2016 11:43  Business
# 146    2/21/2016 11:47   2/21/2016 12:01  Business
# 147    2/21/2016 12:13   2/21/2016 12:35  Business
# 148    2/21/2016 12:51   2/21/2016 13:12  Business
# 149    2/21/2016 13:33   2/21/2016 14:30  Business
# 150    2/21/2016 14:36   2/21/2016 15:03  Business
# 151    2/21/2016 15:14   2/21/2016 15:31  Business
# 152    2/21/2016 15:36   2/21/2016 15:41  Business
# 153    2/21/2016 16:04   2/21/2016 16:32  Business
# 154    2/21/2016 23:15   2/21/2016 23:52  Business
# 155    2/22/2016 21:54   2/22/2016 22:09  Business
# 156    2/24/2016 14:30   2/24/2016 14:35  Business
# 157    2/24/2016 15:19   2/24/2016 15:25  Business
# 158    2/25/2016 16:27   2/25/2016 16:35  Business
# 159    2/25/2016 16:47   2/25/2016 17:02  Business
# 160    2/25/2016 17:16   2/25/2016 17:36  Business
# 161    2/25/2016 18:22   2/25/2016 18:39  Business
# 162     2/26/2016 9:06    2/26/2016 9:29  Business
# 163    2/26/2016 11:05   2/26/2016 11:11  Personal
# 164    2/26/2016 11:35   2/26/2016 11:59  Business
# 165    2/26/2016 13:01   2/26/2016 13:24  Business
# 166    2/26/2016 14:38   2/26/2016 14:46  Personal
# 167    2/26/2016 15:00   2/26/2016 15:18  Personal
# 168    2/26/2016 17:01   2/26/2016 17:12  Personal
# 169     2/28/2016 5:22    2/28/2016 5:38  Business
# 170     2/28/2016 9:26    2/28/2016 9:42  Business
# 171    2/29/2016 11:07   2/29/2016 11:14  Personal
# 172    2/29/2016 11:30   2/29/2016 11:40  Business
# 173    2/29/2016 12:36   2/29/2016 12:48  Business
# 174    2/29/2016 14:55   2/29/2016 15:03  Business
# 175    2/29/2016 16:40   2/29/2016 17:00  Business
# 176     3/1/2016 18:47    3/1/2016 19:10  Business
# 177     3/1/2016 21:27    3/1/2016 21:45  Business
# 178      3/3/2016 9:45     3/3/2016 9:52  Personal
# 179     3/3/2016 11:04    3/3/2016 11:10  Business
# 180     3/3/2016 14:44    3/3/2016 14:58  Business
# 181     3/3/2016 15:27    3/3/2016 15:48  Business
# 182     3/3/2016 16:02    3/3/2016 16:42  Business
# 183      3/4/2016 7:47     3/4/2016 8:06  Business
# 184      3/4/2016 9:46    3/4/2016 10:03  Business
# 185     3/4/2016 11:46    3/4/2016 12:06  Business
# 186     3/4/2016 13:03    3/4/2016 13:25  Business
# 187     3/4/2016 13:40    3/4/2016 14:09  Business
# 188     3/4/2016 15:56    3/4/2016 16:08  Business
# 189     3/4/2016 16:16    3/4/2016 16:22  Business
# 190     3/4/2016 16:43    3/4/2016 17:12  Business
# 191     3/4/2016 19:02    3/4/2016 19:08  Business
# 192     3/4/2016 19:16    3/4/2016 19:25  Business
# 193     3/5/2016 11:44    3/5/2016 11:59  Business
# 194     3/5/2016 12:57    3/5/2016 13:12  Personal
# 195     3/5/2016 14:08    3/5/2016 14:18  Personal
# 196     3/5/2016 14:39    3/5/2016 15:01  Business
# 197     3/5/2016 16:52    3/5/2016 17:13  Business
# 198     3/5/2016 17:23    3/5/2016 17:34  Business
# 199      3/7/2016 9:10     3/7/2016 9:20  Business
# 200      3/7/2016 9:23     3/7/2016 9:47  Business
# 201     3/7/2016 12:10    3/7/2016 12:26  Business
# 202     3/7/2016 13:57    3/7/2016 14:18  Business
# 203     3/7/2016 15:19    3/7/2016 15:45  Business
# 204     3/8/2016 14:38    3/8/2016 14:55  Business
# 205     3/8/2016 15:35    3/8/2016 16:00  Business
# 206     3/8/2016 16:13    3/8/2016 16:25  Personal
# 207     3/10/2016 3:36    3/10/2016 3:53  Business
# 208    3/10/2016 10:08   3/10/2016 10:37  Business
# 209    3/10/2016 14:39   3/10/2016 14:55  Business
# 210    3/10/2016 16:18   3/10/2016 16:28  Business
# 211     3/11/2016 9:47    3/11/2016 9:59  Business
# 212    3/11/2016 10:29   3/11/2016 10:36  Business
# 213    3/11/2016 11:57   3/11/2016 12:04  Business
# 214    3/11/2016 13:43   3/11/2016 13:51  Business
# 215    3/11/2016 19:21   3/11/2016 19:35  Business
# 216     3/12/2016 9:13    3/12/2016 9:22  Business
# 217    3/12/2016 18:27   3/12/2016 18:37  Personal
# 218     3/13/2016 9:07    3/13/2016 9:37  Business
# 219    3/13/2016 18:23   3/13/2016 18:43  Business
# 220    3/13/2016 20:07   3/13/2016 20:28  Business
# 221    3/13/2016 20:39   3/13/2016 20:58  Business
# 222    3/13/2016 21:11   3/13/2016 21:23  Business
# 223    3/13/2016 22:19   3/13/2016 22:39  Business
# 224     3/14/2016 8:34    3/14/2016 8:49  Business
# 225    3/14/2016 18:39   3/14/2016 18:55  Business
# 226     3/15/2016 8:45    3/15/2016 8:57  Business
# 227    3/15/2016 20:48   3/15/2016 21:01  Business
# 228    3/16/2016 11:34   3/16/2016 11:45  Business
# 229    3/16/2016 14:44   3/16/2016 14:55  Business
# 230    3/16/2016 18:43   3/16/2016 18:56  Business
# 231     3/17/2016 0:33    3/17/2016 0:44  Personal
# 232    3/17/2016 12:52   3/17/2016 15:11  Business
# 233    3/17/2016 15:16   3/17/2016 15:58  Business
# 234    3/17/2016 17:20   3/17/2016 18:02  Business
# 235    3/17/2016 18:47   3/17/2016 19:09  Personal
# 236    3/17/2016 20:57   3/17/2016 21:28  Personal
# 237    3/17/2016 21:48   3/17/2016 22:04  Personal
# 238     3/18/2016 7:15    3/18/2016 7:21  Business
# 239     3/18/2016 8:35    3/18/2016 8:43  Business
# 240    3/18/2016 18:24   3/18/2016 19:08  Business
# 241    3/18/2016 19:23   3/18/2016 19:29  Business
# 242    3/18/2016 21:01   3/18/2016 21:15  Business
# 243     3/19/2016 9:10    3/19/2016 9:25  Business
# 244    3/19/2016 12:50   3/19/2016 13:13  Business
# 245    3/19/2016 14:01   3/19/2016 14:57  Business
# 246    3/19/2016 15:34   3/19/2016 16:38  Business
# 247    3/19/2016 17:17   3/19/2016 17:32  Business
# 248    3/19/2016 17:37   3/19/2016 17:47  Business
# 249    3/19/2016 17:52   3/19/2016 18:00  Business
# 250    3/19/2016 18:53   3/19/2016 19:29  Business
# 251    3/19/2016 19:33   3/19/2016 20:39  Business
# 252     3/20/2016 7:37    3/20/2016 7:48  Business
# 253    3/20/2016 11:42   3/20/2016 11:56  Business
# 254    3/20/2016 17:08   3/20/2016 17:34  Business
# 255    3/20/2016 18:34   3/20/2016 18:40  Personal
# 256    3/20/2016 18:45   3/20/2016 19:06  Business
# 257    3/21/2016 10:21   3/21/2016 10:26  Personal
# 258    3/21/2016 16:05   3/21/2016 16:13  Business
# 259    3/21/2016 18:59   3/21/2016 19:15  Business
# 260    3/21/2016 20:18   3/21/2016 20:55  Business
# 261     3/22/2016 6:17    3/22/2016 6:43  Business
# 262    3/22/2016 12:06   3/22/2016 12:24  Personal
# 263    3/22/2016 19:12   3/22/2016 19:25  Personal
# 264    3/23/2016 14:37   3/23/2016 14:42  Personal
# 265    3/23/2016 14:53   3/23/2016 14:59  Personal
# 266    3/24/2016 19:47   3/24/2016 19:54  Personal
# 267    3/24/2016 20:34   3/24/2016 20:40  Business
# 268    3/25/2016 13:24   3/25/2016 16:22  Business
# 269    3/25/2016 16:52   3/25/2016 22:22  Business
# 270    3/25/2016 22:54    3/26/2016 1:39  Business
# 271    3/26/2016 14:05   3/26/2016 14:29  Personal
# 272    3/26/2016 15:19   3/26/2016 15:49  Personal
# 273    3/26/2016 16:26   3/26/2016 16:30  Personal
# 274     3/27/2016 0:31    3/27/2016 0:40  Business
# 275     3/27/2016 1:11    3/27/2016 1:23  Business
# 276    3/27/2016 15:31   3/27/2016 15:56  Business
# 277    3/27/2016 21:26   3/27/2016 21:41  Personal
# 278    3/27/2016 23:04   3/27/2016 23:18  Personal
# 279    3/28/2016 12:29   3/28/2016 12:42  Personal
# 280    3/28/2016 19:30   3/28/2016 20:23  Personal
# 281    3/28/2016 22:55   3/28/2016 23:26  Personal
# 282    3/29/2016 15:27   3/29/2016 16:11  Personal
# 283    3/29/2016 18:20   3/29/2016 18:39  Personal
# 284    3/29/2016 20:29   3/29/2016 20:44  Personal
# 285    3/29/2016 23:04   3/29/2016 23:21  Personal
# 286    3/30/2016 22:05   3/30/2016 22:55  Business
# 287    3/31/2016 12:47   3/31/2016 13:22  Business
# 288    3/31/2016 14:37   3/31/2016 15:09  Business
# 289     4/1/2016 13:43    4/1/2016 14:01  Business
# 290     4/1/2016 14:36    4/1/2016 15:24  Business
# 291     4/1/2016 16:01    4/1/2016 16:49  Business
# 292     4/1/2016 16:52    4/1/2016 16:57  Personal
# 293      4/2/2016 8:48     4/2/2016 9:04  Personal
# 294     4/2/2016 11:01    4/2/2016 11:16  Personal
# 295     4/2/2016 12:21    4/2/2016 14:47  Business
# 296     4/2/2016 16:57    4/2/2016 18:09  Business
# 297     4/2/2016 19:38    4/2/2016 22:36  Business
# 298     4/2/2016 23:11     4/3/2016 1:34  Business
# 299      4/3/2016 2:00     4/3/2016 4:16  Business
# 300     4/5/2016 21:39    4/5/2016 21:55  Business
# 301      4/6/2016 0:19     4/6/2016 0:39  Business
# 302     4/7/2016 18:20    4/7/2016 18:39  Business
# 303     4/7/2016 19:45    4/7/2016 20:00  Business
# 304     4/8/2016 12:30    4/8/2016 12:48  Business
# 305     4/8/2016 13:34    4/8/2016 13:51  Business
# 306     4/8/2016 13:55    4/8/2016 14:03  Business
# 307     4/8/2016 14:43    4/8/2016 15:20  Business
# 308     4/8/2016 16:05    4/8/2016 16:47  Business
# 309     4/12/2016 9:15    4/12/2016 9:26  Business
# 310     4/12/2016 9:34    4/12/2016 9:53  Business
# 311    4/12/2016 10:58   4/12/2016 11:18  Business
# 312    4/12/2016 12:22   4/12/2016 12:44  Business
# 313    4/12/2016 13:42   4/12/2016 14:01  Business
# 314     4/14/2016 7:29    4/14/2016 8:09  Business
# 315    4/14/2016 16:00   4/14/2016 16:43  Business
# 316    4/15/2016 11:36   4/15/2016 12:07  Business
# 317    4/15/2016 12:29   4/15/2016 12:32  Business
# 318    4/15/2016 14:31   4/15/2016 15:01  Business
# 319    4/16/2016 12:59   4/16/2016 13:17  Business
# 320    4/16/2016 15:10   4/16/2016 15:26  Business
# 321    4/19/2016 17:44   4/19/2016 18:08  Business
# 322    4/19/2016 19:57   4/19/2016 20:19  Business
# 323     4/22/2016 8:25    4/22/2016 9:04  Business
# 324    4/22/2016 10:10   4/22/2016 10:40  Business
# 325    4/22/2016 12:08   4/22/2016 12:28  Business
# 326    4/22/2016 13:02   4/22/2016 13:26  Business
# 327    4/23/2016 17:03   4/23/2016 17:16  Business
# 328    4/23/2016 18:49   4/23/2016 19:05  Business
# 329    4/24/2016 19:07   4/24/2016 19:16  Business
# 330    4/24/2016 19:46   4/24/2016 19:52  Business
# 331    4/24/2016 21:41   4/24/2016 21:50  Business
# 332    4/27/2016 13:30   4/27/2016 13:40  Business
# 333    4/27/2016 14:13   4/27/2016 14:25  Business
# 334    4/28/2016 12:09   4/28/2016 12:34  Business
# 335    4/28/2016 13:30   4/28/2016 13:49  Business
# 336    4/28/2016 22:10   4/28/2016 22:28  Business
# 337    4/29/2016 11:44   4/29/2016 12:01  Business
# 338    4/29/2016 13:13   4/29/2016 13:34  Business
# 339    4/29/2016 18:46   4/29/2016 19:18  Business
# 340    4/29/2016 22:44   4/29/2016 23:19  Business
# 341    4/30/2016 18:42   4/30/2016 18:57  Business
# 342    4/30/2016 22:16   4/30/2016 22:34  Business
# 343     5/1/2016 13:45    5/1/2016 13:53  Business
# 344     5/1/2016 14:26    5/1/2016 14:31  Business
# 345     5/1/2016 17:33    5/1/2016 17:45  Business
# 346     5/1/2016 17:54    5/1/2016 18:10  Business
# 347     5/1/2016 22:38    5/1/2016 22:49  Business
# 348     5/2/2016 14:14    5/2/2016 14:21  Business
# 349     5/2/2016 15:37    5/2/2016 15:48  Business
# 350     5/3/2016 22:20    5/3/2016 22:28  Business
# 351     5/4/2016 15:16    5/4/2016 15:37  Business
# 352     5/4/2016 20:55    5/4/2016 21:14  Business
# 353     5/4/2016 21:30    5/4/2016 21:36  Business
# 354     5/4/2016 22:19    5/4/2016 22:27  Business
# 355     5/5/2016 21:24    5/5/2016 21:36  Business
# 356     5/5/2016 22:34    5/5/2016 22:40  Business
# 357     5/5/2016 23:55     5/6/2016 0:08  Business
# 358      5/6/2016 5:47     5/6/2016 6:02  Business
# 359     5/6/2016 16:45    5/6/2016 16:59  Business
# 360     5/6/2016 17:18    5/6/2016 17:44  Business
# 361      5/9/2016 6:08     5/9/2016 6:25  Business
# 362     5/9/2016 14:39    5/9/2016 15:06  Business
# 363     5/9/2016 17:58    5/9/2016 18:26  Business
# 364     5/9/2016 19:35    5/9/2016 19:59  Business
# 365     5/10/2016 9:03    5/10/2016 9:20  Business
# 366    5/10/2016 17:19   5/10/2016 17:31  Business
# 367     5/11/2016 8:35    5/11/2016 9:12  Business
# 368    5/11/2016 21:47   5/11/2016 22:04  Business
# 369    5/14/2016 18:35   5/14/2016 18:39  Business
# 370    5/14/2016 23:01   5/14/2016 23:05  Business
# 371    5/17/2016 13:15   5/17/2016 13:23  Business
# 372    5/17/2016 13:56   5/17/2016 14:08  Business
# 373    5/17/2016 14:34   5/17/2016 14:40  Business
# 374     5/18/2016 9:11    5/18/2016 9:41  Business
# 375    5/18/2016 13:00   5/18/2016 13:02  Business
# 376    5/19/2016 14:37   5/19/2016 15:01  Business
# 377    5/20/2016 10:56   5/20/2016 11:07  Business
# 378    5/20/2016 15:43   5/20/2016 16:12  Business
# 379    5/22/2016 15:39   5/22/2016 15:46  Business
# 380    5/22/2016 18:46   5/22/2016 18:53  Business
# 381    5/23/2016 20:19   5/23/2016 20:27  Business
# 382    5/23/2016 21:09   5/23/2016 21:21  Business
# 383    5/27/2016 20:26   5/27/2016 20:30  Business
# 384    5/27/2016 20:47   5/27/2016 20:53  Business
# 385    5/27/2016 22:11   5/27/2016 22:14  Business
# 386     5/28/2016 0:15    5/28/2016 0:21  Business
# 387    5/28/2016 12:52   5/28/2016 13:06  Business
# 388    5/28/2016 14:35   5/28/2016 15:04  Business
# 389    5/31/2016 13:54   5/31/2016 14:41  Business
# 390    5/31/2016 16:02   5/31/2016 16:39  Business
# 391    5/31/2016 17:50   5/31/2016 17:59  Business
# 392     6/1/2016 10:19    6/1/2016 10:47  Business
# 393     6/1/2016 13:10    6/1/2016 13:39  Business
# 394     6/3/2016 11:29    6/3/2016 11:49  Business
# 395     6/3/2016 13:08    6/3/2016 13:38  Business
# 396     6/3/2016 15:31    6/3/2016 15:54  Business
# 397     6/3/2016 18:14    6/3/2016 18:29  Business
# 398     6/3/2016 18:41    6/3/2016 18:53  Business
# 399     6/3/2016 19:36    6/3/2016 19:42  Business
# 400     6/3/2016 22:47    6/3/2016 23:06  Business
# 401     6/5/2016 14:03    6/5/2016 14:33  Business
# 402     6/5/2016 15:06    6/5/2016 15:22  Business
# 403     6/5/2016 15:57    6/5/2016 16:08  Business
# 404     6/5/2016 18:05    6/5/2016 18:14  Business
# 405     6/5/2016 21:53    6/5/2016 22:05  Business
# 406     6/5/2016 23:52     6/6/2016 0:08  Business
# 407     6/6/2016 15:36    6/6/2016 15:45  Business
# 408     6/6/2016 16:16    6/6/2016 16:24  Business
# 409     6/6/2016 20:06    6/6/2016 20:20  Business
# 410     6/6/2016 21:08    6/6/2016 21:37  Business
# 411     6/6/2016 21:41    6/6/2016 22:00  Business
# 412     6/6/2016 23:34    6/6/2016 23:48  Business
# 413     6/7/2016 21:42    6/7/2016 22:00  Business
# 414     6/7/2016 23:41     6/8/2016 0:04  Business
# 415      6/8/2016 8:23     6/8/2016 8:53  Business
# 416     6/8/2016 12:04    6/8/2016 13:01  Business
# 417     6/8/2016 13:12    6/8/2016 13:29  Business
# 418     6/8/2016 14:31    6/8/2016 14:37  Business
# 419     6/8/2016 16:55    6/8/2016 17:11  Business
# 420     6/8/2016 17:16    6/8/2016 17:18  Business
# 421     6/8/2016 17:59    6/8/2016 18:05  Business
# 422     6/8/2016 20:11    6/8/2016 20:25  Business
# 423    6/10/2016 15:19   6/10/2016 16:28  Business
# 424    6/10/2016 21:47   6/10/2016 22:04  Business
# 425    6/10/2016 23:53    6/11/2016 0:01  Business
# 426    6/11/2016 17:08   6/11/2016 17:16  Business
# 427    6/11/2016 17:34   6/11/2016 17:39  Business
# 428    6/11/2016 17:50   6/11/2016 17:56  Business
# 429    6/11/2016 21:45   6/11/2016 22:04  Business
# 430    6/11/2016 23:39    6/12/2016 0:05  Business
# 431    6/12/2016 19:53   6/12/2016 19:56  Business
# 432    6/12/2016 20:05   6/12/2016 20:16  Business
# 433    6/12/2016 21:58   6/12/2016 22:19  Business
# 434     6/13/2016 5:23    6/13/2016 5:42  Business
# 435    6/13/2016 14:17   6/13/2016 14:46  Business
# 436    6/13/2016 18:08   6/13/2016 18:47  Business
# 437    6/13/2016 18:54   6/13/2016 19:23  Business
# 438    6/13/2016 20:00   6/13/2016 20:05  Business
# 439    6/14/2016 12:03   6/14/2016 12:21  Business
# 440    6/14/2016 16:09   6/14/2016 16:39  Business
# 441    6/14/2016 17:15   6/14/2016 17:24  Business
# 442    6/14/2016 17:27   6/14/2016 17:57  Business
# 443     6/15/2016 1:46    6/15/2016 2:06  Business
# 444    6/15/2016 15:26   6/15/2016 15:34  Business
# 445    6/15/2016 16:37   6/15/2016 17:02  Business
# 446    6/15/2016 17:29   6/15/2016 17:49  Personal
# 447    6/15/2016 19:52   6/15/2016 19:58  Business
# 448    6/16/2016 13:36   6/16/2016 14:30  Business
# 449    6/16/2016 14:42   6/16/2016 14:46  Business
# 450    6/16/2016 15:17   6/16/2016 15:41  Business
# 451    6/16/2016 19:39   6/16/2016 19:56  Business
# 452    6/16/2016 21:43   6/16/2016 21:56  Business
# 453    6/17/2016 16:11   6/17/2016 16:44  Business
# 454     6/18/2016 0:29    6/18/2016 0:51  Business
# 455     6/19/2016 2:39    6/19/2016 2:50  Business
# 456     6/19/2016 5:51    6/19/2016 6:00  Business
# 457    6/21/2016 15:39   6/21/2016 16:08  Business
# 458    6/21/2016 17:11   6/21/2016 18:02  Business
# 459    6/24/2016 10:41   6/24/2016 10:57  Business
# 460    6/24/2016 11:54   6/24/2016 12:01  Business
# 461    6/24/2016 12:19   6/24/2016 12:37  Business
# 462    6/24/2016 12:50   6/24/2016 13:12  Business
# 463    6/24/2016 13:18   6/24/2016 13:27  Business
# 464    6/24/2016 14:01   6/24/2016 14:20  Business
# 465    6/24/2016 20:44   6/24/2016 21:02  Business
# 466     6/25/2016 9:03    6/25/2016 9:12  Business
# 467     6/25/2016 9:15   6/25/2016 10:08  Business
# 468    6/25/2016 10:18   6/25/2016 10:25  Business
# 469    6/25/2016 10:50   6/25/2016 11:18  Business
# 470    6/25/2016 11:25   6/25/2016 11:34  Business
# 471    6/25/2016 11:53   6/25/2016 13:21  Business
# 472    6/25/2016 19:47   6/25/2016 19:58  Business
# 473    6/25/2016 23:19   6/25/2016 23:26  Business
# 474    6/26/2016 17:43   6/26/2016 18:18  Business
# 475    6/26/2016 18:45   6/26/2016 19:12  Business
# 476    6/26/2016 19:41   6/26/2016 19:50  Business
# 477    6/26/2016 21:14   6/26/2016 21:42  Business
# 478     6/27/2016 7:37    6/27/2016 8:48  Business
# 479     6/27/2016 8:51    6/27/2016 9:00  Business
# 480     6/27/2016 9:05    6/27/2016 9:33  Business
# 481     6/27/2016 9:43   6/27/2016 10:08  Business
# 482    6/27/2016 10:22   6/27/2016 10:39  Business
# 483    6/27/2016 10:51   6/27/2016 10:58  Business
# 484    6/27/2016 11:06   6/27/2016 11:24  Business
# 485    6/27/2016 11:30   6/27/2016 11:42  Business
# 486    6/27/2016 12:22   6/27/2016 13:02  Business
# 487    6/27/2016 13:56   6/27/2016 14:05  Business
# 488    6/27/2016 21:09   6/27/2016 21:19  Business
# 489     6/28/2016 0:48    6/28/2016 1:05  Business
# 490    6/28/2016 20:13   6/28/2016 20:33  Business
# 491    6/28/2016 23:34   6/28/2016 23:59  Business
# 492    6/28/2016 23:34   6/28/2016 23:59  Business
# 493     6/29/2016 8:56    6/29/2016 9:24  Business
# 494    6/29/2016 10:22   6/29/2016 10:38  Business
# 495    6/29/2016 11:49   6/29/2016 11:51  Business
# 496    6/29/2016 12:11   6/29/2016 12:16  Business
# 497    6/29/2016 20:11   6/29/2016 20:29  Business
# 498    6/29/2016 23:38    6/30/2016 0:00  Business
# 499    6/30/2016 20:09   6/30/2016 20:26  Business
# 500      7/1/2016 0:00     7/1/2016 0:25  Business
# 501      7/1/2016 9:34     7/1/2016 9:57  Business
# 502     7/1/2016 12:36    7/1/2016 13:00  Business
# 503     7/1/2016 20:06    7/1/2016 20:24  Business
# 504     7/1/2016 23:48     7/2/2016 0:09  Business
# 505     7/2/2016 20:18    7/2/2016 20:36  Business
# 506     7/2/2016 23:48     7/3/2016 0:12  Business
# 507      7/3/2016 0:28     7/3/2016 0:38  Business
# 508      7/3/2016 3:02     7/3/2016 3:08  Business
# 509     7/3/2016 20:00    7/3/2016 20:18  Business
# 510      7/4/2016 0:32     7/4/2016 0:47  Business
# 511     7/4/2016 17:31    7/4/2016 17:49  Business
# 512     7/4/2016 18:23    7/4/2016 18:49  Business
# 513     7/4/2016 20:00    7/4/2016 20:17  Business
# 514      7/5/2016 0:00     7/5/2016 0:05  Business
# 515      7/5/2016 0:08     7/5/2016 0:28  Business
# 516     7/5/2016 16:48    7/5/2016 16:52  Business
# 517     7/5/2016 20:06    7/5/2016 20:26  Business
# 518     7/5/2016 22:41    7/5/2016 23:02  Business
# 519      7/6/2016 0:33     7/6/2016 0:53  Business
# 520      7/6/2016 9:06     7/6/2016 9:25  Business
# 521     7/6/2016 12:48    7/6/2016 13:08  Business
# 522     7/6/2016 20:04    7/6/2016 20:14  Business
# 523     7/6/2016 23:46    7/6/2016 23:59  Business
# 524      7/7/2016 8:22     7/7/2016 8:50  Business
# 525     7/7/2016 10:27    7/7/2016 10:33  Business
# 526     7/7/2016 12:59    7/7/2016 13:35  Business
# 527      7/8/2016 9:50    7/8/2016 10:13  Business
# 528     7/8/2016 10:51    7/8/2016 11:12  Business
# 529     7/8/2016 13:48    7/8/2016 14:11  Business
# 530     7/8/2016 17:11    7/8/2016 17:30  Business
# 531      7/9/2016 9:03     7/9/2016 9:46  Business
# 532      7/9/2016 9:52    7/9/2016 10:06  Business
# 533     7/9/2016 10:15    7/9/2016 10:33  Business
# 534    7/10/2016 14:10   7/10/2016 14:17  Business
# 535    7/10/2016 16:04   7/10/2016 16:15  Business
# 536    7/10/2016 18:05   7/10/2016 18:21  Business
# 537    7/10/2016 19:51   7/10/2016 20:08  Business
# 538    7/12/2016 16:10   7/12/2016 16:45  Business
# 539    7/12/2016 19:21   7/12/2016 19:26  Personal
# 540    7/12/2016 23:47    7/13/2016 0:11  Personal
# 541    7/13/2016 12:39   7/13/2016 13:20  Personal
# 542    7/13/2016 13:25   7/13/2016 13:39  Personal
# 543    7/13/2016 13:42   7/13/2016 13:54  Personal
# 544    7/14/2016 15:51   7/14/2016 15:59  Personal
# 545    7/14/2016 16:03   7/14/2016 16:34  Business
# 546    7/14/2016 16:39   7/14/2016 20:05  Business
# 547    7/15/2016 11:32   7/15/2016 11:53  Personal
# 548    7/15/2016 12:09   7/15/2016 12:19  Personal
# 549    7/15/2016 12:35   7/15/2016 13:15  Personal
# 550    7/15/2016 15:03   7/15/2016 15:33  Personal
# 551    7/15/2016 15:40   7/15/2016 15:52  Personal
# 552    7/16/2016 13:14   7/16/2016 14:10  Personal
# 553    7/16/2016 14:14   7/16/2016 14:30  Personal
# 554    7/16/2016 15:29   7/16/2016 16:57  Personal
# 555    7/16/2016 19:42   7/16/2016 20:35  Personal
# 556    7/16/2016 21:45   7/16/2016 22:18  Personal
# 557    7/16/2016 22:50   7/16/2016 23:03  Business
# 558    7/17/2016 11:23   7/17/2016 11:50  Personal
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal
# 560    7/18/2016 10:37   7/18/2016 10:49  Personal
# 561    7/18/2016 10:54   7/18/2016 11:15  Personal
# 562    7/18/2016 11:25   7/18/2016 11:36  Personal
# 563    7/18/2016 11:40   7/18/2016 11:56  Personal
# 564    7/18/2016 17:12   7/18/2016 17:33  Business
# 565    7/18/2016 18:32   7/18/2016 18:47  Business
# 566    7/18/2016 19:07   7/18/2016 19:14  Business
# 567    7/18/2016 20:28   7/18/2016 20:32  Business
# 568    7/18/2016 21:11   7/18/2016 21:19  Business
# 569    7/19/2016 10:35   7/19/2016 10:51  Business
# 570    7/19/2016 10:56   7/19/2016 11:11  Business
# 571    7/19/2016 11:30   7/19/2016 12:00  Business
# 572    7/19/2016 17:14   7/19/2016 17:24  Business
# 573    7/19/2016 17:50   7/19/2016 18:08  Personal
# 574    7/20/2016 17:12   7/20/2016 17:24  Personal
# 575    7/20/2016 17:50   7/20/2016 17:57  Personal
# 576    7/20/2016 18:16   7/20/2016 18:20  Personal
# 577    7/21/2016 17:17   7/21/2016 17:23  Business
# 578    7/21/2016 17:42   7/21/2016 17:51  Business
# 579    7/21/2016 18:27   7/21/2016 18:42  Business
# 580    7/21/2016 19:30   7/21/2016 19:39  Business
# 581    7/22/2016 10:42   7/22/2016 10:53  Business
# 582    7/22/2016 11:11   7/22/2016 11:25  Business
# 583    7/22/2016 11:37   7/22/2016 12:00  Business
# 584    7/22/2016 12:14   7/22/2016 12:31  Business
# 585    7/22/2016 13:21   7/22/2016 13:42  Business
# 586    7/22/2016 14:27   7/22/2016 14:43  Business
# 587    7/22/2016 15:49   7/22/2016 16:22  Business
# 588    7/22/2016 18:33   7/22/2016 18:51  Business
# 589    7/23/2016 14:27   7/23/2016 14:44  Business
# 590    7/23/2016 14:48   7/23/2016 15:12  Business
# 591    7/23/2016 15:15   7/23/2016 15:27  Business
# 592    7/23/2016 15:50   7/23/2016 16:10  Business
# 593    7/23/2016 20:17   7/23/2016 20:33  Business
# 594    7/23/2016 23:18   7/23/2016 23:43  Business
# 595    7/25/2016 10:35   7/25/2016 10:41  Business
# 596    7/25/2016 10:47   7/25/2016 10:58  Business
# 597    7/25/2016 11:04   7/25/2016 11:33  Business
# 598    7/25/2016 11:37   7/25/2016 11:44  Business
# 599    7/26/2016 15:43   7/26/2016 15:49  Business
# 600    7/26/2016 17:14   7/26/2016 17:24  Business
# 601    7/26/2016 20:52   7/26/2016 21:00  Business
# 602    7/26/2016 22:31   7/26/2016 22:39  Business
# 603    7/27/2016 19:08   7/27/2016 19:20  Business
# 604    7/27/2016 21:34   7/27/2016 21:57  Business
# 605    7/27/2016 22:00   7/27/2016 22:26  Business
# 606     7/28/2016 0:04    7/28/2016 0:09  Business
# 607    7/29/2016 15:45   7/29/2016 15:47  Business
# 608    7/29/2016 17:27   7/29/2016 17:45  Business
# 609    7/30/2016 17:02   7/30/2016 17:27  Business
# 610    7/30/2016 21:16   7/30/2016 21:41  Business
# 611    7/31/2016 17:30   7/31/2016 17:37  Business
# 612     8/1/2016 12:47    8/1/2016 13:04  Business
# 613     8/1/2016 13:08    8/1/2016 13:19  Business
# 614     8/1/2016 13:28    8/1/2016 13:46  Business
# 615     8/1/2016 13:52    8/1/2016 14:14  Business
# 616     8/1/2016 15:40    8/1/2016 15:47  Business
# 617     8/1/2016 16:18    8/1/2016 16:25  Business
# 618     8/1/2016 16:29    8/1/2016 16:59  Business
# 619     8/1/2016 17:23    8/1/2016 17:55  Business
# 620      8/2/2016 8:11     8/2/2016 8:32  Business
# 621     8/2/2016 11:51    8/2/2016 12:15  Business
# 622     8/2/2016 19:15    8/2/2016 19:23  Business
# 623     8/2/2016 21:23    8/2/2016 21:29  Business
# 624     8/3/2016 12:46    8/3/2016 13:00  Business
# 625     8/3/2016 14:59    8/3/2016 15:03  Business
# 626     8/3/2016 16:00    8/3/2016 16:04  Business
# 627     8/5/2016 17:23    8/5/2016 17:30  Business
# 628     8/5/2016 18:17    8/5/2016 18:21  Business
# 629     8/5/2016 19:17    8/5/2016 19:27  Business
# 630      8/6/2016 6:40     8/6/2016 6:58  Business
# 631      8/6/2016 9:31     8/6/2016 9:53  Business
# 632     8/7/2016 17:14    8/7/2016 17:23  Business
# 633     8/7/2016 17:28    8/7/2016 17:43  Business
# 634     8/7/2016 18:17    8/7/2016 18:23  Business
# 635     8/7/2016 20:15    8/7/2016 20:23  Business
# 636     8/8/2016 16:17    8/8/2016 16:31  Business
# 637     8/8/2016 16:37    8/8/2016 16:50  Business
# 638     8/8/2016 17:02    8/8/2016 17:13  Business
# 639     8/8/2016 21:50    8/8/2016 22:15  Business
# 640     8/8/2016 23:28    8/8/2016 23:37  Business
# 641     8/9/2016 14:20    8/9/2016 14:38  Business
# 642     8/9/2016 15:15    8/9/2016 15:36  Business
# 643     8/9/2016 16:04    8/9/2016 16:37  Business
# 644    8/10/2016 16:56   8/10/2016 17:24  Business
# 645    8/10/2016 17:53   8/10/2016 18:28  Business
# 646    8/10/2016 18:49   8/10/2016 18:50  Business
# 647    8/10/2016 19:47   8/10/2016 20:02  Business
# 648    8/11/2016 12:53   8/11/2016 13:00  Business
# 649    8/11/2016 13:14   8/11/2016 13:28  Business
# 650    8/11/2016 13:32   8/11/2016 13:42  Business
# 651    8/11/2016 18:37   8/11/2016 19:29  Business
# 652    8/11/2016 20:59   8/11/2016 21:44  Business
# 653    8/12/2016 18:49   8/12/2016 18:52  Business
# 654    8/12/2016 18:56   8/12/2016 19:05  Business
# 655    8/13/2016 15:35   8/13/2016 15:58  Business
# 656     8/15/2016 9:05    8/15/2016 9:52  Business
# 657    8/15/2016 15:20   8/15/2016 15:47  Business
# 658    8/15/2016 16:52   8/15/2016 17:30  Business
# 659    8/15/2016 19:08   8/15/2016 20:30  Business
# 660     8/16/2016 7:58    8/16/2016 8:11  Business
# 661     8/16/2016 8:16    8/16/2016 8:23  Business
# 662     8/16/2016 8:46    8/16/2016 8:53  Business
# 663    8/16/2016 10:06   8/16/2016 10:27  Business
# 664    8/16/2016 10:31   8/16/2016 10:38  Business
# 665    8/16/2016 11:47   8/16/2016 12:03  Business
# 666    8/16/2016 15:13   8/16/2016 15:36  Business
# 667    8/17/2016 10:17   8/17/2016 10:41  Business
# 668    8/17/2016 10:57   8/17/2016 11:20  Business
# 669    8/17/2016 14:45   8/17/2016 14:50  Business
# 670    8/17/2016 15:32   8/17/2016 15:47  Business
# 671    8/17/2016 16:29   8/17/2016 16:50  Business
# 672    8/17/2016 16:54   8/17/2016 17:00  Business
# 673    8/17/2016 17:05   8/17/2016 17:34  Business
# 674    8/17/2016 18:38   8/17/2016 18:57  Business
# 675    8/18/2016 18:40   8/18/2016 19:07  Business
# 676     8/19/2016 8:24    8/19/2016 8:45  Business
# 677     8/19/2016 8:54    8/19/2016 9:07  Business
# 678     8/19/2016 9:27    8/19/2016 9:47  Business
# 679    8/19/2016 10:57   8/19/2016 11:06  Business
# 680    8/19/2016 12:07   8/19/2016 12:24  Business
# 681    8/19/2016 15:51   8/19/2016 16:06  Business
# 682    8/19/2016 17:12   8/19/2016 17:52  Business
# 683    8/21/2016 10:00   8/21/2016 10:29  Business
# 684    8/21/2016 14:05   8/21/2016 14:34  Business
# 685    8/21/2016 16:30   8/21/2016 17:02  Business
# 686    8/21/2016 18:10   8/21/2016 18:17  Business
# 687    8/21/2016 18:48   8/21/2016 19:24  Business
# 688    8/22/2016 10:00   8/22/2016 10:44  Business
# 689    8/22/2016 11:07   8/22/2016 11:23  Business
# 690    8/22/2016 12:36   8/22/2016 12:49  Business
# 691    8/22/2016 13:02   8/22/2016 13:11  Business
# 692    8/22/2016 14:07   8/22/2016 14:31  Business
# 693    8/22/2016 15:14   8/22/2016 15:49  Business
# 694    8/22/2016 15:59   8/22/2016 17:16  Business
# 695    8/22/2016 19:58   8/22/2016 20:50  Business
# 696    8/22/2016 20:53   8/22/2016 21:31  Business
# 697    8/22/2016 22:31   8/22/2016 23:00  Business
# 698     8/23/2016 8:10    8/23/2016 8:25  Business
# 699     8/23/2016 9:35   8/23/2016 10:09  Business
# 700    8/23/2016 12:59   8/23/2016 13:15  Business
# 701    8/23/2016 13:19   8/23/2016 13:30  Business
# 702    8/23/2016 13:49   8/23/2016 14:04  Business
# 703    8/23/2016 15:07   8/23/2016 15:12  Business
# 704    8/23/2016 15:15   8/23/2016 17:16  Business
# 705    8/23/2016 17:42   8/23/2016 18:31  Business
# 706    8/24/2016 12:05   8/24/2016 12:56  Business
# 707    8/24/2016 13:01   8/24/2016 15:25  Business
# 708    8/25/2016 15:17   8/25/2016 16:22  Business
# 709    8/25/2016 16:36   8/25/2016 16:56  Business
# 710    8/25/2016 17:19   8/25/2016 19:20  Business
# 711    8/25/2016 19:25   8/25/2016 19:57  Business
# 712    8/25/2016 22:58   8/25/2016 23:16  Business
# 713     8/26/2016 9:06    8/26/2016 9:20  Business
# 714    8/26/2016 11:14   8/26/2016 11:26  Business
# 715    8/26/2016 12:10   8/26/2016 12:20  Business
# 716    8/26/2016 14:10   8/26/2016 14:33  Business
# 717    8/26/2016 15:23   8/26/2016 15:35  Business
# 718    8/26/2016 15:59   8/26/2016 16:24  Business
# 719    8/26/2016 16:55   8/26/2016 17:12  Business
# 720    8/26/2016 18:42   8/26/2016 18:56  Business
# 721    8/26/2016 19:31   8/26/2016 19:54  Business
# 722    8/26/2016 20:06   8/26/2016 20:16  Business
# 723     8/27/2016 9:34   8/27/2016 10:11  Business
# 724    8/27/2016 11:47   8/27/2016 12:06  Business
# 725    8/27/2016 12:12   8/27/2016 12:17  Business
# 726    8/27/2016 14:01   8/27/2016 15:44  Business
# 727    8/27/2016 16:15   8/27/2016 19:13  Business
# 728     8/28/2016 9:57   8/28/2016 10:18  Business
# 729    8/28/2016 16:39   8/28/2016 16:55  Business
# 730    8/28/2016 17:37   8/28/2016 17:55  Business
# 731    8/28/2016 21:15   8/28/2016 21:59  Business
# 732    8/29/2016 12:02   8/29/2016 12:31  Business
# 733    8/29/2016 13:38   8/29/2016 13:48  Business
# 734    8/29/2016 14:31   8/29/2016 14:41  Business
# 735    8/29/2016 14:49   8/29/2016 15:04  Business
# 736    8/29/2016 15:49   8/29/2016 15:59  Business
# 737    8/29/2016 16:06   8/29/2016 16:21  Business
# 738    8/29/2016 17:24   8/29/2016 17:41  Business
# 739    8/29/2016 18:27   8/29/2016 18:36  Business
# 740    8/30/2016 11:53   8/30/2016 12:05  Business
# 741    8/30/2016 12:46   8/30/2016 13:09  Business
# 742    8/30/2016 13:25   8/30/2016 13:46  Business
# 743    8/30/2016 14:00   8/30/2016 14:20  Business
# 744    8/30/2016 17:27   8/30/2016 18:09  Business
# 745     9/1/2016 11:51    9/1/2016 12:24  Business
# 746     9/1/2016 17:21    9/1/2016 17:36  Business
# 747     9/1/2016 18:49    9/1/2016 19:08  Business
# 748     9/2/2016 11:37    9/2/2016 12:24  Business
# 749     9/2/2016 18:56    9/2/2016 19:37  Business
# 750     9/5/2016 10:25    9/5/2016 10:44  Business
# 751     9/6/2016 17:49    9/6/2016 17:49  Business
# 752    9/10/2016 10:28   9/10/2016 10:45  Business
# 753     9/11/2016 9:51    9/11/2016 9:55  Business
# 754    9/11/2016 21:40   9/11/2016 21:42  Business
# 755     9/12/2016 8:07    9/12/2016 8:12  Business
# 756    9/12/2016 11:15   9/12/2016 11:24  Business
# 757    9/12/2016 13:04   9/12/2016 13:44  Business
# 758    9/13/2016 16:56   9/13/2016 17:02  Business
# 759    9/14/2016 11:55   9/14/2016 11:59  Business
# 760    9/15/2016 20:33   9/15/2016 20:38  Business
# 761     9/16/2016 7:08    9/16/2016 7:08  Business
# 762    9/18/2016 18:07   9/18/2016 18:11  Business
# 763     9/19/2016 6:18    9/19/2016 6:49  Business
# 764    9/19/2016 14:40   9/19/2016 14:56  Business
# 765    9/19/2016 16:23   9/19/2016 16:31  Business
# 766    9/19/2016 17:36   9/19/2016 18:20  Business
# 767    9/19/2016 19:10   9/19/2016 19:49  Business
# 768    9/20/2016 11:29   9/20/2016 11:48  Business
# 769    9/20/2016 20:47   9/20/2016 22:47  Business
# 770    9/23/2016 13:15   9/23/2016 13:40  Business
# 771    9/24/2016 14:34   9/24/2016 15:15  Business
# 772    9/24/2016 20:29   9/24/2016 20:33  Business
# 773     9/27/2016 8:33    9/27/2016 8:35  Business
# 774    9/27/2016 13:21   9/27/2016 14:43  Business
# 775    9/27/2016 19:14   9/27/2016 20:34  Business
# 776    9/27/2016 21:01    9/28/2016 2:37  Business
# 777    9/28/2016 17:21   9/28/2016 19:36  Business
# 778    9/29/2016 16:13   9/29/2016 18:47  Business
# 779    9/30/2016 17:39   9/30/2016 20:20  Business
# 780    9/30/2016 20:59   9/30/2016 22:34  Business
# 781    10/3/2016 17:09   10/3/2016 17:12  Business
# 782    10/3/2016 18:17   10/3/2016 18:34  Business
# 783    10/3/2016 18:51   10/3/2016 19:01  Business
# 784    10/3/2016 22:04   10/3/2016 22:33  Business
# 785     10/4/2016 9:50   10/4/2016 10:52  Business
# 786    10/4/2016 12:17   10/4/2016 12:18  Business
# 787     10/6/2016 8:49   10/6/2016 11:36  Business
# 788    10/6/2016 17:23   10/6/2016 17:40  Business
# 789    10/6/2016 18:37   10/6/2016 18:39  Business
# 790    10/6/2016 19:46   10/6/2016 20:26  Business
# 791    10/7/2016 10:56   10/7/2016 10:59  Business
# 792    10/7/2016 11:27   10/7/2016 11:50  Business
# 793    10/7/2016 13:52   10/7/2016 14:08  Business
# 794    10/7/2016 14:29   10/7/2016 15:11  Business
# 795    10/7/2016 15:47   10/7/2016 16:02  Business
# 796    10/7/2016 18:08   10/7/2016 18:27  Business
# 797    10/7/2016 18:33   10/7/2016 19:01  Business
# 798    10/8/2016 15:03   10/8/2016 15:03  Business
# 799    10/8/2016 18:15   10/8/2016 18:18  Business
# 800    10/9/2016 14:04   10/9/2016 14:23  Business
# 801   10/10/2016 17:22  10/10/2016 17:28  Business
# 802   10/10/2016 17:33  10/10/2016 18:13  Business
# 803    10/11/2016 1:27   10/11/2016 2:08  Business
# 804   10/12/2016 19:18  10/12/2016 19:21  Business
# 805   10/13/2016 11:20  10/13/2016 11:58  Business
# 806   10/13/2016 12:08  10/13/2016 12:14  Business
# 807   10/13/2016 13:02  10/13/2016 13:02  Business
# 808   10/13/2016 13:37  10/13/2016 13:46  Business
# 809   10/13/2016 16:08  10/13/2016 16:53  Business
# 810    10/14/2016 8:50   10/14/2016 9:44  Business
# 811   10/14/2016 10:16  10/14/2016 10:52  Business
# 812   10/14/2016 15:56  10/14/2016 16:20  Business
# 813   10/14/2016 23:54   10/15/2016 2:06  Business
# 814   10/15/2016 22:28  10/15/2016 22:48  Business
# 815    10/16/2016 0:01   10/16/2016 0:14  Business
# 816   10/16/2016 12:52  10/16/2016 13:11  Business
# 817   10/16/2016 14:40  10/16/2016 15:01  Business
# 818   10/16/2016 15:10  10/16/2016 15:19  Business
# 819   10/16/2016 19:27  10/16/2016 19:33  Business
# 820   10/16/2016 20:30  10/16/2016 20:39  Business
# 821   10/16/2016 21:34  10/16/2016 21:41  Business
# 822   10/17/2016 15:19  10/17/2016 15:57  Business
# 823   10/17/2016 16:29  10/17/2016 17:11  Business
# 824   10/17/2016 18:02  10/17/2016 18:16  Business
# 825   10/17/2016 18:31  10/17/2016 18:45  Business
# 826   10/17/2016 19:08  10/17/2016 19:25  Business
# 827    10/18/2016 8:12   10/18/2016 8:22  Business
# 828    10/18/2016 8:53   10/18/2016 9:02  Business
# 829   10/18/2016 10:41  10/18/2016 11:09  Business
# 830   10/18/2016 18:12  10/18/2016 18:33  Business
# 831   10/18/2016 19:03  10/18/2016 19:13  Business
# 832   10/18/2016 20:31  10/18/2016 20:37  Business
# 833    10/19/2016 9:33   10/19/2016 9:47  Business
# 834    10/19/2016 9:54  10/19/2016 10:21  Business
# 835   10/19/2016 13:45  10/19/2016 13:56  Business
# 836   10/19/2016 14:02  10/19/2016 14:31  Business
# 837   10/19/2016 15:44  10/19/2016 16:02  Business
# 838   10/19/2016 16:06  10/19/2016 16:19  Business
# 839   10/19/2016 16:33  10/19/2016 17:01  Business
# 840   10/20/2016 11:26  10/20/2016 11:34  Business
# 841   10/20/2016 12:19  10/20/2016 13:17  Business
# 842   10/20/2016 20:44  10/20/2016 21:37  Business
# 843   10/21/2016 10:06  10/21/2016 10:21  Business
# 844    10/22/2016 0:54   10/22/2016 1:09  Business
# 845   10/22/2016 13:26  10/22/2016 14:03  Business
# 846   10/22/2016 17:08  10/22/2016 17:55  Business
# 847    10/23/2016 9:24  10/23/2016 10:05  Business
# 848   10/23/2016 12:17  10/23/2016 12:59  Business
# 849   10/23/2016 19:04  10/23/2016 19:14  Business
# 850   10/23/2016 21:10  10/23/2016 21:25  Business
# 851   10/24/2016 14:57  10/24/2016 15:26  Business
# 852   10/24/2016 15:33  10/24/2016 16:13  Business
# 853   10/24/2016 16:34  10/24/2016 16:41  Business
# 854   10/25/2016 13:27  10/25/2016 14:08  Business
# 855   10/25/2016 15:04  10/25/2016 15:11  Business
# 856   10/25/2016 15:16  10/25/2016 15:33  Business
# 857   10/25/2016 20:00  10/25/2016 20:11  Business
# 858   10/25/2016 20:54  10/25/2016 21:03  Business
# 859   10/25/2016 22:24  10/25/2016 22:45  Business
# 860   10/26/2016 19:25  10/26/2016 19:31  Business
# 861   10/26/2016 20:53  10/26/2016 21:03  Business
# 862   10/27/2016 18:51  10/27/2016 19:16  Business
# 863   10/27/2016 19:20  10/27/2016 19:35  Business
# 864   10/27/2016 19:52  10/27/2016 20:21  Business
# 865   10/27/2016 20:47  10/27/2016 20:54  Business
# 866   10/27/2016 21:26  10/27/2016 21:48  Business
# 867   10/28/2016 11:34  10/28/2016 11:52  Business
# 868   10/28/2016 13:06  10/28/2016 13:36  Business
# 869   10/28/2016 15:53  10/28/2016 17:59  Business
# 870   10/28/2016 18:13  10/28/2016 20:07  Business
# 871   10/28/2016 20:13  10/28/2016 22:00  Business
# 872   10/29/2016 15:22  10/29/2016 17:05  Business
# 873   10/29/2016 17:13  10/29/2016 19:19  Business
# 874    10/30/2016 7:49   10/30/2016 8:30  Business
# 875    10/30/2016 9:07  10/30/2016 10:09  Business
# 876   10/30/2016 10:11  10/30/2016 10:38  Business
# 877   10/30/2016 10:51  10/30/2016 11:21  Business
# 878   10/30/2016 12:24  10/30/2016 12:35  Business
# 879   10/30/2016 12:58  10/30/2016 13:18  Business
# 880   10/30/2016 13:24  10/30/2016 14:37  Business
# 881   10/30/2016 15:22  10/30/2016 18:23  Business
# 882   10/30/2016 18:26  10/30/2016 19:39  Business
# 883   10/31/2016 18:11  10/31/2016 18:20  Business
# 884   10/31/2016 18:47  10/31/2016 19:16  Business
# 885   10/31/2016 20:18  10/31/2016 20:44  Business
# 886   10/31/2016 21:45  10/31/2016 22:10  Business
# ...
# 490           Meeting
# 491           Meeting
# 492           Meeting
# 493               NaN
# 494               NaN
# 495               NaN
# 496               NaN
# 497           Meeting
# 498           Meeting
# 499           Meeting
# 500           Meeting
# 501           Meeting
# 502           Meeting
# 503           Meeting
# 504           Meeting
# 505           Meeting
# 506           Meeting
# 507   Errand/Supplies
# 508   Errand/Supplies
# 509           Meeting
# 510           Meeting
# 511           Meeting
# 512    Temporary Site
# 513           Meeting
# 514   Errand/Supplies
# 515           Meeting
# 516   Errand/Supplies
# 517               NaN
# 518               NaN
# 519    Meal/Entertain
# 520           Meeting
# 521               NaN
# 522    Meal/Entertain
# 523    Customer Visit
# 524    Temporary Site
# 525               NaN
# 526               NaN
# 527               NaN
# 528               NaN
# 529               NaN
# 530               NaN
# 531               NaN
# 532               NaN
# 533               NaN
# 534               NaN
# 535               NaN
# 536               NaN
# 537               NaN
# 538               NaN
# 539               NaN
# 540               NaN
# 541               NaN
# 542               NaN
# 543               NaN
# 544               NaN
# 545   Errand/Supplies
# 546               NaN
# 547               NaN
# 548               NaN
# 549               NaN
# 550               NaN
# 551               NaN
# 552               NaN
# 553               NaN
# 554               NaN
# 555               NaN
# 556               NaN
# 557   Errand/Supplies
# 558       Charity ($)
# 559           Commute
# 560            Moving
# 561            Moving
# 562            Moving
# 563            Moving
# 564           Meeting
# 565    Meal/Entertain
# 566    Meal/Entertain
# 567   Errand/Supplies
# 568    Meal/Entertain
# 569    Customer Visit
# 570           Meeting
# 571    Meal/Entertain
# 572   Errand/Supplies
# 573               NaN
# 574               NaN
# 575               NaN
# 576               NaN
# 577               NaN
# 578               NaN
# 579               NaN
# 580               NaN
# 581               NaN
# 582               NaN
# 583               NaN
# 584               NaN
# 585           Meeting
# 586    Meal/Entertain
# 587               NaN
# 588               NaN
# 589               NaN
# 590               NaN
# 591               NaN
# 592               NaN
# 593           Meeting
# 594           Meeting
# 595               NaN
# 596               NaN
# 597               NaN
# 598               NaN
# 599               NaN
# 600               NaN
# 601    Meal/Entertain
# 602    Meal/Entertain
# 603               NaN
# 604               NaN
# 605               NaN
# 606               NaN
# 607               NaN
# 608    Meal/Entertain
# 609               NaN
# 610               NaN
# 611               NaN
# 612               NaN
# 613               NaN
# 614               NaN
# 615               NaN
# 616               NaN
# 617               NaN
# 618               NaN
# 619               NaN
# 620           Meeting
# 621               NaN
# 622               NaN
# 623               NaN
# 624               NaN
# 625               NaN
# 626               NaN
# 627               NaN
# 628               NaN
# 629               NaN
# 630               NaN
# 631               NaN
# 632               NaN
# 633    Customer Visit
# 634               NaN
# 635    Meal/Entertain
# 636               NaN
# 637               NaN
# 638    Customer Visit
# 639               NaN
# 640    Customer Visit
# 641               NaN
# 642               NaN
# 643               NaN
# 644               NaN
# 645               NaN
# 646               NaN
# 647               NaN
# 648               NaN
# 649               NaN
# 650               NaN
# 651               NaN
# 652               NaN
# 653               NaN
# 654               NaN
# 655           Meeting
# 656               NaN
# 657               NaN
# 658               NaN
# 659    Temporary Site
# 660               NaN
# 661               NaN
# 662               NaN
# 663               NaN
# 664               NaN
# 665    Temporary Site
# 666               NaN
# 667               NaN
# 668               NaN
# 669               NaN
# 670               NaN
# 671               NaN
# 672               NaN
# 673               NaN
# 674    Temporary Site
# 675    Temporary Site
# 676               NaN
# 677               NaN
# 678               NaN
# 679               NaN
# 680               NaN
# 681               NaN
# 682               NaN
# 683    Airport/Travel
# 684               NaN
# 685               NaN
# 686               NaN
# 687               NaN
# 688               NaN
# 689               NaN
# 690               NaN
# 691               NaN
# 692               NaN
# 693               NaN
# 694               NaN
# 695               NaN
# 696               NaN
# 697               NaN
# 698               NaN
# 699               NaN
# 700               NaN
# 701               NaN
# 702               NaN
# 703               NaN
# 704               NaN
# 705               NaN
# 706               NaN
# 707               NaN
# 708               NaN
# 709               NaN
# 710               NaN
# 711               NaN
# 712               NaN
# 713               NaN
# 714               NaN
# 715               NaN
# 716               NaN
# 717               NaN
# 718               NaN
# 719               NaN
# 720               NaN
# 721               NaN
# 722               NaN
# 723               NaN
# 724               NaN
# 725               NaN
# 726               NaN
# 727               NaN
# 728               NaN
# 729               NaN
# 730               NaN
# 731               NaN
# 732               NaN
# 733               NaN
# 734               NaN
# 735    Temporary Site
# 736               NaN
# 737               NaN
# 738               NaN
# 739               NaN
# 740               NaN
# 741               NaN
# 742               NaN
# 743               NaN
# 744               NaN
# 745               NaN
# 746               NaN
# 747               NaN
# 748               NaN
# 749               NaN
# 750               NaN
# 751               NaN
# 752               NaN
# 753               NaN
# 754               NaN
# 755               NaN
# 756               NaN
# 757               NaN
# 758               NaN
# 759               NaN
# 760               NaN
# 761               NaN
# 762               NaN
# 763               NaN
# 764               NaN
# 765               NaN
# 766               NaN
# 767               NaN
# 768               NaN
# 769               NaN
# 770               NaN
# 771               NaN
# 772               NaN
# 773               NaN
# 774               NaN
# 775               NaN
# 776               NaN
# 777               NaN
# 778               NaN
# 779               NaN
# 780               NaN
# 781               NaN
# 782               NaN
# 783               NaN
# 784               NaN
# 785               NaN
# 786               NaN
# 787               NaN
# 788               NaN
# 789               NaN
# 790               NaN
# 791               NaN
# 792               NaN
# 793               NaN
# 794               NaN
# 795               NaN
# 796               NaN
# 797               NaN
# 798               NaN
# 799               NaN
# 800    Temporary Site
# 801               NaN
# 802               NaN
# 803           Meeting
# 804               NaN
# 805               NaN
# 806               NaN
# 807               NaN
# 808               NaN
# 809               NaN
# 810               NaN
# 811               NaN
# 812               NaN
# 813           Meeting
# 814               NaN
# 815               NaN
# 816           Meeting
# 817               NaN
# 818               NaN
# 819           Meeting
# 820               NaN
# 821    Meal/Entertain
# 822               NaN
# 823               NaN
# 824               NaN
# 825               NaN
# 826               NaN
# 827               NaN
# 828               NaN
# 829    Temporary Site
# 830               NaN
# 831               NaN
# 832               NaN
# 833               NaN
# 834               NaN
# 835               NaN
# 836               NaN
# 837               NaN
# 838               NaN
# 839               NaN
# 840               NaN
# 841               NaN
# 842               NaN
# 843               NaN
# 844               NaN
# 845               NaN
# 846               NaN
# 847               NaN
# 848               NaN
# 849    Meal/Entertain
# 850    Customer Visit
# 851               NaN
# 852               NaN
# 853               NaN
# 854               NaN
# 855               NaN
# 856               NaN
# 857    Meal/Entertain
# 858               NaN
# 859   Errand/Supplies
# 860           Meeting
# 861               NaN
# 862           Meeting
# 863               NaN
# 864               NaN
# 865               NaN
# 866               NaN
# 867           Meeting
# 868           Meeting
# 869           Meeting
# 870           Meeting
# 871           Meeting
# 872           Meeting
# 873               NaN
# 874               NaN
# 875               NaN
# 876               NaN
# 877               NaN
# 878               NaN
# 879               NaN
# 880               NaN
# 881               NaN
# 882               NaN
# 883               NaN
# 884               NaN
# 885               NaN
# 886   Errand/Supplies
# 887               NaN
# 888               NaN
# 889               NaN
# 890               NaN
# 891               NaN
# 892    Meal/Entertain
# 893               NaN
# 894               NaN
# 895           Meeting
# 896               NaN
# 897               NaN
# 898               NaN
# 899               NaN
# 900               NaN
# 901               NaN
# 902    Meal/Entertain
# 903    Customer Visit
# 904    Temporary Site
# 905               NaN
# 906               NaN
# 907               NaN
# 908               NaN
# 909               NaN
# 910               NaN
# 911               NaN
# 912           Meeting
# 913    Customer Visit
# 914               NaN
# 915               NaN
# 916   Between Offices
# 917   Between Offices
# 918   Between Offices
# 919           Meeting
# 920               NaN
# 921               NaN
# 922               NaN
# 923               NaN
# 924               NaN
# 925               NaN
# 926           Meeting
# 927    Customer Visit
# 928               NaN
# 929               NaN
# 930    Temporary Site
# 931               NaN
# 932               NaN
# 933    Temporary Site
# 934           Meeting
# 935               NaN
# 936    Customer Visit
# 937               NaN
# 938               NaN
# 939    Customer Visit
# 940               NaN
# 941               NaN
# 942               NaN
# 943               NaN
# 944               NaN
# 945               NaN
# 946           Meeting
# 947               NaN
# 948               NaN
# 949   Errand/Supplies
# 950               NaN
# 951               NaN
# 952               NaN
# 953               NaN
# 954           Meeting
# 955               NaN
# 956               NaN
# 957               NaN
# 958               NaN
# 959               NaN
# 960    Customer Visit
# 961    Customer Visit
# 962               NaN
# 963   Errand/Supplies
# 964               NaN
# 965    Temporary Site
# 966    Temporary Site
# 967    Temporary Site
# 968    Meal/Entertain
# 969    Customer Visit
# 970    Meal/Entertain
# 971    Meal/Entertain
# 972           Meeting
# 973           Meeting
# 974           Meeting
# 975               NaN
# 976               NaN
# 977   Errand/Supplies
# 978    Customer Visit
# 979   Between Offices
# 980    Customer Visit
# 981           Meeting
# 982   Errand/Supplies
# 983    Meal/Entertain
# 984    Meal/Entertain
# 985   Errand/Supplies
# 986    Meal/Entertain
# 987   Errand/Supplies
# 988           Meeting
# 989           Meeting
# 990    Customer Visit
# 991    Meal/Entertain
# 992    Customer Visit
# 993    Meal/Entertain
# 994               NaN
# 995               NaN
# 996               NaN
# 997           Meeting
# 998           Meeting
# 999               NaN
# 1000          Meeting
# 1001          Meeting
# 1002  Between Offices
# 1003  Errand/Supplies
# 1004   Meal/Entertain
# 1005              NaN
# 1006   Customer Visit
# 1007   Temporary Site
# 1008              NaN
# 1009          Meeting
# 1010  Errand/Supplies
# 1011   Meal/Entertain
# 1012   Customer Visit
# 1013   Meal/Entertain
# 1014   Customer Visit
# 1015   Meal/Entertain
# 1016   Customer Visit
# 1017  Errand/Supplies
# 1018              NaN
# 1019   Customer Visit
# 1020   Meal/Entertain
# 1021   Customer Visit
# 1022              NaN
# 1023   Meal/Entertain
# 1024          Meeting
# 1025          Meeting
# 1026   Customer Visit
# 1027   Meal/Entertain
# 1028  Errand/Supplies
# 1029  Errand/Supplies
# 1030          Meeting
# 1031  Errand/Supplies
# 1032  Errand/Supplies
# 1033   Temporary Site
# 1034          Meeting
# 1035   Customer Visit
# 1036          Meeting
# 1037  Errand/Supplies
# 1038   Meal/Entertain
# 1039   Customer Visit
# 1040   Meal/Entertain
# 1041  Errand/Supplies
# 1042  Errand/Supplies
# 1043  Errand/Supplies
# 1044   Meal/Entertain
# 1045   Customer Visit
# 1046   Meal/Entertain
# 1047   Customer Visit
# 1048  Errand/Supplies
# 1049   Meal/Entertain
# 1050              NaN
# 1051              NaN
# 1052   Meal/Entertain
# 1053   Customer Visit
# 1054          Meeting
# 1055   Airport/Travel
# 1056   Temporary Site
# 1057  Errand/Supplies
# 1058  Errand/Supplies
# 1059              NaN
# 1060  Errand/Supplies
# 1061   Temporary Site
# 1062  Errand/Supplies
# 1063              NaN
# 1064              NaN
# 1065              NaN
# 1066              NaN
# 1067   Customer Visit
# 1068   Customer Visit
# 1069              NaN
# 1070          Meeting
# 1071              NaN
# 1072  Errand/Supplies
# 1073          Meeting
# 1074  Errand/Supplies
# 1075   Temporary Site
# 1076  Errand/Supplies
# 1077  Errand/Supplies
# 1078   Customer Visit
# 1079          Meeting
# 1080  Errand/Supplies
# 1081   Meal/Entertain
# 1082          Meeting
# 1083  Errand/Supplies
# 1084  Errand/Supplies
# 1085          Meeting
# 1086   Customer Visit
# 1087          Meeting
# 1088          Meeting
# 1089          Meeting
# 1090   Customer Visit
# 1091          Meeting
# 1092          Meeting
# 1093  Errand/Supplies
# 1094   Temporary Site
# 1095          Meeting
# 1096   Meal/Entertain
# 1097   Customer Visit
# 1098          Meeting
# 1099          Meeting
# 1100          Meeting
# 1101  Errand/Supplies
# 1102   Meal/Entertain
# 1103   Meal/Entertain
# 1104   Meal/Entertain
# 1105   Meal/Entertain
# 1106  Errand/Supplies
# 1107  Errand/Supplies
# 1108  Errand/Supplies
# 1109   Meal/Entertain
# 1110  Errand/Supplies
# 1111  Errand/Supplies
# 1112   Meal/Entertain
# 1113   Meal/Entertain
# 1114   Meal/Entertain
# 1115   Customer Visit
# 1116   Customer Visit
# 1117   Customer Visit
# 1118          Meeting
# 1119   Temporary Site
# 1120   Meal/Entertain
# 1121   Meal/Entertain
# 1122   Customer Visit
# 1123          Meeting
# 1124   Customer Visit
# 1125   Meal/Entertain
# 1126  Errand/Supplies
# 1127  Errand/Supplies
# 1128   Meal/Entertain
# 1129  Errand/Supplies
# 1130  Errand/Supplies
# 1131  Errand/Supplies
# 1132  Errand/Supplies
# 1133   Meal/Entertain
# 1134   Meal/Entertain
# 1135  Errand/Supplies
# 1136  Errand/Supplies
# 1137   Airport/Travel
# 1138  Between Offices
# 1139  Errand/Supplies
# 1140   Meal/Entertain
# 1141   Customer Visit
# 1142          Meeting
# 1143              NaN
# 1144          Meeting
# 1145  Errand/Supplies
# 1146  Errand/Supplies
# 1147  Errand/Supplies
# 1148          Meeting
# 1149   Customer Visit
# 1150          Meeting
# 1151   Temporary Site
# 1152          Meeting
# 1153   Temporary Site
# 1154   Temporary Site
# 1155              NaN  >

# %%
df[["START*","STOP*"]].describe()
# Out:
#        START* STOP*
# count    1155  1155
# unique    177   188
# top      Cary  Cary
# freq      201   203

# %%
df[["START*","STOP*","END_DATE*"]].describe()
# Out:
#        START* STOP*        END_DATE*
# count    1155  1155             1155
# unique    177   188             1154
# top      Cary  Cary  6/28/2016 23:59
# freq      201   203                2

# %%
df[["START*","STOP*","MILES*"]].describe(include="all")
# Out:
#        START* STOP*        MILES*
# count    1155  1155   1156.000000
# unique    177   188           NaN
# top      Cary  Cary           NaN
# freq      201   203           NaN
# mean      NaN   NaN     21.115398
# std       NaN   NaN    359.299007
# min       NaN   NaN      0.500000
# 25%       NaN   NaN      2.900000
# 50%       NaN   NaN      6.000000
# 75%       NaN   NaN     10.400000
# max       NaN   NaN  12204.700000

# %% [markdown]
# ### Simple Uni Variate Analysis

# %%
### No of trips per Category - analyse the column "CATEGORY*"

# %%
### to get the top5 rows of "CATEGORY*"
df['CATEGORY*']
# Out:
# 0       Business
# 1       Business
# 2       Business
# 3       Business
# 4       Business
#           ...
# 1151    Business
# 1152    Business
# 1153    Business
# 1154    Business
# 1155         NaN
# Name: CATEGORY*, Length: 1156, dtype: object

# %%
x
# Out:
# 0    Business
# 1    Business
# 2    Business
# 3    Business
# 4    Business
# Name: CATEGORY*, dtype: object

# %%
### to get the bottom 5 rows of "CATEGORY*"
df['CATEGORY*'].tail()
# Out:
# 1151    Business
# 1152    Business
# 1153    Business
# 1154    Business
# 1155         NaN
# Name: CATEGORY*, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df['CATEGORY*'].isnull().sum()
# Out:
# 1

# %%
 df['CATEGORY*'].describe(include="all")
# Out:
# count         1155
# unique           2
# top       Business
# freq          1078
# Name: CATEGORY*, dtype: object

# %%
### to understand how many rows as  "CATEGORY" = "Business" and "CATEGORY" = "Personal"
df['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
### another way to find out the highest occuring category
df['CATEGORY*'].mode()
# Out:
# 0    Business
# dtype: object

# %%
### gives the unique occurrences of each value in a column
df["START*"].value_counts() 

### The top occurring value is "Cary"               - Means many customers have bought a cab service starting at place "Cary"
                                                ##  - highest revenue earning starting location

### The second Occuring value is "Unknown Location" - - second highest revenue earning starting location is "Unknown Location"
                                                ##     - could be a case of system glitch or a case of fraud. more analysis is
                                                ##     - required
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: START*, Length: 177, dtype: int64

# %%
### top 5 records of the value counts of categories
df["START*"].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %%
### gives  unique values in START*
df["START*"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
#        'North Austin', 'Coxville', 'Convention Center District', 'Austin',
#        'Katy', 'Sharpstown', 'Sugar Land', 'Galveston', 'Port Bolivar',
#        'Washington Avenue', 'Briar Meadow', 'Latta', 'Jacksonville',
#        'Couples Glen', 'Kissimmee', 'Lake Reams', 'Orlando',
#        'Sand Lake Commons', 'Sky Lake', 'Daytona Beach', 'Ridgeland',
#        'Florence', 'Meredith', 'Holly Springs', 'Chessington', 'Burtrose',
#        'Parkway', 'Mcvan', 'Capitol One', 'University District',
#        'Seattle', 'Redmond', 'Bellevue', 'San Francisco', 'Palo Alto',
#        'Sunnyvale', 'Newark', 'Menlo Park', 'Old City', 'Savon Height',
#        'Kilarney Woods', 'Townes at Everett Crossing', 'Huntington Woods',
#        'Seaport', 'Medical Centre', 'Rose Hill', 'Soho', 'Tribeca',
#        'Financial District', 'Oakland', 'Emeryville', 'Berkeley',
#        'Kenner', 'CBD', 'Lower Garden District', 'Lakeview', 'Storyville',
#        'New Orleans', 'Metairie', 'Chalmette', 'Arabi',
#        'Pontchartrain Shores', 'Marigny', 'Covington', 'Mandeville',
#        'Jamestown Court', 'Summerwinds', 'Parkwood',
#        'Pontchartrain Beach', 'St Thomas', 'Banner Elk', 'Elk Park',
#        'Newland', 'Boone', 'Stonewater', 'Lexington Park at Amberly',
#        'Arlington Park at Amberly', 'Arlington', 'Kalorama Triangle',
#        'K Street', 'West End', 'Connecticut Avenue', 'Columbia Heights',
#        'Washington', 'Wake Forest', 'Lahore', 'Karachi', 'SOMISSPO',
#        'West Berkeley', 'North Berkeley Hills', 'San Jose', 'Eagle Rock',
#        'Winston Salem', 'Asheville', 'Topton', 'Hayesville',
#        'Bryson City', 'Almond', 'Mebane', 'Agnew', 'Cory', 'Renaissance',
#        'Santa Clara', 'NOMA', 'Sunnyside', 'Ingleside', 'Central',
#        'Tenderloin', 'College Avenue', 'South', 'Southside',
#        'South Berkeley', 'Mountain View', 'El Cerrito', 'Krendle Woods',
#        'Wake Co.', 'Fuquay-Varina', 'Rawalpindi', 'Kar?chi', 'Katunayake',
#        'Gampaha', nan], dtype=object)

# %%
### to get the number of unique values in a given column
df["START*"].nunique()
# Out:
# 177

# %%
### analyse column "MILES*"

# %%
df["MILES*"].describe()
# Out:
# count     1156.000000
# mean        21.115398
# std        359.299007
# min          0.500000
# 25%          2.900000
# 50%          6.000000
# 75%         10.400000
# max      12204.700000
# Name: MILES*, dtype: float64

# %%
df["MILES*"].max()
# Out:
# 12204.7

# %%
df["MILES*"].min()
# Out:
# 0.5

# %%
df["MILES*"].mean()
# Out:
# 21.11539792387542

# %%
df["MILES*"].median()
# Out:
# 6.0

# %%
df["MILES*"].sum()
# Out:
# 24409.4

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df["MILES*"].std()
# Out:
# 359.2990073950659

# %%
df["MILES*"].var()
# Out:
# 129095.77671507963

# %%
import seaborn as sns

# %%
sns.distplot(df["MILES*"],kde=True,hist=True,bins=2)
# Out:
# C:\Users\anand\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MILES*', ylabel='Density'>

# %%
#pd.read_csv('My_Output2').head()

# %% [markdown]
# ### Groupby Summarize

# %%
dfnew.groupby("start").agg("mean").head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15796/4021140938.py in <module>
# ----> 1 dfnew.groupby("start").agg("mean").head()
#
# NameError: name 'dfnew' is not defined

# %%
# for each start loc find the mean distance travelled
dfnew.groupby("start")["miles"].agg("mean").head()
# Out:
# start
# Agnew         2.775000
# Almond       15.200000
# Apex          5.341176
# Arabi        17.000000
# Arlington     4.900000
# Name: miles, dtype: float64

# %%
# for each start loc find the mean & the total dist travelled
dfnew.groupby("start").agg(["mean","sum"]).head()
# Out:
#                miles
#                 mean   sum
# start
# Agnew       2.775000  11.1
# Almond     15.200000  15.2
# Apex        5.341176  90.8
# Arabi      17.000000  17.0
# Arlington   4.900000   4.9

# %% [markdown]
# ### Assignments
#
# 1) Find mean quarterly sales by store
#
# 2) Find the month with highest sales for each store

# %% [markdown]
# ## Other/Optional/Miscellaneous topics

# %% [markdown]
# ##### Creating series objects

# %%
### let us create 4 objects

### create a new list called "labels"  with strings
labels = ['a','b','c','d','e']

#### create a new list of numbers
my_data = [10,20,30,40,50]

#### create a numpy array 
arr = np.array(my_data)

### create a dictionary
d = {'key1':10, 'key2':20,'key3':100,'key4':40,'key5':50}

# %%
print(labels)

print(my_data)

print(arr)

print(d)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# [10, 20, 30, 40, 50]
# [10 20 30 40 50]
# {'key1': 10, 'key2': 20, 'key3': 100, 'key4': 40, 'key5': 50}

# %%
#### create a new series.
### A series takes a wide variety of params. We will focus only on data and index

### CREATE A SERIES WITH "data" as parameter and passing the list my_data
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# #### create series with "data" parameter from my_data list and index parameter from "labels" list
# my_series=pd.Series(data=my_data,index=labels)
#
# #### note the contents of the list "lablels" as become the index of the Series my_series

# %%
###### Difference between Numpy and Series
###### unlike numpy array, i have labeled index , i can have one object as an index of another object
###### data points or observations can be called using the labled index

# %%
#### creating a series by using numpy array. with automatic indexes (no index parameter specified)

pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
#### creating a Series out of a tuple
### create my_tup
my_tup = ((1,2),('aa','bb'),(3,4),('cc','dd'),(50,60))

pd.Series(data=my_tup,index=labels)


#### note
  ### the indexes and contents of the tuples need to align
# Out:
# a      (1, 2)
# b    (aa, bb)
# c      (3, 4)
# d    (cc, dd)
# e    (50, 60)
# dtype: object

# %%
#### creating a series by using numpy array and labeled indexes index is the list "labels"
ser_1 = pd.Series(data=arr,index=labels)
print(ser_1)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int32

# %% [markdown]
# ### Indexing in a series

# %%
### to grab the first element in a series
## by using default indexes
print(ser_1[0])

### by using .iloc
print(ser_1.iloc[0])
# Out:
# 10
# 10

# %%
## or
## by using labels
print(ser_1['a'] )
print(ser_1.loc['a'])
# Out:
# 10
# 10

# %%
### slice notation in series
print('series data retrieval using regular index values')
print(ser_1[0:2])

#or by using .iloc
print('\n')  ## new line
 
print('series data retrieval using .iloc')
print(ser_1.iloc[0:2])
# Out:
# series data retrieval using regular index values
# a    10
# b    20
# dtype: int32
#
#
# series data retrieval using .iloc
# a    10
# b    20
# dtype: int32

# %%
### slice notation in series with "user defined indexes" - work differently
ser_1['a':'c']
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
print('series data retrieval using .loc and slice notation')

ser_1.loc['a' : 'c']

### note slice notation works differently while using user defined indexes
# Out:
# series data retrieval using .loc and slice notation
# a    10
# b    20
# c    30
# dtype: int32

# %%
print('series data retrieval using .iloc and slice notation')

ser_1.iloc[0 : 3]
# Out:
# series data retrieval using .iloc and slice notation
# a    10
# b    20
# c    30
# dtype: int32

# %% [markdown]
# ---

# %% [markdown]
#  ### Data Manipulation - Manipulation of Date and Time
#    - Sometimes Dates need to be manipulated
#    - Date manipulation in pandas needs code to be written and every date format needs to be specified
#    - its a little cumbersome

# %%
import datetime as dt
from datetime import timedelta
 
datetimeFormat = '%Y-%m-%d %H:%M:%S.%f'
date1 = '2016-04-16 10:01:28.585'
date2 = '2016-03-10 09:56:28.067'
diff = dt.datetime.strptime(date1, datetimeFormat) - dt.datetime.strptime(date2, datetimeFormat)
 
print("Difference:", diff)
print("Days:", diff.days)
print("Microseconds:", diff.microseconds)
print("Seconds:", diff.seconds)
# Out:
# Difference: 37 days, 0:05:00.518000
# Days: 37
# Microseconds: 518000
# Seconds: 300

# %%
### calculating elapsed time

import time
start = time.time()

time.sleep(10)  # or do something more productive

# %%
done = time.time()
elapsed = done - start
print(elapsed)

# %% [markdown]
# #### Alternate Ways of using Group By

# %%
import numpy as np
import pandas as pd

# %%
sales_data = {'Company':['GooG','GooG','MSFT','MSFT','FB','FB'],
              'Person' :['John Smith','Jane Doe','Amy','Andy','Charlie','Karla'],
              'Sales'  :[200,400,600,1000,1200,10000]}

# %%
### create a data frame using dictionary sales_data
sales_df = pd.DataFrame(data=sales_data)

# %%
sales_df
# Out:
#   Company      Person  Sales
# 0    GooG  John Smith    200
# 1    GooG    Jane Doe    400
# 2    MSFT         Amy    600
# 3    MSFT        Andy   1000
# 4      FB     Charlie   1200
# 5      FB       Karla  10000

# %%
#### using Group By Method. group by "company" column

grpbycomp = sales_df.groupby('Company')
grpbycomp
print(type(grpbycomp))

### note that the output is a group by object
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>

# %%
### mean of sales by company or average sales for each company
grpbycomp.mean()

### for eg mean sales of facebook is (1200+10000)/2) = 5600 
### outputs a data frame with index called company and sales
### this allows us to further process the data
# Out:
#          Sales
# Company
# FB        5600
# GooG       300
# MSFT       800

# %%
### to find total sales per company
grpbycomp.sum()
# Out:
#          Sales
# Company
# FB       11200
# GooG       600
# MSFT      1600

# %%
#### to get the overall sales of facebook - extract this from the resultset of the previous line executed
grpbycomp.sum().loc['FB']
# Out:
# Sales    11200
# Name: FB, dtype: int64

# %%
### smart coding 
res= sales_df.groupby('Company').sum().loc['FB']
print(res)
# Out:
# Sales    11200
# Name: FB, dtype: int64

# %%
### smart coding 
res= sales_df.groupby('Company').sum().loc[['FB','GooG']]
print(res)
# Out:
#          Sales
# Company
# FB       11200
# GooG       600

# %%
#### to get the overall sales of Google
grpbycomp.sum().loc['GooG']

# %%
### smart coding 
sales_df.groupby('Company').sum().loc['GooG']
# Out:
# Sales    600
# Name: GooG, dtype: int64

# %%
### other ways of writing expression with groupby
#### groupby (column). aggregatefunction
sales_df.groupby('Company').sum().loc['FB']
# Out:
# Sales    11200
# Name: FB, dtype: int64

# %%
### to count the number of persons in each company

sales_df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GooG          2      2
# MSFT          2      2

# %%
### count of rows in Sales column for every company
sales_df.groupby('Company').count()['Sales']
# Out:
# Company
# FB      2
# GooG    2
# MSFT    2
# Name: Sales, dtype: int64

# %%
### Max Sales in every company

sales_df.groupby('Company').max()
# Out:
#              Person  Sales
# Company
# FB            Karla  10000
# GooG     John Smith    400
# MSFT           Andy   1000

# %%
sales_df.groupby('Company').min()
# Out:
#            Person  Sales
# Company
# FB        Charlie   1200
# GooG     Jane Doe    200
# MSFT          Amy    600

# %%
#### group by with describe method, gives min,max, mean , count, std deviation, \
### 1st quartile, 2nd quartile, 3rd quartile.
### All your summary statistics will be displayed by describe

sales_df.groupby('Company').describe()
# Out:
#         Sales
#         count    mean          std     min     25%     50%     75%      max
# Company
# FB        2.0  5600.0  6222.539674  1200.0  3400.0  5600.0  7800.0  10000.0
# GooG      2.0   300.0   141.421356   200.0   250.0   300.0   350.0    400.0
# MSFT      2.0   800.0   282.842712   600.0   700.0   800.0   900.0   1000.0

# %%
### describe on the overall dataframe
sales_df.describe(include='all')
# Out:
#        Company   Person         Sales
# count        6        6      6.000000
# unique       3        6           NaN
# top         FB  Charlie           NaN
# freq         2        1           NaN
# mean       NaN      NaN   2233.333333
# std        NaN      NaN   3822.913374
# min        NaN      NaN    200.000000
# 25%        NaN      NaN    450.000000
# 50%        NaN      NaN    800.000000
# 75%        NaN      NaN   1150.000000
# max        NaN      NaN  10000.000000

# %%
#### use transpose method on describe method output to transpose rows and columns
sales_df.groupby('Company').describe().transpose()
# Out:
# Company                FB        GooG         MSFT
# Sales count      2.000000    2.000000     2.000000
#       mean    5600.000000  300.000000   800.000000
#       std     6222.539674  141.421356   282.842712
#       min     1200.000000  200.000000   600.000000
#       25%     3400.000000  250.000000   700.000000
#       50%     5600.000000  300.000000   800.000000
#       75%     7800.000000  350.000000   900.000000
#       max    10000.000000  400.000000  1000.000000

# %%
### for loop to iterate through a data frame columns
#for key, value in df100.iteritems():
#    value +=1                        ## value = value+1
 #   print(key,value)

# %%
df200 = pd.DataFrame(np.random.rand(5,4),columns=['col1','col2','col3','col4'])

# %%
df200
# Out:
#        col1      col2      col3      col4
# 0  0.468889  0.077554  0.518809  0.388241
# 1  0.549242  0.727328  0.302544  0.116583
# 2  0.132353  0.819229  0.973219  0.717648
# 3  0.696574  0.934283  0.390065  0.630795
# 4  0.732080  0.049692  0.387112  0.710102

# %%
### for loop to iterate through a data frame rows

for key, value in df200.iterrows():
    value= value+100
    print(key,value)
# Out:
# 0 col1    100.468889
# col2    100.077554
# col3    100.518809
# col4    100.388241
# Name: 0, dtype: float64
# 1 col1    100.549242
# col2    100.727328
# col3    100.302544
# col4    100.116583
# Name: 1, dtype: float64
# 2 col1    100.132353
# col2    100.819229
# col3    100.973219
# col4    100.717648
# Name: 2, dtype: float64
# 3 col1    100.696574
# col2    100.934283
# col3    100.390065
# col4    100.630795
# Name: 3, dtype: float64
# 4 col1    100.732080
# col2    100.049692
# col3    100.387112
# col4    100.710102
# Name: 4, dtype: float64

# %%
df200
# Out:
#        col1      col2      col3      col4
# 0  0.468889  0.077554  0.518809  0.388241
# 1  0.549242  0.727328  0.302544  0.116583
# 2  0.132353  0.819229  0.973219  0.717648
# 3  0.696574  0.934283  0.390065  0.630795
# 4  0.732080  0.049692  0.387112  0.710102

# %%
for key, value in df200.iteritems():
    value= value+100
    print(key,value)
# Out:
# col1 0    100.468889
# 1    100.549242
# 2    100.132353
# 3    100.696574
# 4    100.732080
# Name: col1, dtype: float64
# col2 0    100.077554
# 1    100.727328
# 2    100.819229
# 3    100.934283
# 4    100.049692
# Name: col2, dtype: float64
# col3 0    100.518809
# 1    100.302544
# 2    100.973219
# 3    100.390065
# 4    100.387112
# Name: col3, dtype: float64
# col4 0    100.388241
# 1    100.116583
# 2    100.717648
# 3    100.630795
# 4    100.710102
# Name: col4, dtype: float64

# %% [markdown]
# # Merging, Joining, and Concatenating
#
# ###
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating. In this lecture we will discuss these 3 methods with examples.
#
# ###### we have used simple objects for ease of understanding

# %% [markdown]
# ### Example DataFrames
# ### column names but indexes are different

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
## note indexes are different

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

## note indexes are different

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

## note indexes are different

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use **pd.concat** and pass in a list of DataFrames to concatenate together:

# %%
### the axis of concatenation is rows - because by default axis=0 represents rows. so concatenation happens on rows
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
### concatenating on columns
pd.concat([df1,df2,df3],axis=1)

### note the missing values as the columns do not have corresponding row indexes are different
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# _____
# ## Example DataFrames
#
# ##### column names are different and indexes are default (not user defined)

# %%
left = pd.DataFrame({'mykeys': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'mykeys': ['K0', 'K1', 'K2', 'K3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   mykeys   A   B
# 0     K0  A0  B0
# 1     K1  A1  B1
# 2     K2  A2  B2
# 3     K3  A3  B3

# %%
right
# Out:
#   mykeys   C   D
# 0     K0  C0  D0
# 1     K1  C1  D1
# 2     K2  C2  D2
# 3     K3  C3  D3

# %%
pd.concat([left,right]) ### concat on rows

### note missing values in c and d cols and a and b cols
# Out:
# C:\Users\anand\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      A    B    C    D mykeys
# 0   A0   B0  NaN  NaN     K0
# 1   A1   B1  NaN  NaN     K1
# 2   A2   B2  NaN  NaN     K2
# 3   A3   B3  NaN  NaN     K3
# 0  NaN  NaN   C0   D0     K0
# 1  NaN  NaN   C1   D1     K1
# 2  NaN  NaN   C2   D2     K2
# 3  NaN  NaN   C3   D3     K3

# %%
pd.concat([left,right],axis=1)

### note no missing values now as the concatenation has happned across columns. 
### the column key matches with both dataframes and hence no missing values
# Out:
#   mykeys   A   B mykeys   C   D
# 0     K0  A0  B0     K0  C0  D0
# 1     K1  A1  B1     K1  C1  D1
# 2     K2  A2  B2     K2  C2  D2
# 3     K3  A3  B3     K3  C3  D3

# %% [markdown]
# ___

# %% [markdown]
# ## Merging
#
# The **merge** function allows you to merge DataFrames together using a similar logic as merging SQL Tables together. For example:

# %%
pd.merge(left,right,how='inner',on='mykeys')

### merge type is inner join and on the column "key"
### brings the data together based on the matching values of column "key"
# Out:
#   mykeys   A   B   C   D
# 0     K0  A0  B0  C0  D0
# 1     K1  A1  B1  C1  D1
# 2     K2  A2  B2  C2  D2
# 3     K3  A3  B3  C3  D3

# %% [markdown]
# Or to show a more complicated example:

# %%
left1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right1 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                         'C': ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

### note that the  keys key1 and key2 do not exactly match betweeen 2 dataframes here

# %%
print(left1)
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
print(right1)
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left1, right1, on=['key1', 'key2'])

## only those data points which have matching mykey1+mykey2 beteween dataframe1 and dataframe2 is displayed
## example in lef dataframe when key1 = k0 and key2 = k0, there is an equivalent key match in right dataframe key1 = k0
##  and key2 = k0. 
## output will be displayed on this matching columns

### no key match for k0,k1 / k2,k1 /k2,k0
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
print(left)
# Out:
#   mykeys   A   B
# 0     K0  A0  B0
# 1     K1  A1  B1
# 2     K2  A2  B2
# 3     K3  A3  B3

# %%
print(right)
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left1, right1, how='outer', on=['key1','key2'])   ### similar to sql full outer join

### displays all the matched and unmatched keys
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left1, right1, how='right', on=['key1', 'key2'])        ### similar to sql right outer join

## displays matched rows  and unmatched rows from right1 dataframe
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left1, right1, how='left', on=['key1', 'key2'])

### displays all matched, and unmatched rows from left1 dataframe
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# ## Joining
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.

# %%
left2 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left2.join(right2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
### 
left2.join(right2, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ---

# %% [markdown]
# ### Treating Outliers in Python
#
# #### why do we need to treat outliers
#     - Outliers can impact the results of our analysis and statistical modeling in a drastic way.

# %%
dfout = pd.read_csv("Uber Drives 2016.csv")
dfout.rename(columns={'START_DATE*' : 'start_date',
                    'END_DATE*'  : 'end_date',
                     'CATEGORY*' : 'category',
                     'START*'    : 'start',
                     'STOP*'     : 'stop',
                     'MILES*'    :  'miles',
                     'PURPOSE*'   :  'purpose' }, 
                 inplace=True)

# %%
dfout.head()
# Out:
#        start_date        end_date  category        start             stop  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    miles          purpose
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
dfout['miles'].value_counts()
# Out:
# 9.9        28
# 3.1        26
# 2.1        19
# 10.4       19
# 2.5        19
# 3.0        19
# 1.8        18
# 2.2        18
# 1.7        18
# 2.8        16
# 1.9        16
# 2.0        16
# 3.3        16
# 6.1        15
# 3.8        15
# 1.4        14
# 5.5        14
# 1.6        13
# 7.9        13
# 1.5        12
# 2.7        12
# 6.2        12
# 5.7        12
# 2.9        12
# 2.3        12
# 6.0        11
# 7.7        11
# 1.0        11
# 4.9        11
# 5.1        11
# 8.7        10
# 3.9        10
# 3.6        10
# 8.4        10
# 5.3        10
# 2.4         9
# 1.2         9
# 2.6         9
# 3.2         9
# 4.1         9
# 7.6         9
# 1.1         9
# 8.0         9
# 4.8         9
# 6.4         8
# 0.9         8
# 0.7         8
# 4.4         8
# 4.0         8
# 1.3         8
# 13.0        8
# 7.2         8
# 5.9         8
# 5.2         8
# 4.6         7
# 3.4         7
# 8.1         7
# 10.5        7
# 8.8         6
# 6.3         6
# 9.8         6
# 4.7         6
# 7.3         6
# 11.8        6
# 9.6         6
# 12.9        6
# 5.0         6
# 4.2         6
# 0.8         6
# 6.6         6
# 4.3         6
# 13.6        5
# 0.6         5
# 13.2        5
# 6.5         5
# 3.5         5
# 12.2        5
# 8.3         5
# 4.5         5
# 8.5         5
# 12.7        5
# 7.5         5
# 10.3        5
# 8.2         4
# 8.6         4
# 12.8        4
# 5.8         4
# 11.2        4
# 7.8         4
# 16.5        4
# 9.2         4
# 15.1        4
# 14.0        4
# 3.7         4
# 5.6         4
# 9.0         4
# 6.9         4
# 12.6        4
# 6.7         4
# 17.0        4
# 12.4        4
# 11.3        3
# 10.1        3
# 16.2        3
# 11.6        3
# 7.1         3
# 15.7        3
# 10.6        3
# 15.5        3
# 10.9        3
# 8.9         3
# 9.4         3
# 16.3        3
# 9.5         3
# 7.0         3
# 12.0        3
# 12.5        3
# 14.5        3
# 10.0        3
# 11.5        3
# 19.0        3
# 0.5         3
# 18.4        3
# 5.4         3
# 10.8        3
# 9.7         3
# 14.7        3
# 15.6        3
# 12.1        3
# 13.3        3
# 11.9        3
# 14.9        2
# 10.2        2
# 14.4        2
# 9.3         2
# 18.7        2
# 23.5        2
# 12.3        2
# 17.2        2
# 44.6        2
# 17.3        2
# 14.1        2
# 15.3        2
# 18.2        2
# 19.4        2
# 144.0       2
# 11.0        2
# 14.2        2
# 20.5        2
# 18.0        2
# 15.2        2
# 17.1        2
# 13.8        2
# 6.8         2
# 18.3        2
# 9.1         2
# 11.4        2
# 25.6        2
# 28.1        2
# 16.4        2
# 17.6        2
# 13.5        2
# 7.4         2
# 18.9        1
# 39.2        1
# 18.5        1
# 35.0        1
# 33.2        1
# 133.6       1
# 40.7        1
# 30.0        1
# 15.0        1
# 20.2        1
# 15.9        1
# 13.1        1
# 50.4        1
# 22.5        1
# 195.3       1
# 19.3        1
# 18.6        1
# 17.9        1
# 46.9        1
# 21.9        1
# 37.7        1
# 69.1        1
# 180.2       1
# 63.7        1
# 17.4        1
# 23.0        1
# 77.3        1
# 13.4        1
# 20.0        1
# 195.9       1
# 21.4        1
# 19.1        1
# 136.0       1
# 45.2        1
# 57.0        1
# 32.3        1
# 31.7        1
# 103.0       1
# 201.0       1
# 28.8        1
# 41.9        1
# 17.7        1
# 31.9        1
# 159.3       1
# 16.7        1
# 13.9        1
# 14.6        1
# 12204.7     1
# 156.9       1
# 48.2        1
# 43.9        1
# 43.6        1
# 40.2        1
# 23.3        1
# 27.2        1
# 28.6        1
# 35.1        1
# 112.6       1
# 32.8        1
# 68.4        1
# 43.7        1
# 22.3        1
# 91.8        1
# 36.6        1
# 30.2        1
# 28.2        1
# 29.8        1
# 23.1        1
# 107.0       1
# 86.6        1
# 80.5        1
# 25.7        1
# 174.2       1
# 20.3        1
# 36.5        1
# 25.2        1
# 45.9        1
# 96.2        1
# 16.1        1
# 20.6        1
# 47.7        1
# 13.7        1
# 23.2        1
# 75.7        1
# 22.4        1
# 23.8        1
# 15.4        1
# 25.9        1
# 310.3       1
# 11.1        1
# 10.7        1
# 195.6       1
# 16.6        1
# 22.7        1
# Name: miles, dtype: int64

# %%
q = dfout["miles"].quantile(0.99)

# %%
dfout['miles'].value_counts().sum()
# Out:
# 1156

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)  ### lower quartile
    q3 = df_in[col_name].quantile(0.75)  ### upper quartile
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
x = remove_outlier(dfout,'miles')

# %%
x['miles'].value_counts().sum()
# Out:
# 1078

# %% [markdown]
# ### Angle-Based Outlier Detection (ABOD)
# - It considers the relationship between each point and its neighbor(s).
# - It does not consider the relationships among these neighbors.
# - The variance of its weighted cosine scores to all neighbors could be viewed as the outlying score
# - ABOD performs well on multi-dimensional data
# - PyOD provides two different versions of ABOD:
# - Fast ABOD: Uses k-nearest neighbors to approximate
# - Original ABOD: Considers all training points with high-time complexity

# %% [markdown]
# ### k-Nearest Neighbors Detector
# - For any data point, the distance to its kth nearest neighbor could be viewed as the outlying score
# - PyOD supports three kNN detectors:
#     - Largest: Uses the distance of the kth neighbor as the outlier score
#     - Mean: Uses the average of all k neighbors as the outlier score
#     - Median: Uses the median of the distance to k neighbors as the outlier score

# %% [markdown]
# ### Isolation Forest
# - It uses the scikit-learn library internally. In this method, data partitioning is done using a set of trees.
# - Isolation Forest provides an anomaly score looking at how isolated the point is in the structure.
# - The anomaly score is then used to identify outliers from normal observations
# - Isolation Forest performs well on multi-dimensional data

# %% [markdown]
# ##### OPTIONAL TOPICS (Use as is needed)

# %% [markdown]
# ##### Use of Random library and Random.seed
#        - the random library is used for generating random numbers
#        - random.seed helps to genreate the same set of random numbers everytime

# %%
from numpy.random import randn 

### similar to numpy.random.randn

# %%
np.random.seed(101)      #### we get the same set of random numbers

# %%
### Test for random no generation
import random
print ("Random number with seed 30")
random.seed( 30 )
print ("first - ", random.randint(25,50))
#will generate a same random number as previous
random.seed( 30 )
print ("Second - ", random.randint(25,50))
#will generate a same random number as previous
random.seed( 30 )
print ("Third - ", random.randint(25,50))
# Out:
# Random number with seed 30
# first -  42
# Second -  42
# Third -  42

# %% [markdown]
# ### Matrix operations use case

# %% [markdown]
# ### Example 1 - compute month on month growth in sales

# %%
store_sales = pd.read_csv("store_sales.csv")

# %%
store_sales.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13

# %%
sales_mat = np.array(store_sales.iloc[:,2:])

# %%
sales_mat
# Out:
# array([[ 8, 20, 13, ...,  9,  7,  6],
#        [12, 19, 15, ..., 11, 21, 19],
#        [16, 16, 14, ..., 14, 24,  8],
#        ...,
#        [16,  9,  6, ..., 22, 17, 22],
#        [18, 16,  9, ..., 17, 19, 10],
#        [ 5, 23, 17, ..., 20,  5,  9]], dtype=int64)

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag
# Out:
# array([[20, 13, 21, ...,  9,  7,  6],
#        [19, 15, 15, ..., 11, 21, 19],
#        [16, 14, 19, ..., 14, 24,  8],
#        ...,
#        [ 9,  6, 14, ..., 22, 17, 22],
#        [16,  9,  5, ..., 17, 19, 10],
#        [23, 17, 24, ..., 20,  5,  9]], dtype=int64)

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag = np.c_[sales_mat_lag,np.zeros(100)]

# %%
sales_diff = sales_mat_lag - sales_mat

# %%
perct_change = pd.DataFrame(sales_diff/sales_mat)

# %%
perct_change.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.500000 -0.350000  0.615385 -0.190476  0.176471  0.200000 -0.291667
# 1  0.583333 -0.210526  0.000000 -0.266667  0.727273 -0.631579  1.142857
# 2  0.000000 -0.125000  0.357143  0.210526 -0.739130  1.166667  0.000000
# 3  1.250000 -0.277778 -0.230769  0.400000  0.000000 -0.571429  0.333333
# 4 -0.736842  3.800000 -0.625000 -0.444444  3.800000 -0.583333 -0.500000
#
#          7         8         9         10   11
# 0 -0.058824 -0.437500 -0.222222 -0.142857 -1.0
# 1 -0.333333  0.100000  0.909091 -0.095238 -1.0
# 2  0.153846 -0.066667  0.714286 -0.666667 -1.0
# 3  0.000000  1.250000 -0.611111  0.571429 -1.0
# 4  3.800000 -0.375000 -0.600000  1.166667 -1.0

# %% [markdown]
# ### Example 1 - compute net revenue

# %%
profit_mat = np.random.uniform(low=0.05, high=0.25, size=(100,12))

# %%
## Find total annual profit for each store
profit_mat = profit_mat.transpose()

# %%
profit_mat.shape
# Out:
# (12, 100)

# %%
prof_matrix = np.dot(sales_mat,profit_mat)

# %%
prof_matrix.shape
# Out:
# (100, 100)

# %%
prof_matrix
# Out:
# array([[26.41569728, 33.01168971, 25.25683158, ..., 25.39903693,
#         26.41128217, 25.43750936],
#        [27.49826907, 34.75977543, 24.38745803, ..., 22.82258243,
#         24.51307131, 25.94602128],
#        [27.59829379, 35.78681714, 24.3944105 , ..., 24.17100634,
#         29.12625627, 27.59860201],
#        ...,
#        [26.85743716, 33.75101337, 23.06119788, ..., 22.72592125,
#         26.08304965, 24.91544673],
#        [27.4633386 , 33.9282459 , 24.28436918, ..., 23.59420231,
#         25.72654251, 27.18798676],
#        [27.40572615, 33.64371642, 23.98673658, ..., 25.35221968,
#         25.30234862, 25.85400044]])
